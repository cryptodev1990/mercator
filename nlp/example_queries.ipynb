# %%
intros = ['Get',
          'Show me',
          '']

POIs = ['all the coffee shops',
        'coffee shops',
        'the single family homes',
        'single family homes',
        'multi-family homes',
        'multifamily homes',
        'bars',
        'pubs',
        'brewpubs',
        'restaurants',
        'fast food joints',
        'parks',
        'schools'
        'elementary schools',
        'middle schools',
        'high schools']

AOIs = ['California',
        'Iowa',
        'Los Angeles',
        'San Diego',
        'San Jose',
        'San Francisco',
        'Fresno',
        'Sacramento',
        'Long Beach',
        'Oakland',
        'Bakersfield',
        'Anaheim',
        '94112',
        '94110',
        '94122',
        '94109',
        '94116',
        '94118',
        '94117',
        '94121',
        '94134',
        '94124',
        '94114',
        '94115',
        '94102',
        '94132',
        '94103',
        '94131',
        '94107',
        '94133',
        '94123',
        '94127',
        '94108',
        '94105',
        '94158',
        '94111',
        '94129',
        '94104',
        '94143',
        '94101',
        '94153',
        '94154',
        '94156',
        '94162',
        '94171',
        '94199',
        '94016',
        '94106',
        '94119',
        '94120',
        '94125',
        '94126',
        '94130',
        '94135',
        '94137',
        '94136',
        '94139',
        '94138',
        '94141',
        '94140',
        '94142',
        '94145',
        '94144',
        '94147',
        '94146',
        '94151',
        '94150',
        '94152',
        '94155',
        '94157',
        '94159',
        '94161',
        '94160',
        '94163',
        '94165',
        '94164',
        '94167',
        '94166',
        '94169',
        '94168',
        '94170',
        '94175',
        '94172',
        '94188',
        '94177',
        '415', 
        '209', 
        '408', 
        '559', 
        '831', 
        '510', 
        '925', 
        '650']

# %%
for intro in intros:
    for POI in POIs:
        for AOI in AOIs:
            print(f'{intro} {POI} in {AOI}')
# Out:
# Get all the coffee shops in California
# Get all the coffee shops in Iowa
# Get all the coffee shops in Los Angeles
# Get all the coffee shops in San Diego
# Get all the coffee shops in San Jose
# Get all the coffee shops in San Francisco
# Get all the coffee shops in Fresno
# Get all the coffee shops in Sacramento
# Get all the coffee shops in Long Beach
# Get all the coffee shops in Oakland
# Get all the coffee shops in Bakersfield
# Get all the coffee shops in Anaheim
# Get all the coffee shops in 94112
# Get all the coffee shops in 94110
# Get all the coffee shops in 94122
# Get all the coffee shops in 94109
# Get all the coffee shops in 94116
# Get all the coffee shops in 94118
# Get all the coffee shops in 94117
# Get all the coffee shops in 94121
# Get all the coffee shops in 94134
# Get all the coffee shops in 94124
# Get all the coffee shops in 94114
# Get all the coffee shops in 94115
# Get all the coffee shops in 94102
# Get all the coffee shops in 94132
# ...
