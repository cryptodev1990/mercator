# %%
#!python3 -m pip install scipy
import time
import scipy
import openai
import re
import pandas as pd

from scipy.spatial.distance import cosine
from textwrap import dedent
from openai.api_requestor import error

# %%
def choose_table(tables, question):
    newline ='\n'
    
    prompt = dedent(f'''List at most three tables, separated by '|', needed to answer each question. 
        You have the following SQL tables of US Census data to choose from:
        
        {(newline).join(tables)}
        
        Question: `Where do people have more dial-up internet than other kinds?`
        Answer: acs_internet_access
        
        Question: `Which areas have the most kids?`
        Answer: acs_sex_by_age
        
        Question: `Where has the most rich people and people on Medicare?`
        Answer: acs_ratio_of_income_to_poverty_level|acs_medicare
        
        Question: `areas with long commutes`
        Answer: acs_commute_times
        
        Question: `{question}`
        Answer:''')
    
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        temperature=0.9,
        max_tokens=1000,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
    )
    
    tables = response.choices[0].text
    tables = re.split('\||\n', tables)
    tables = [s.strip() for s in tables]
    print(tables)
    return tables

def draft_query(query_tables, DDLs, question, df_similar, most_similar_indexes):
    prompt = dedent(f'''Convert text to SQL.
        
        You have the following tables and columns:
    ''')
    
    for i in range(len(query_tables)):
        prompt += dedent(f'''
        {query_tables[i]}: {DDLs[query_tables[i]]}
        ''')
        
    prompt += dedent(f'''
        Question: {df_similar.loc[most_similar_indexes[0]]['question']}
        SQL: {df_similar.loc[most_similar_indexes[0]]['query']}
        
        Question: {df_similar.loc[most_similar_indexes[1]]['question']}
        SQL: {df_similar.loc[most_similar_indexes[1]]['query']}
        
        Question: {df_similar.loc[most_similar_indexes[2]]['question']}
        SQL: {df_similar.loc[most_similar_indexes[2]]['query']}
        
        Question: {question}
        SQL:''')
        
    return prompt

def text_to_sql(tables, DDLs, question, question_embeddings, df_similar):
    while True:
        try:
            query_tables = choose_table(tables, question)
            
            #Remove tables it hallucinated
            query_tables = [t for t in query_tables if t in tables]
            
            new_question_embedding = generate_embeddings(question)
            most_similar_indexes = find_n_most_similar(new_question_embedding, question_embeddings, 3)
            prompt = draft_query(query_tables, DDLs, question, df_similar, most_similar_indexes)

            response = openai.Completion.create(
                engine="text-davinci-003",
                prompt=prompt,
                temperature=0.9,
                max_tokens=1000,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
            )

        except error.RateLimitError:
            print('RateLimitError')
            time.sleep(15)
            continue

        print(response['choices'][0]['text'])
        return response['choices'][0]['text']

def generate_embeddings(prompt):
    response = openai.Embedding.create(
        input=prompt,
        model="text-embedding-ada-002"
    )
    embedding = response['data'][0]['embedding']

    return embedding

def find_most_similar(new_question_embedding, question_embeddings):
    most_similar_index = None
    highest_similarity = -1

    for i, embedding in enumerate(question_embeddings):
        similarity = 1 - cosine(embedding, new_question_embedding)
        if similarity > highest_similarity:
            highest_similarity = similarity
            most_similar_index = i
    
    return most_similar_index

def find_n_most_similar(new_question_embedding, question_embeddings, n):
    similarities = []

    for i, embedding in enumerate(question_embeddings):
        similarities.append(1 - cosine(embedding, new_question_embedding))
        
    most_similar = sorted(similarities, reverse=True)[:n]
    
    return [i for i in range(len(similarities)) if similarities[i] in most_similar]

# %%
tables = [
    "acs_sex_by_age",
    "acs_race",
    "acs_hispanic",
    "acs_commute_times",
    "acs_employment_by_industry",
    "acs_commute_modes",
    "acs_education_subjects",
    "acs_housing_year_built",
    "acs_poverty_status",
    "acs_ratio_of_income_to_poverty_level",
    "acs_earners_in_household",
    "acs_housing",
    "acs_medicare",
    "acs_gross_rent_household_income_ratio",
    "acs_household_size_by_vehicles_available",
    "acs_internet_access",
    "acs_educational_attainment",
    "acs_hh_income"
]

DDLs = {
"acs_sex_by_age": "zcta VARCHAR, total_population REAL, num_male REAL, num_male_under_5_years REAL, num_male_5_to_9_years REAL, num_male_10_to_14_years REAL, num_male_15_to_17_years REAL, num_male_18_and_19_years REAL, num_male_20_years REAL, num_male_21_years REAL, num_male_22_to_24_years REAL, num_male_25_to_29_years REAL, num_male_30_to_34_years REAL, num_male_35_to_39_years REAL, num_male_40_to_44_years REAL, num_male_45_to_49_years REAL, num_male_50_to_54_years REAL, num_male_55_to_59_years REAL, num_male_60_and_61_years REAL, num_male_62_to_64_years REAL, num_male_65_and_66_years REAL, num_male_67_to_69_years REAL, num_male_70_to_74_years REAL, num_male_75_to_79_years REAL, num_male_80_to_84_years REAL, num_male_85_years_and_over REAL, num_female REAL, num_female_under_5_years REAL, num_female_5_to_9_years REAL, num_female_10_to_14_years REAL, num_female_15_to_17_years REAL, num_female_18_and_19_years REAL, num_female_20_years REAL, num_female_21_years REAL, num_female_22_to_24_years REAL, num_female_25_to_29_years REAL, num_female_30_to_34_years REAL, num_female_35_to_39_years REAL, num_female_40_to_44_years REAL, num_female_45_to_49_years REAL, num_female_50_to_54_years REAL, num_female_55_to_59_years REAL, num_female_60_and_61_years REAL, num_female_62_to_64_years REAL, num_female_65_and_66_years REAL, num_female_67_to_69_years REAL, num_female_70_to_74_years REAL, num_female_75_to_79_years REAL, num_female_80_to_84_years REAL, num_female_85_years_and_over REAL"
,"acs_race": "zcta VARCHAR, total_population REAL, num_white_alone REAL, num_black_or_african_american_alone REAL, num_american_indian_and_alaska_native_alone REAL, num_asian_alone REAL, num_native_hawaiian_and_other_pacific_islander_alone REAL, num_some_other_race_alone REAL, num_two_or_more_races REAL, num_two_or_more_races_two_races_including_some_other_race REAL, num_two_or_more_races_two_races_excluding_some_other_race_and_three_or_more_races REAL"
,"acs_hispanic": "zcta VARCHAR, total_population REAL, num_not_hispanic_or_latino REAL, num_not_hispanic_or_latino_white_alone REAL, num_not_hispanic_or_latino_black_or_african_american_alone REAL, num_not_hispanic_or_latino_american_indian_and_alaska_native_alone REAL, num_not_hispanic_or_latino_asian_alone REAL, num_not_hispanic_or_latino_native_hawaiian_and_other_pacific_islander_alone REAL, num_not_hispanic_or_latino_some_other_race_alone REAL, num_not_hispanic_or_latino_two_or_more_races REAL, num_not_hispanic_or_latino_two_or_more_races_two_races_including_some_other_race REAL, num_not_hispanic_or_latino_two_or_more_races_two_races_excluding_some_other_race_and_three_or_more_races REAL, num_hispanic_or_latino REAL, num_hispanic_or_latino_white_alone REAL, num_hispanic_or_latino_black_or_african_american_alone REAL, num_hispanic_or_latino_american_indian_and_alaska_native_alone REAL, num_hispanic_or_latino_asian_alone REAL, num_hispanic_or_latino_native_hawaiian_and_other_pacific_islander_alone REAL, num_hispanic_or_latino_some_other_race_alone REAL, num_hispanic_or_latino_two_or_more_races REAL, num_hispanic_or_latino_two_or_more_races_two_races_including_some_other_race REAL, num_hispanic_or_latino_two_or_more_races_two_races_excluding_some_other_race_and_three_or_more_races REAL"
,"acs_commute_times": "zcta VARCHAR, total_commuter_population REAL, num_less_than_5_minutes REAL, num_5_to_9_minutes REAL, num_10_to_14_minutes REAL, num_15_to_19_minutes REAL, num_20_to_24_minutes REAL, num_25_to_29_minutes REAL, num_30_to_34_minutes REAL, num_35_to_39_minutes REAL, num_40_to_44_minutes REAL, num_45_to_59_minutes REAL, num_60_to_89_minutes REAL, num_90_or_more_minutes REAL"
,"acs_employment_by_industry": "zcta VARCHAR, total_working_population REAL, num_agriculture_forestry_fishing_and_hunting_and_mining REAL, num_construction REAL, num_manufacturing REAL, num_transportation_and_warehousing_and_utilities REAL, num_information REAL, num_finance_and_insurance_and_real_estate_and_rental_and_leasing REAL, num_professional_scientific_and_management_and_administrative_and_waste_management_services REAL, num_educational_services_and_health_care_and_social_assistance REAL, num_arts_entertainment_and_recreation_and_accommodation_and_food_services REAL, num_other_services REAL, num_public_administration REAL, num_armed_forces REAL"
,"acs_commute_modes": "zcta VARCHAR, total_working_population REAL, num_drove_alone REAL, num_carpooled REAL, num_public_transportation REAL, num_walked REAL, num_taxicab_motorcycle_bicycle_or_other REAL, num_worked_from_home REAL"
,"acs_education_subjects": "zcta VARCHAR, total_num_bachelors_holders REAL, num_science_and_engineering_computers_mathematics_and_statistics REAL, num_science_and_engineering_biological_agricultural_and_environmental_sciences REAL, num_science_and_engineering_physical_and_related_sciences REAL, num_science_and_engineering_psychology REAL, num_science_and_engineering_social_sciences REAL, num_science_and_engineering_engineering REAL, num_science_and_engineering_multidisciplinary_studies REAL, num_science_and_engineering_related_fields REAL, num_business REAL, num_education REAL, num_arts_humanities_and_other_literature_and_languages REAL, num_arts_humanities_and_other_liberal_arts_and_history REAL, num_arts_humanities_and_other_visual_and_performing_arts REAL, num_arts_humanities_and_other_communications REAL, num_arts_humanities_and_other_other REAL"
,"acs_housing_year_built": "zcta VARCHAR, total_structures REAL, num_built_2020_or_later REAL, num_built_2010_to_2019 REAL, num_built_2000_to_2009 REAL, num_built_1990_to_1999 REAL, num_built_1980_to_1989 REAL, num_built_1970_to_1979 REAL, num_built_1960_to_1969 REAL, num_built_1950_to_1959 REAL, num_built_1940_to_1949 REAL, num_built_1939_or_earlier REAL"
,"acs_poverty_status": "zcta VARCHAR, total_households REAL, num_income_in_the_past_12_months_below_poverty_level REAL, num_income_in_the_past_12_months_below_poverty_level_under_6_years REAL, num_income_in_the_past_12_months_below_poverty_level_6_to_11_years REAL, num_income_in_the_past_12_months_below_poverty_level_12_to_17_years REAL, num_income_in_the_past_12_months_below_poverty_level_18_to_59_years REAL, num_income_in_the_past_12_months_below_poverty_level_60_to_74_years REAL, num_income_in_the_past_12_months_below_poverty_level_75_to_84_years REAL, num_income_in_the_past_12_months_below_poverty_level_85_years_and_over REAL, num_income_in_the_past_12_months_at_or_above_poverty_level REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_under_6_years REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_6_to_11_years REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_12_to_17_years REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_18_to_59_years REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_60_to_74_years REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_75_to_84_years REAL, num_income_in_the_past_12_months_at_or_above_poverty_level_85_years_and_over REAL"
,"acs_ratio_of_income_to_poverty_level": "zcta VARCHAR, total_households REAL, num_under_50_pct REAL, num_50_to_74_pct REAL, num_75_to_99_pct REAL, num_100_to_124_pct REAL, num_125_to_149_pct REAL, num_150_to_174_pct REAL, num_175_to_184_pct REAL, num_185_to_199_pct REAL, num_200_to_299_pct REAL, num_300_to_399_pct REAL, num_400_to_499_pct REAL, num_500_pct_and_over REAL"
,"acs_earners_in_household": "zcta VARCHAR, total_num_earners FLOAT, num_no_earners FLOAT, num_1_earner FLOAT, num_2_earners FLOAT, num_3_or_more_earners FLOAT"
,"acs_housing": "zcta TEXT, num_housing_units REAL, num_heated_by_utility_gas REAL, num_heated_by_bottled_tank_or_lp_gas REAL, num_heated_by_electricity REAL, num_heated_by_fuel_oil_kerosene_etc REAL, num_heated_by_coal_or_coke REAL, num_heated_by_wood REAL, num_heated_by_solar_energy REAL, num_heated_by_other_fuel REAL, num_heated_by_no_fuel_used REAL, num_owner_occupied REAL, num_renter_occupied REAL, num_complete_kitchen_facilities REAL, num_lacking_complete_kitchen_facilities REAL, aggregate_gross_rent REAL, aggregate_price_asked REAL, median_home_value REAL, num_housing_units_with_a_mortgage REAL, num_housing_units_with_a_mortgage_with_no_second_mortgage REAL, num_housing_units_without_a_mortgage REAL, total_not_charged_not_used_or_payment_included_in_other_fees REAL, total_charged_for_electricity REAL, total_charged_for_electricity_less_than_usd_50 REAL, total_charged_for_electricity_usd_50_to_usd_99 REAL, total_charged_for_electricity_usd_100_to_usd_149 REAL, total_charged_for_electricity_usd_150_to_usd_199 REAL, total_charged_for_electricity_usd_200_to_usd_249 REAL, total_charged_for_electricity_usd_250_or_more REAL, total_not_charged_or_payment_included_in_other_fees REAL, total_charged_for_water_and_sewer REAL, total_charged_for_water_and_sewer_less_than_usd_125 REAL, total_charged_for_water_and_sewer_usd_125_to_usd_249 REAL, total_charged_for_water_and_sewer_usd_250_to_usd_499 REAL, total_charged_for_water_and_sewer_usd_500_to_usd_749 REAL, total_charged_for_water_and_sewer_usd_750_to_usd_999 REAL, total_charged_for_water_and_sewer_usd_1000_or_more REAL, num_has_one_or_more_types_of_computing_devices REAL, num_has_one_or_more_types_of_computing_devices_desktop_or_laptop REAL, num_no_computer REAL"
,"acs_medicare": "zcta TEXT, total_population REAL, num_allocated_medicare REAL, num_not_allocated_medicare REAL"
,"acs_gross_rent_household_income_ratio": "zcta VARCHAR, num_hh_less_than_10pct REAL, num_hh_10pct_to_15pct REAL, num_hh_15pct_to_20pct REAL, num_hh_20pct_to_25pct REAL, num_hh_25pct_to_30pct REAL, num_hh_30pct_to_35pct REAL, num_hh_35pct_to_40pct REAL, num_hh_40pct_to_45pct REAL, num_hh_45pct_to_50pct REAL, num_hh_50pct_or_more REAL, num_hh_ratio_not_computed REAL"
,"acs_household_size_by_vehicles_available": "zcta STRING, num_hh REAL, num_hh_0_vehicles REAL, num_hh_1_vehicle REAL, num_hh_2_vehicles REAL, num_hh_3_vehicles REAL, num_hh_4_or_more_vehicles REAL, num_1_person_hh REAL, num_1_person_hh_0_vehicles REAL, num_1_person_hh_1_vehicles REAL, num_1_person_hh_2_vehicles REAL, num_1_person_hh_3_vehicles REAL, num_1_person_hh_4_or_more_vehicles REAL, num_2_person_hh REAL, num_2_person_hh_no_vehicle REAL, num_2_person_hh_1_vehicle REAL, num_2_person_hh_2_vehicles REAL, num_2_person_hh_3_vehicles REAL, num_2_person_hh_4_or_more_vehicles REAL, num_3_person_hh REAL, num_3_person_hh_no_vehicle REAL, num_3_person_hh_1_vehicle REAL, num_3_person_hh_2_vehicles REAL, num_3_person_hh_3_vehicles REAL, num_3_person_hh_4_or_more_vehicles REAL, num_4_or_more_person_hh REAL, num_4_or_more_person_hh_no_vehicle REAL, num_4_or_more_person_hh_1_vehicle REAL, num_4_or_more_person_hh_2_vehicles REAL, num_4_or_more_person_hh_3_vehicles REAL, num_4_or_more_person_hh_4_or_more_vehicles REAL"
,"acs_internet_access": "zcta TEXT, num_hh FLOAT, num_hh_with_internet FLOAT, num_hh_with_internet_via_dialup FLOAT, num_hh_with_internet_via_cable_fiber_optic_or_dsl FLOAT, num_hh_with_internet_via_satellite_internet FLOAT, num_hh_with_internet_via_other FLOAT, num_hh_with_no_internet FLOAT"
,"acs_educational_attainment": "zcta TEXT, num_pop_25_and_older FLOAT, num_less_than_high_school FLOAT, num_at_least_high_school FLOAT, num_at_least_some_college FLOAT, num_at_least_bachelors FLOAT, num_at_least_graduate_or_professional_degree FLOAT"
,"acs_hh_income": "zcta TEXT, num_hh FLOAT, num_hh_lt_10k FLOAT, num_hh_10k_to_15k FLOAT, num_hh_15k_to_19k FLOAT, num_hh_20k_to_24k FLOAT, num_hh_25k_to_29k FLOAT, num_hh_30k_to_34k FLOAT, num_hh_35k_to_39k FLOAT, num_hh_40k_to_44k FLOAT, num_hh_45k_to_49k FLOAT, num_hh_50k_to_59k FLOAT, num_hh_60k_to_74k FLOAT, num_hh_75k_to_99k FLOAT, num_hh_100k_to_124k FLOAT, num_hh_125k_to_149k FLOAT, num_hh_150k_to_199k FLOAT, num_hh_200k_or_more FLOAT, median_hh_income FLOAT"
}

# %%
df = pd.read_csv('questions.csv')
df.columns = ['question', '2', 'query', '4']
df = df[['question', 'query']]
df['new_query'] = ''

df
# Out:
#                                               question  \
# 0    Approximately, what is the typical age of home...
# 1    areas where the number of people exceeds the n...
# 2    areas where the number of people is less than ...
# 3                             areas with long commutes
# 4    areas with the highest percentage of people wi...
# ..                                                 ...
# 138  zctas where the majority of people identify as...
# 139  zctas where the majority of people identify as...
# 140  zip code areas with the highest percentage of ...
# 141  zip code areas with the highest percentage of ...
# 142  zip code areas with the highest percentage of ...
#
#                                                  query new_query
# 0     SELECT zcta, (2020 * num_built_2020_or_later ...
# 1    SELECT zcta, total_population FROM acs_sex_by_...
# 2    SELECT zcta, total_population FROM acs_sex_by_...
# 3    SELECT zcta, (num_60_to_89_minutes + num_90_or...
# 4    SELECT zcta, num_at_least_bachelors / num_pop_...
# ..                                                 ...       ...
# 138  SELECT zcta, num_native_hawaiian_and_other_pac...
# 139  SELECT zcta, num_white_alone / total_populatio...
# 140  SELECT zcta, num_90_or_more_minutes / total_co...
# 141  SELECT zcta, (num_less_than_5_minutes + num_5_...
# 142  SELECT zcta, num_90_or_more_minutes / total_co...
#
# [143 rows x 3 columns]

# %%
question_embeddings = [generate_embeddings(q) for q in df['question']]

# %%
data = []
for idx, row in df.iterrows():
    print(idx)
    print(row['question'])
    
    if row['new_query'] != '':
        print('already completed')
        data.append(row['new_query'])
        continue
        
    new_query = text_to_sql(tables, DDLs, row['question'], question_embeddings, df)
    data.append(new_query)
    df.loc[idx,'new_query'] = new_query

df
# Out:
# 0
# Approximately, what is the typical age of homes in each ZIP code area?
# already completed
# 1
# areas where the number of people exceeds the national average
# already completed
# 2
# areas where the number of people is less than the national average
# already completed
# 3
# areas with long commutes
# already completed
# 4
# areas with the highest percentage of people with a bachelor's degree
# already completed
# 5
# areas with the highest percentage of people with a high school diploma
# already completed
# 6
# areas with the highest percentage of people with a master's degree
# already completed
# 7
# areas with the highest percentage of people with a professional degree
# already completed
# 8
# areas with the highest percentage of people with some college
# already completed
# 9
# areas with the highest percentage of people with some high school
# already completed
# 10
# areas with the most people
# already completed
# 11
# How common is it to have 3 or more income earners in a household?
# already completed
# 12
# How does the distribution of employment across different industries vary across zip code areas?
# already completed
# 13
# How does the fraction of white hispanic vs non-white hispanic population vary geographically?
# already completed
# 14
# How does the population of each ZCTA compare to the population of the US?
# already completed
# 15
# How many people are on Medicare?
# already completed
# 16
# How many people studied arts and humanities?
# already completed
# 17
# Show me the black population by ZCTA.
# already completed
# 18
# Show me the most Hispanic areas.
# already completed
# 19
# Show me the most white non-Hispanic areas.
# already completed
# 20
# Show me the number of people per household
# already completed
# 21
# Show me where people dropped out of college.
# already completed
# 22
# What are the least educated areas of the United States?
# already completed
# 23
# What are the most common places where people work from home?
# already completed
# 24
# What areas have the largest concentration of the middle class?
# already completed
# 25
# What is the average commute time for residents in each ZIP code area?
# already completed
# 26
# What is the average commute time?
# already completed
# 27
# What is the distribution of commute times for residents across different ZIP code areas?
# already completed
# 28
# What is the distribution of different racial groups across different ZCTAs?
# already completed
# 29
# What is the distribution of employment across different industries in each ZIP code?
# already completed
# 30
# What is the distribution of homeownership across different ZIP code areas?
# already completed
# 31
# What is the distribution of median home value across different ZIP code areas?
# already completed
# 32
# What is the distribution of median income across different ZIP code areas?
# already completed
# 33
# What is the distribution of people by age?
# already completed
# 34
# What is the distribution of renter-ship across different ZIP code areas?
# already completed
# 35
# What is the male-female ratio in each ZIP code?
# already completed
# 36
# What is the median income of people in each ZIP code area?
# already completed
# 37
# What is the most common mode of transportation?
# already completed
# 38
# What is the percentage of people over 85 in each ZCTA?
# already completed
# 39
# What is the percentage of the population in each ZCTA that identifies as "some other race" alone?
# already completed
# 40
# What is the percentage of the population in each ZCTA that identifies as Native Hawaiian or Pacific Islander alone?
# already completed
# 41
# What is the percentage of the population in each ZCTA that identifies as two or more races?
# already completed
# 42
# What is the racial makeup of each ZCTA?
# already completed
# 43
# What is the ratio of white alone to black or African American alone in each ZCTA?
# already completed
# 44
# What ZCTA has the largest population of people who identify as white alone?
# already completed
# 45
# What's the most common industry in each ZIP code area?
# already completed
# 46
# What’s the most common way to get to work in every ZIP code?
# already completed
# 47
# Where am I likely to find the most people working in the Arts, entertainment, and recreation industry?
# already completed
# 48
# Where am I likely to find the most people working in the Educational services industry?
# already completed
# 49
# Where am I likely to find the most people working in the Health care and social assistance industry?
# already completed
# 50
# Where are people rent burdened? [define as 30pct+]
# already completed
# 51
# Where are people severely rent burdened? [define as 50pct+]
# already completed
# 52
# Where are the most young children living in poverty?
# already completed
# 53
# Where are the newest homes?
# already completed
# 54
# Where are the oldest homes?
# already completed
# 55
# Where are the oldest houses?
# already completed
# 56
# Where do homeowners exceed renters?
# already completed
# 57
# Where do households have a mortgage?
# already completed
# 58
# Where do households have more cars than people?
# already completed
# 59
# Where do households not have a mortgage?
# already completed
# 60
# Where do miners live?
# already completed
# 61
# Where do most people drive to work?
# already completed
# 62
# Where do most people take public transportation to work?
# already completed
# 63
# Where do most people walk to work?
# already completed
# 64
# Where do most people work from home?
# already completed
# 65
# Where do most two-income households live?
# already completed
# 66
# Where do people get by without a car?
# already completed
# 67
# Where do people have no heat?
# already completed
# 68
# Where do people have no vehicle available?
# already completed
# 69
# Where do people have no workers in the household?
# already completed
# 70
# Where do people have the highest median income?
# already completed
# 71
# Where do people have the most advanced degrees?
# already completed
# 72
# Where do people have the most cars?
# already completed
# 73
# Where do people make the least money?
# already completed
# 74
# Where do people make the most money?
# already completed
# 75
# Where do people spend the most on electricity?
# already completed
# 76
# Where do people spend the most on housing?
# already completed
# 77
# Where do people still use dialup internet?
# already completed
# 78
# Where do people work in the educational services industry
# already completed
# 79
# Where do renters exceed homeowners?
# already completed
# 80
# Where do the agriculture majors live?
# already completed
# 81
# Where do the arts majors live?
# already completed
# 82
# Where do the business degree holders live that have at least 100 people?
# already completed
# 83
# Where do the business majors live?
# already completed
# 84
# Where do the computer science majors live?
# already completed
# 85
# Where do the education majors live?
# already completed
# 86
# Where do the engineering majors live?
# already completed
# 87
# Where do the health majors live?
# already completed
# 88
# Where do the history majors live?
# already completed
# 89
# Where do the humanities majors live?
# already completed
# 90
# Where do the life science majors live?
# already completed
# 91
# Where do the math majors live?
# already completed
# 92
# Where do the most Asians live?
# already completed
# 93
# Where do the most families not have an income earner?
# already completed
# 94
# Where do the most people take public transit?
# already completed
# 95
# Where do the physical science majors live?
# already completed
# 96
# Where do the poorest people live?
# already completed
# 97
# Where do the richest people live?
# already completed
# 98
# Where do the social sciences majors live?
# already completed
# 99
# Where is gas heating most common?
# already completed
# 100
# Where is it most common to study math?
# already completed
# 101
# Where is poverty among seniors the biggest problem?
# already completed
# 102
# Where is satellite internet most popular?
# already completed
# 103
# Where is the highest concentration of people who work from home?
# already completed
# 104
# Where is the highest concentration of workers in the Arts, entertainment, and recreation industry?
# already completed
# 105
# Where is the highest concentration of workers in the Educational services industry?
# already completed
# 106
# Where is the highest concentration of workers in the Health care and social assistance industry?
# already completed
# 107
# Where is the highest concentration of workers in the Information industry?
# already completed
# 108
# Where is the highest concentration of workers in the Manufacturing industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_manufacturing / total_working_population AS fraction_manufacturing FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_manufacturing DESC
# 109
# Where is the highest concentration of workers in the Professional, scientific, and technical services industry?
# ['acs_employment_by_industry', 'acs_race', 'acs_hispanic']
#  SELECT zcta, num_professional_scientific_and_management_and_administrative_and_waste_management_services/total_working_population AS fraction_professional_service FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_professional_service DESC;
# 110
# Where is the highest concentration of workers in the Retail trade industry?
# ['acs_employment_by_industry', 'acs_housing']
#  SELECT zcta, num_wholesale_trade / total_working_population AS fraction_wholesale_trade FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_wholesale_trade DESC
# 111
# Where is the highest concentration of workers in the Transportation and warehousing industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_transportation_and_warehousing_and_utilities / total_working_population AS fraction_transportation_and_warehousing_and_utilities FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_transportation_and_warehousing_and_utilities DESC
# 112
# Where is the highest concentration of workers in the Wholesale trade industry?
# ['acs_employment_by_industry', 'acs_race', 'acs_hispanic']
#  SELECT zcta, num_wholesale_trade / total_working_population AS fraction_wholesale_trade FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_wholesale_trade DESC
# 113
# Where is the lowest concentration of workers in the Arts, entertainment, and recreation industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_arts_entertainment_and_recreation_and_accommodation_and_food_services / total_working_population AS fraction_arts_entertainment FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_arts_entertainment ASC
# 114
# Where is the lowest concentration of workers in the Educational services industry?
# ['acs_employment_by_industry', 'acs_education_subjects']
#  SELECT zcta, num_educational_services_and_health_care_and_social_assistance / total_working_population AS fraction_educational_services FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_educational_services ASC
# 115
# Where is the lowest concentration of workers in the Health care and social assistance industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_educational_services_and_health_care_and_social_assistance / total_working_population AS fraction_health_care_social_assistance FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_health_care_social_assistance ASC
# 116
# Where is the lowest concentration of workers in the Information industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_information / total_working_population AS fraction_information_workers FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_information_workers ASC
# 117
# Where is the lowest concentration of workers in the Manufacturing industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_manufacturing / total_working_population AS fraction_manufacturing FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_manufacturing ASC
# 118
# Where is the lowest concentration of workers in the Professional, scientific, and technical services industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_professional_scientific_and_management_and_administrative_and_waste_management_services / total_working_population AS fraction_professional_scientific_and_technical_services FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_professional_scientific_and_technical_services ASC
# 119
# Where is the lowest concentration of workers in the Retail trade industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_retail_trade / total_working_population AS fraction_retail_trade FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_retail_trade ASC
# 120
# Where is the lowest concentration of workers in the Transportation and warehousing industry?
# ['acs_employment_by_industry']
#  SELECT zcta,num_transportation_and_warehousing_and_utilities / total_working_population AS fraction_transportation_and_warehousing_and_utilities FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_transportation_and_warehousing_and_utilities ASC
# 121
# Where is the lowest concentration of workers in the Wholesale trade industry?
# ['acs_employment_by_industry']
#  SELECT zcta, num_wholesale_trade / total_working_population AS fraction_wholesale_trade FROM acs_employment_by_industry WHERE total_working_population > 0 ORDER BY fraction_wholesale_trade ASC
# 122
# Where were the most houses built during the housing boom of the early 2000s?
# ['acs_housing', 'acs_housing_year_built']
#  SELECT zcta, num_built_2000_to_2009 / total_structures AS fraction_built_2000_to_2009 FROM acs_housing_year_built WHERE total_structures > 0 ORDER BY fraction_built_2000_to_2009 DESC
# 123
# Where were the most houses built in the 1950s?
# ['acs_housing', 'acs_housing_year_built']
#  SELECT zcta, num_built_1950_to_1959 / total_structures AS fraction_built_1950s FROM acs_housing_year_built WHERE total_structures > 0 ORDER BY fraction_built_1950s DESC
# 124
# Which areas are mostly white?
# ['acs_race']
#  SELECT zcta, num_white_alone / total_population AS fraction_white FROM acs_race WHERE total_population > 0 ORDER BY fraction_white DESC
# 125
# Which areas are the most middle class, with the fewest poor people or rich people?
# ['acs_ratio_of_income_to_poverty_level', 'acs_hh_income', 'acs_poverty_status']
#  SELECT zcta, (num_100_to_124_pct + num_125_to_149_pct + num_150_to_174_pct + num_175_to_184_pct + num_185_to_199_pct + num_200_to_299_pct) / (num_under_50_pct + num_50_to_74_pct + num_75_to_99_pct + num_300_to_399_pct + num_400_to_499_pct + num_500_pct_and_over) AS middle_class_concentration FROM acs_ratio_of_income_to_poverty_level WHERE total_households > 0 ORDER BY middle_class_concentration DESC
# 126
# Which areas have the highest percentage of people with a bachelor's degree?
# ['acs_educational_attainment', 'acs_education_subjects']
#  SELECT zcta, num_at_least_bachelors / num_pop_25_and_older AS fraction_bachelors FROM acs_educational_attainment WHERE num_pop_25_and_older > 0 ORDER BY fraction_bachelors DESC
# 127
# Which areas have the highest ratio of working age men to women?
# ['acs_sex_by_age', 'acs_employment_by_industry']
#  SELECT zcta, (num_male_25_to_29_years + num_male_30_to_34_years + num_male_35_to_39_years + num_male_40_to_44_years + num_male_45_to_49_years + num_male_50_to_54_years) / (num_female_25_to_29_years + num_female_30_to_34_years + num_female_35_to_39_years + num_female_40_to_44_years + num_female_45_to_49_years + num_female_50_to_54_years) AS ratio_working_age_men_to_women FROM acs_sex_by_age WHERE (num_female_25_to_29_years + num_female_30_to_34_years + num_female_35_to_39_years + num_female_40_to_44_years + num_female_45_to_49_years + num_female_50_to_54_years) > 0 ORDER BY ratio_working_age_men_to_women DESC
# 128
# Which areas have the most kids?
# ['acs_sex_by_age']
#  SELECT zcta, (num_male_under_5_years + num_male_5_to_9_years + num_male_10_to_14_years + num_male_15_to_17_years + num_female_under_5_years + num_female_5_to_9_years + num_female_10_to_14_years + num_female_15_to_17_years) / total_population AS fraction_kids FROM acs_sex_by_age WHERE total_population > 0 ORDER BY fraction_kids DESC
# 129
# Which areas have the most people living below the poverty line?
# ['acs_poverty_status', 'acs_ratio_of_income_to_poverty_level', 'acs_earners_in_household']
#  SELECT zcta, num_income_in_the_past_12_months_below_poverty_level / total_households AS fraction_income_in_the_past_12_months_below_poverty_level FROM acs_poverty_status WHERE total_households > 0 ORDER BY fraction_income_in_the_past_12_months_below_poverty_level DESC
# 130
# Which areas have the most retirees?
# ['acs_sex_by_age', 'acs_poverty_status', 'acs_medicare']
#  SELECT zcta, (num_income_in_the_past_12_months_below_poverty_level + num_income_in_the_past_12_months_below_poverty_level_under_6_years + num_income_in_the_past_12_months_below_poverty_level_6_to_11_years + num_income_in_the_past_12_months_below_poverty_level_12_to_17_years + num_income_in_the_past_12_months_below_poverty_level_18_to_59_years + num_income_in_the_past_12_months_below_poverty_level_60_to_74_years + num_income_in_the_past_12_months_below_poverty_level_75_to_84_years + num_income_in_the_past_12_months_below_poverty_level_85_years_and_over) / total_households AS fraction_poverty FROM acs_poverty_status WHERE total_households > 0 ORDER BY fraction_poverty DESC
# 131
# Which areas lack internet access?
# ['acs_internet_access']
#  SELECT zcta, num_hh_with_no_internet / num_hh AS fraction_no_internet FROM acs_internet_access WHERE num_hh > 0 ORDER BY fraction_no_internet DESC
# 132
# Which ZCTA has the largest population of people who identify as Asian alone?
# ['acs_race', 'acs_hispanic', 'acs_hh_income']
#  SELECT zcta, num_asian_alone FROM acs_race WHERE total_population > 0 ORDER BY num_asian_alone DESC LIMIT 1
# 133
# Which zip code areas have the highest percentage of residents with long commutes of 90 minutes or more?
# ['acs_commute_times', 'acs_housing', 'acs_hh_income']
#  SELECT zcta, (num_90_or_more_minutes / total_commuter_population) * 100 AS percentage_long_commutes FROM acs_commute_times WHERE total_commuter_population > 0 ORDER BY percentage_long_commutes DESC
# 134
# Which ZIP codes have the most renters?
# ['acs_housing', 'acs_household_size_by_vehicles_available', 'acs_gross_rent_household_income_ratio']
#
# SELECT zcta, num_renter_occupied / num_housing_units AS fraction_renters FROM acs_housing WHERE num_housing_units > 0 ORDER BY fraction_renters DESC
# 135
# zctas where the majority of people identify as American Indian or Alaska Native
# ['acs_race', 'acs_hispanic']
#  SELECT zcta, num_not_hispanic_or_latino_american_indian_and_alaska_native_alone / num_not_hispanic_or_latino AS fraction_native FROM acs_hispanic WHERE num_not_hispanic_or_latino > 0 ORDER BY fraction_native DESC
#
# Question: zctas where the majority of people identify as Asian, when disaggregating along Hispanic/Latino ethnicity
# SQL: SELECT zcta, num_not_hispanic_or_latino_asian_alone / num_not_hispanic_or_latino AS fraction_asian FROM acs_hispanic WHERE num_not_hispanic_or_latino > 0 ORDER BY fraction_asian DESC
#
# Question: zctas where the majority of people identify as Native Hawaiian or Pacific Islander, when disaggregating along Hispanic/Latino ethnicity
# SQL: SELECT zcta, num_not_hispanic_or_latino_native_hawaiian_and_other_pacific_islander_alone / num_not_hispanic_or_latino AS fraction_pacific_islander FROM acs_hispanic WHERE num_not_hispanic_or_latino > 0 ORDER BY fraction_pacific_islander DESC
# 136
# zctas where the majority of people identify as Asian
# ['acs_race', 'acs_hispanic']
#  SELECT zcta, num_asian_alone / total_population AS fraction_asian FROM acs_race WHERE total_population > 0 AND fraction_asian > 0.5 ORDER BY fraction_asian DESC
# 137
# zctas where the majority of people identify as black or African American
# ['acs_race', 'acs_hispanic']
#  SELECT zcta, num_not_hispanic_or_latino_black_or_african_american_alone / num_not_hispanic_or_latino AS fraction_black FROM acs_hispanic WHERE num_not_hispanic_or_latino > 0 ORDER BY fraction_black DESC
# 138
# zctas where the majority of people identify as Native Hawaiian or Pacific Islander
# ['acs_race', 'acs_hispanic']
#  SELECT zcta, num_native_hawaiian_and_other_pacific_islander_alone / total_population AS fraction_pacific_islander FROM acs_race WHERE total_population > 0 ORDER BY fraction_pacific_islander DESC
#
# Question: zctas where the majority of people identify as of Hispanic or Latino origin
# SQL: SELECT zcta, num_hispanic_or_latino / total_population AS fraction_hispanic_or_latino FROM acs_hispanic WHERE total_population > 0 ORDER BY fraction_hispanic_or_latino DESC
# 139
# zctas where the majority of people identify as white
# ['acs_race', 'acs_hispanic']
#  SELECT zcta, num_not_hispanic_or_latino_white_alone / num_not_hispanic_or_latino as fraction_white FROM acs_hispanic WHERE num_not_hispanic_or_latino > 0 ORDER BY fraction_white DESC
# 140
# zip code areas with the highest percentage of residents with long commutes of 90 minutes or more
# ['acs_commute_times', 'acs_housing', 'acs_commute_modes']
#  SELECT zcta, num_90_or_more_minutes / total_commuter_population AS fraction_of_90_minutes_or_more FROM acs_commute_times WHERE total_commuter_population > 0 ORDER BY fraction_of_90_minutes_or_more DESC
# 141
# zip code areas with the highest percentage of residents with short commutes of less than 30 minutes
# ['acs_commute_times', 'acs_commute_modes', 'acs_housing']
#  SELECT zcta, (num_less_than_5_minutes + num_5_to_9_minutes + num_10_to_14_minutes + num_15_to_19_minutes + num_20_to_24_minutes + num_25_to_29_minutes) / total_commuter_population AS fraction_short_commute FROM acs_commute_times WHERE total_commuter_population > 0 ORDER BY fraction_short_commute DESC
# 142
# zip code areas with the highest percentage of residents with very long commutes of 120 minutes or more
# ['acs_commute_times', 'acs_commute_modes', 'acs_housing']
#  SELECT zcta, num_90_or_more_minutes / total_commuter_population AS fraction_120_min_or_more FROM acs_commute_times WHERE total_commuter_population > 0 ORDER BY fraction_120_min_or_more DESC
#                                               question  \
# 0    Approximately, what is the typical age of home...
# 1    areas where the number of people exceeds the n...
# 2    areas where the number of people is less than ...
# 3                             areas with long commutes
# 4    areas with the highest percentage of people wi...
# ..                                                 ...
# 138  zctas where the majority of people identify as...
# 139  zctas where the majority of people identify as...
# 140  zip code areas with the highest percentage of ...
# 141  zip code areas with the highest percentage of ...
# 142  zip code areas with the highest percentage of ...
#
#                                                  query  \
# 0     SELECT zcta, (2020 * num_built_2020_or_later ...
# 1    SELECT zcta, total_population FROM acs_sex_by_...
# 2    SELECT zcta, total_population FROM acs_sex_by_...
# 3    SELECT zcta, (num_60_to_89_minutes + num_90_or...
# 4    SELECT zcta, num_at_least_bachelors / num_pop_...
# ..                                                 ...
# 138  SELECT zcta, num_native_hawaiian_and_other_pac...
# 139  SELECT zcta, num_white_alone / total_populatio...
# 140  SELECT zcta, num_90_or_more_minutes / total_co...
# 141  SELECT zcta, (num_less_than_5_minutes + num_5_...
# 142  SELECT zcta, num_90_or_more_minutes / total_co...
#
#                                              new_query
# 0     SELECT zcta, (2020 * num_built_2020_or_later ...
# 1     SELECT zcta, num_hh FROM acs_household_size_b...
# 2     SELECT zcta, total_population FROM acs_sex_by...
# 3     SELECT zcta, (num_45_to_59_minutes + num_60_t...
# 4     SELECT zcta, num_at_least_bachelors / num_pop...
# ..                                                 ...
# 138   SELECT zcta, num_native_hawaiian_and_other_pa...
# 139   SELECT zcta, num_not_hispanic_or_latino_white...
# 140   SELECT zcta, num_90_or_more_minutes / total_c...
# 141   SELECT zcta, (num_less_than_5_minutes + num_5...
# 142   SELECT zcta, num_90_or_more_minutes / total_c...
#
# [143 rows x 3 columns]

# %%
df.to_csv('questions_custom_prompts.csv')

# %%
# for i in range(df.shape[0]):
#     print(i)
#     print(df.iloc[i]['question'])
    
#     tmp = question_embeddings.copy()
#     tmp_df = df.copy().drop(i)
    
#     new_question_embedding = tmp[i]
#     del tmp[i]
#     print(tmp_df.iloc[find_most_similar(new_question_embedding, tmp)]['question'])
# Out:
# 0
# Approximately, what is the typical age of homes in each ZIP code area?
# What is the distribution of homeownership across different ZIP code areas?
# 1
# areas where the number of people exceeds the national average
# areas where the number of people is less than the national average
# 2
# areas where the number of people is less than the national average
# areas where the number of people exceeds the national average
# 3
# areas with long commutes
# zip code areas with the highest percentage of residents with long commutes of 90 minutes or more
# 4
# areas with the highest percentage of people with a bachelor's degree
# Which areas have the highest percentage of people with a bachelor's degree?
# 5
# areas with the highest percentage of people with a high school diploma
# areas with the highest percentage of people with some high school
# 6
# areas with the highest percentage of people with a master's degree
# areas with the highest percentage of people with a bachelor's degree
# 7
# areas with the highest percentage of people with a professional degree
# areas with the highest percentage of people with a master's degree
# 8
# areas with the highest percentage of people with some college
# areas with the highest percentage of people with some high school
# 9
# areas with the highest percentage of people with some high school
# areas with the highest percentage of people with a high school diploma
# 10
# areas with the most people
# Which areas have the most kids?
# 11
# How common is it to have 3 or more income earners in a household?
# Where do most two-income households live?
# 12
# How does the distribution of employment across different industries vary across zip code areas?
# What is the distribution of employment across different industries in each ZIP code?
# 13
# How does the fraction of white hispanic vs non-white hispanic population vary geographically?
# What is the distribution of different racial groups across different ZCTAs?
# 14
# How does the population of each ZCTA compare to the population of the US?
# What is the racial makeup of each ZCTA?
# 15
# How many people are on Medicare?
# What is the distribution of people by age?
# 16
# How many people studied arts and humanities?
# Where do the humanities majors live?
# 17
# Show me the black population by ZCTA.
# What is the racial makeup of each ZCTA?
# 18
# Show me the most Hispanic areas.
# Show me the most white non-Hispanic areas.
# 19
# Show me the most white non-Hispanic areas.
# Show me the most Hispanic areas.
# 20
# Show me the number of people per household
# Where do households have more cars than people?
# 21
# Show me where people dropped out of college.
# areas with the highest percentage of people with some college
# 22
# What are the least educated areas of the United States?
# Which areas have the most people living below the poverty line?
# 23
# What are the most common places where people work from home?
# Where do most people work from home?
# 24
# What areas have the largest concentration of the middle class?
# Which areas are the most middle class, with the fewest poor people or rich people?
# 25
# What is the average commute time for residents in each ZIP code area?
# What is the distribution of commute times for residents across different ZIP code areas?
# 26
# What is the average commute time?
# What is the average commute time for residents in each ZIP code area?
# 27
# What is the distribution of commute times for residents across different ZIP code areas?
# What is the average commute time for residents in each ZIP code area?
# 28
# What is the distribution of different racial groups across different ZCTAs?
# What is the racial makeup of each ZCTA?
# 29
# What is the distribution of employment across different industries in each ZIP code?
# How does the distribution of employment across different industries vary across zip code areas?
# 30
# What is the distribution of homeownership across different ZIP code areas?
# What is the distribution of median home value across different ZIP code areas?
# 31
# What is the distribution of median home value across different ZIP code areas?
# What is the distribution of median income across different ZIP code areas?
# 32
# What is the distribution of median income across different ZIP code areas?
# What is the distribution of median home value across different ZIP code areas?
# 33
# What is the distribution of people by age?
# What is the distribution of different racial groups across different ZCTAs?
# 34
# What is the distribution of renter-ship across different ZIP code areas?
# What is the distribution of homeownership across different ZIP code areas?
# 35
# What is the male-female ratio in each ZIP code?
# What is the median income of people in each ZIP code area?
# 36
# What is the median income of people in each ZIP code area?
# What is the distribution of median income across different ZIP code areas?
# 37
# What is the most common mode of transportation?
# Where do most people take public transportation to work?
# 38
# What is the percentage of people over 85 in each ZCTA?
# What is the percentage of the population in each ZCTA that identifies as two or more races?
# 39
# What is the percentage of the population in each ZCTA that identifies as "some other race" alone?
# What is the percentage of the population in each ZCTA that identifies as two or more races?
# 40
# What is the percentage of the population in each ZCTA that identifies as Native Hawaiian or Pacific Islander alone?
# What is the percentage of the population in each ZCTA that identifies as "some other race" alone?
# 41
# What is the percentage of the population in each ZCTA that identifies as two or more races?
# What is the percentage of the population in each ZCTA that identifies as "some other race" alone?
# 42
# What is the racial makeup of each ZCTA?
# What is the distribution of different racial groups across different ZCTAs?
# 43
# What is the ratio of white alone to black or African American alone in each ZCTA?
# What is the racial makeup of each ZCTA?
# 44
# What ZCTA has the largest population of people who identify as white alone?
# Which ZCTA has the largest population of people who identify as Asian alone?
# 45
# What's the most common industry in each ZIP code area?
# What is the distribution of employment across different industries in each ZIP code?
# 46
# What’s the most common way to get to work in every ZIP code?
# What is the distribution of commute times for residents across different ZIP code areas?
# 47
# Where am I likely to find the most people working in the Arts, entertainment, and recreation industry?
# Where is the highest concentration of workers in the Arts, entertainment, and recreation industry?
# 48
# Where am I likely to find the most people working in the Educational services industry?
# Where do people work in the educational services industry
# 49
# Where am I likely to find the most people working in the Health care and social assistance industry?
# Where is the highest concentration of workers in the Health care and social assistance industry?
# 50
# Where are people rent burdened? [define as 30pct+]
# Where are people severely rent burdened? [define as 50pct+]
# 51
# Where are people severely rent burdened? [define as 50pct+]
# Where are people rent burdened? [define as 30pct+]
# 52
# Where are the most young children living in poverty?
# Which areas have the most people living below the poverty line?
# 53
# Where are the newest homes?
# Where are the oldest homes?
# 54
# Where are the oldest homes?
# Where are the oldest houses?
# 55
# Where are the oldest houses?
# Where are the oldest homes?
# 56
# Where do homeowners exceed renters?
# Where do renters exceed homeowners?
# 57
# Where do households have a mortgage?
# Where do households not have a mortgage?
# 58
# Where do households have more cars than people?
# Where do people have the most cars?
# 59
# Where do households not have a mortgage?
# Where do households have a mortgage?
# 60
# Where do miners live?
# Where do the richest people live?
# 61
# Where do most people drive to work?
# Where do most people walk to work?
# 62
# Where do most people take public transportation to work?
# Where do the most people take public transit?
# 63
# Where do most people walk to work?
# Where do most people drive to work?
# 64
# Where do most people work from home?
# What are the most common places where people work from home?
# 65
# Where do most two-income households live?
# Where do the most families not have an income earner?
# 66
# Where do people get by without a car?
# Where do people have no vehicle available?
# 67
# Where do people have no heat?
# Where do people have no vehicle available?
# 68
# Where do people have no vehicle available?
# Where do people get by without a car?
# 69
# Where do people have no workers in the household?
# Where do the most families not have an income earner?
# 70
# Where do people have the highest median income?
# Where do people make the most money?
# 71
# Where do people have the most advanced degrees?
# areas with the highest percentage of people with a professional degree
# 72
# Where do people have the most cars?
# Where do households have more cars than people?
# 73
# Where do people make the least money?
# Where do people make the most money?
# 74
# Where do people make the most money?
# Where do people make the least money?
# 75
# Where do people spend the most on electricity?
# Where do people spend the most on housing?
# 76
# Where do people spend the most on housing?
# Where do people spend the most on electricity?
# 77
# Where do people still use dialup internet?
# Which areas lack internet access?
# 78
# Where do people work in the educational services industry
# Where am I likely to find the most people working in the Educational services industry?
# 79
# Where do renters exceed homeowners?
# Where do homeowners exceed renters?
# 80
# Where do the agriculture majors live?
# Where do the education majors live?
# 81
# Where do the arts majors live?
# Where do the humanities majors live?
# 82
# Where do the business degree holders live that have at least 100 people?
# Where do the business majors live?
# 83
# Where do the business majors live?
# Where do the education majors live?
# 84
# Where do the computer science majors live?
# Where do the social sciences majors live?
# 85
# Where do the education majors live?
# Where do the business majors live?
# 86
# Where do the engineering majors live?
# Where do the education majors live?
# 87
# Where do the health majors live?
# Where do the education majors live?
# 88
# Where do the history majors live?
# Where do the education majors live?
# 89
# Where do the humanities majors live?
# Where do the social sciences majors live?
# 90
# Where do the life science majors live?
# Where do the physical science majors live?
# 91
# Where do the math majors live?
# Where do the education majors live?
# 92
# Where do the most Asians live?
# Which ZCTA has the largest population of people who identify as Asian alone?
# 93
# Where do the most families not have an income earner?
# Where do people have no workers in the household?
# 94
# Where do the most people take public transit?
# Where do most people take public transportation to work?
# 95
# Where do the physical science majors live?
# Where do the life science majors live?
# 96
# Where do the poorest people live?
# Which areas have the most people living below the poverty line?
# 97
# Where do the richest people live?
# Where do the poorest people live?
# 98
# Where do the social sciences majors live?
# Where do the physical science majors live?
# 99
# Where is gas heating most common?
# Where do people spend the most on electricity?
# 100
# Where is it most common to study math?
# Where do the math majors live?
# 101
# Where is poverty among seniors the biggest problem?
# Where are the most young children living in poverty?
# 102
# Where is satellite internet most popular?
# Where do people still use dialup internet?
# 103
# Where is the highest concentration of people who work from home?
# Where do most people work from home?
# 104
# Where is the highest concentration of workers in the Arts, entertainment, and recreation industry?
# Where is the lowest concentration of workers in the Arts, entertainment, and recreation industry?
# 105
# Where is the highest concentration of workers in the Educational services industry?
# Where is the lowest concentration of workers in the Educational services industry?
# 106
# Where is the highest concentration of workers in the Health care and social assistance industry?
# Where is the lowest concentration of workers in the Health care and social assistance industry?
# 107
# Where is the highest concentration of workers in the Information industry?
# Where is the lowest concentration of workers in the Information industry?
# 108
# Where is the highest concentration of workers in the Manufacturing industry?
# Where is the lowest concentration of workers in the Manufacturing industry?
# 109
# Where is the highest concentration of workers in the Professional, scientific, and technical services industry?
# Where is the lowest concentration of workers in the Professional, scientific, and technical services industry?
# 110
# Where is the highest concentration of workers in the Retail trade industry?
# Where is the highest concentration of workers in the Wholesale trade industry?
# 111
# Where is the highest concentration of workers in the Transportation and warehousing industry?
# Where is the lowest concentration of workers in the Transportation and warehousing industry?
# 112
# Where is the highest concentration of workers in the Wholesale trade industry?
# Where is the highest concentration of workers in the Retail trade industry?
# 113
# Where is the lowest concentration of workers in the Arts, entertainment, and recreation industry?
# Where is the highest concentration of workers in the Arts, entertainment, and recreation industry?
# 114
# Where is the lowest concentration of workers in the Educational services industry?
# Where is the highest concentration of workers in the Educational services industry?
# 115
# Where is the lowest concentration of workers in the Health care and social assistance industry?
# Where is the highest concentration of workers in the Health care and social assistance industry?
# 116
# Where is the lowest concentration of workers in the Information industry?
# Where is the highest concentration of workers in the Information industry?
# 117
# Where is the lowest concentration of workers in the Manufacturing industry?
# Where is the highest concentration of workers in the Manufacturing industry?
# 118
# Where is the lowest concentration of workers in the Professional, scientific, and technical services industry?
# Where is the highest concentration of workers in the Professional, scientific, and technical services industry?
# 119
# Where is the lowest concentration of workers in the Retail trade industry?
# Where is the lowest concentration of workers in the Wholesale trade industry?
# 120
# Where is the lowest concentration of workers in the Transportation and warehousing industry?
# Where is the highest concentration of workers in the Transportation and warehousing industry?
# 121
# Where is the lowest concentration of workers in the Wholesale trade industry?
# Where is the lowest concentration of workers in the Retail trade industry?
# 122
# Where were the most houses built during the housing boom of the early 2000s?
# Where were the most houses built in the 1950s?
# 123
# Where were the most houses built in the 1950s?
# Where were the most houses built during the housing boom of the early 2000s?
# 124
# Which areas are mostly white?
# Show me the most white non-Hispanic areas.
# 125
# Which areas are the most middle class, with the fewest poor people or rich people?
# What areas have the largest concentration of the middle class?
# 126
# Which areas have the highest percentage of people with a bachelor's degree?
# areas with the highest percentage of people with a bachelor's degree
# 127
# Which areas have the highest ratio of working age men to women?
# Which areas have the most retirees?
# 128
# Which areas have the most kids?
# areas with the most people
# 129
# Which areas have the most people living below the poverty line?
# Where do the poorest people live?
# 130
# Which areas have the most retirees?
# Which areas have the most kids?
# 131
# Which areas lack internet access?
# Where do people still use dialup internet?
# 132
# Which ZCTA has the largest population of people who identify as Asian alone?
# What ZCTA has the largest population of people who identify as white alone?
# 133
# Which zip code areas have the highest percentage of residents with long commutes of 90 minutes or more?
# zip code areas with the highest percentage of residents with long commutes of 90 minutes or more
# 134
# Which ZIP codes have the most renters?
# What is the distribution of renter-ship across different ZIP code areas?
# 135
# zctas where the majority of people identify as American Indian or Alaska Native
# zctas where the majority of people identify as Native Hawaiian or Pacific Islander
# 136
# zctas where the majority of people identify as Asian
# zctas where the majority of people identify as white
# 137
# zctas where the majority of people identify as black or African American
# zctas where the majority of people identify as Asian
# 138
# zctas where the majority of people identify as Native Hawaiian or Pacific Islander
# zctas where the majority of people identify as American Indian or Alaska Native
# 139
# zctas where the majority of people identify as white
# zctas where the majority of people identify as Asian
# 140
# zip code areas with the highest percentage of residents with long commutes of 90 minutes or more
# zip code areas with the highest percentage of residents with very long commutes of 120 minutes or more
# 141
# zip code areas with the highest percentage of residents with short commutes of less than 30 minutes
# zip code areas with the highest percentage of residents with long commutes of 90 minutes or more
# 142
# zip code areas with the highest percentage of residents with very long commutes of 120 minutes or more
# zip code areas with the highest percentage of residents with long commutes of 90 minutes or more
