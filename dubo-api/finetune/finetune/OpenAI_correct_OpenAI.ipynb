# %%
import pandas as pd
import numpy as np

import openai
import sqlite3
import re

# %% [markdown]
# # Fix invalid SQL

# %%
def get_schema(x):
    return re.sub(r'Schema: (.+?);\nQuestion.*\n\n###\n\n', r'\1', x['open_ai_prompt'])

def get_question(x):
    return re.sub(r'Schema: .+?\nQuestion: (.+?)\n\n###\n\n', r'\1', x['open_ai_prompt'])

def open_ai_completion(x):
    return f" {x['query']}\n" 

def open_ai_correction_prompt(x):
    return f'''
        Your task is to correct a SQL query.
        
        You have the following DDLs:
        ```
        {x['schema']}
        ```
        And following question:
        """{x['question']}"""
        
        The draft SQL query is:
        ```
        {x['model_response']}
        ```
        
        The problem is:
        ```
        {x['error_prompt']}
        ```
        
        Respond with only one concise, corrected SQL statement.
        '''

def execution(row, query_type):
    PATH = 'spider/database/'
    db_id = row['db_id']
    
    query = row[query_type]

    # Connect to the SQLite database file
    conn = sqlite3.connect(PATH + db_id + '/' + db_id + '.sqlite')

    # Create a cursor object
    cursor = conn.cursor()

    # Execute a SELECT statement
    try:
        cursor.execute(query)
    except:
        return "invalid SQL"

    # Fetch the results
    results = cursor.fetchall()

    # Loop through the results and print them
    # for result in results:
    #     print(result)

    # Close the cursor and connection
    cursor.close()
    conn.close()
    
    return results

def correct_query(x):
    prompt = open_ai_correction_prompt(x)

    completions = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        temperature=0.3,
        max_tokens=2000,
        best_of=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    print(completions.choices[0].text)
    return completions.choices[0].text

# %%
df = pd.read_csv('davinci-ft-mercator-2023-01-25-23-01-53-completions.csv',index_col=0)
df['schema']   = df.apply(get_schema, axis=1)
df['question'] = df.apply(get_question, axis=1)

df_spider = pd.read_json('spider/train_spider.json')
df_spider['open_ai_completion'] = df_spider.apply(lambda x: open_ai_completion(x), axis=1)


df = df.merge(df_spider[['db_id', 'open_ai_completion']], left_on='open_ai_completion', right_on='open_ai_completion')

df['open_ai_execution'] = df.apply(lambda x: execution(x, 'open_ai_completion'), axis=1)
df['model_response_execution'] = df.apply(lambda x: execution(x, 'model_response'), axis=1)
df['execution_accuracy'] = np.where(df['open_ai_execution'] == df['model_response_execution'], 1, 0)

df
# Out:
#                                         open_ai_prompt  \
# 0    Schema: create table `catalog_contents` (`cata...
# 1    Schema: create table `catalog_contents` (`cata...
# 2    Schema: create table `catalog_contents` (`cata...
# 3    Schema: create table `catalog_contents` (`cata...
# 4    Schema: create table `attribute_definitions` (...
# ..                                                 ...
# 985  Schema: create table airports (   apid integer...
# 986  Schema: create table airports (   apid integer...
# 987  Schema: create table airports (   apid integer...
# 988  Schema: create table airports (   apid integer...
# 989  Schema: create table airports (   apid integer...
#
#                                     open_ai_completion  \
# 0     SELECT distinct(catalog_entry_name) FROM cata...
# 1     SELECT distinct(catalog_entry_name) FROM cata...
# 2     SELECT distinct(catalog_entry_name) FROM cata...
# 3     SELECT distinct(catalog_entry_name) FROM cata...
# 4     SELECT attribute_data_type FROM Attribute_Def...
# ..                                                 ...
# 985   SELECT avg(elevation) ,  country FROM airport...
# 986   SELECT city FROM airports GROUP BY city HAVIN...
# 987   SELECT city FROM airports GROUP BY city HAVIN...
# 988   SELECT city FROM airports GROUP BY city HAVIN...
# 989   SELECT city FROM airports GROUP BY city HAVIN...
#
#                                         model_response  \
# 0     SELECT DISTINCT catalog_entry_name FROM CATAL...
# 1     SELECT DISTINCT catalog_entry_name FROM CATAL...
# 2     SELECT DISTINCT catalog_entry_name FROM Catal...
# 3     SELECT DISTINCT catalog_entry_name FROM Catal...
# 4     SELECT attribute_data_type FROM attribute_def...
# ..                                                 ...
# 985   SELECT country ,  avg(elevation) FROM airport...
# 986   SELECT city FROM airports GROUP BY city HAVIN...
# 987   SELECT city FROM airports GROUP BY city HAVIN...
# 988   SELECT city FROM airports GROUP BY city HAVIN...
# 989   SELECT city FROM airports GROUP BY city HAVIN...
#
#                                                 schema  \
# 0    create table `catalog_contents` (`catalog_entr...
# 1    create table `catalog_contents` (`catalog_entr...
# 2    create table `catalog_contents` (`catalog_entr...
# 3    create table `catalog_contents` (`catalog_entr...
# 4    create table `attribute_definitions` (`attribu...
# ..                                                 ...
# 985  create table airports (   apid integer primary...
# 986  create table airports (   apid integer primary...
# 987  create table airports (   apid integer primary...
# 988  create table airports (   apid integer primary...
# 989  create table airports (   apid integer primary...
#
#                                               question            db_id  \
# 0           Find the names of all the catalog entries.  product_catalog
# 1           Find the names of all the catalog entries.  product_catalog
# 2                What are all the catalog entry names?  product_catalog
# 3                What are all the catalog entry names?  product_catalog
# 4    Find the list of attribute data types possesse...  product_catalog
# ..                                                 ...              ...
# 985  For each country, what is the average elevatio...         flight_4
# 986   Find the cities which have exactly two airports.         flight_4
# 987   Find the cities which have exactly two airports.         flight_4
# 988     What are the cities with exactly two airports?         flight_4
# 989     What are the cities with exactly two airports?         flight_4
#
#                                      open_ai_execution  \
# 0    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...
# 1    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...
# 2    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...
# 3    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...
# 4                                            [(Bool,)]
# ..                                                 ...
# 985  [(3732.4, Afghanistan), (281.4, Albania), (144...
# 986  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...
# 987  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...
# 988  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...
# 989  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...
#
#                               model_response_execution  execution_accuracy
# 0    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...                   1
# 1    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...                   1
# 2    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...                   1
# 3    [(Cola,), (Root beer,), (Cream Soda,), (Carbon...                   1
# 4                                            [(Bool,)]                   1
# ..                                                 ...                 ...
# 985  [(Afghanistan, 3732.4), (Albania, 281.4), (Alg...                   0
# 986  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...                   1
# 987  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...                   1
# 988  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...                   1
# 989  [(Abilene,), (Adana,), (Addis Ababa,), (Adelai...                   1
#
# [990 rows x 9 columns]

# %%
df_wrong = df[df['execution_accuracy'] == 0].copy()
df_wrong['error_prompt'] = np.where(df_wrong['model_response_execution'] == 'invalid SQL',
                                   'invalid SQL', '')

df_wrong['corrected_query'] = ''

for idx, row in df_wrong.iterrows():
    if df_wrong.loc[idx]['error_prompt'] != 'invalid SQL':
        continue
    df_wrong.at[idx,'corrected_query'] = correct_query(row)

df_wrong.head()
# Out:
#         SELECT SUM(settlement_amount), AVG(settlement_amount) FROM Settlements;
#
#         SELECT SUM(settlement_amount), AVG(settlement_amount) FROM Settlements;
#
#         SELECT dependent_name FROM dependent WHERE relationship  =  'spouse'
#
#         SELECT hispanic FROM city WHERE black > 10;
#
#         SELECT hispanic FROM city WHERE black > 10;
#
#         SELECT COUNT(DISTINCT region_id) FROM affected_region
#
#         SELECT COUNT(DISTINCT region_id) FROM affected_region;
#
#         SELECT format FROM files GROUP BY format ORDER BY COUNT(*) DESC LIMIT 1
#
#         SELECT format FROM files GROUP BY format ORDER BY COUNT(*) DESC LIMIT 1
#
#         SELECT language, AVG(rating) FROM song GROUP BY language;
#
#         SELECT language, AVG(rating) FROM song GROUP BY language;
#
#         SELECT language, AVG(rating) FROM song WHERE rating > 0 AND rating < 11 GROUP BY language;
#
#         SELECT language, AVG(rating) FROM song WHERE rating > 0 AND rating < 11 GROUP BY language;
#
#         SELECT formats, COUNT(DISTINCT artist_name) FROM files GROUP BY formats;
#
#         SELECT formats, COUNT(DISTINCT artist_name) FROM files GROUP BY formats;
#
#         SELECT COUNT(*), formats FROM files GROUP BY formats;
#
#         SELECT COUNT(*), formats FROM files GROUP BY formats;
#
#         SELECT song_name FROM Song WHERE genre_is = 'modern' OR languages = 'English';
#
#         SELECT song_name FROM Song WHERE genre_is = 'modern' OR languages = 'English';
#
#         SELECT customer_phone FROM performers WHERE customer_name = "Ashley";
#
#         SELECT customer_phone FROM performers WHERE customer_name = "Ashley";
#
#         SELECT city FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
#
#         SELECT city FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
#
#         SELECT COUNT(DISTINCT city) FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
#
#         SELECT COUNT(DISTINCT city) FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
#                                        open_ai_prompt  \
# 16  Schema: create table `catalogs` (`catalog_id` ...
# 17  Schema: create table `catalogs` (`catalog_id` ...
# 18  Schema: create table `catalogs` (`catalog_id` ...
# 19  Schema: create table `catalogs` (`catalog_id` ...
# 36  Schema: create table `catalog_contents` (`cata...
#
#                                    open_ai_completion  \
# 16   SELECT distinct(catalog_publisher) FROM catal...
# 17   SELECT distinct(catalog_publisher) FROM catal...
# 18   SELECT distinct(catalog_publisher) FROM catal...
# 19   SELECT distinct(catalog_publisher) FROM catal...
# 36   SELECT catalog_entry_name FROM catalog_conten...
#
#                                        model_response  \
# 16   SELECT catalog_publisher FROM catalogs WHERE ...
# 17   SELECT catalog_publisher FROM catalogs WHERE ...
# 18   SELECT catalog_publisher FROM catalogs WHERE ...
# 19   SELECT catalog_publisher FROM catalogs WHERE ...
# 36   SELECT product_stock_number FROM Catalog_Cont...
#
#                                                schema  \
# 16  create table `catalogs` (`catalog_id` integer ...
# 17  create table `catalogs` (`catalog_id` integer ...
# 18  create table `catalogs` (`catalog_id` integer ...
# 19  create table `catalogs` (`catalog_id` integer ...
# 36  create table `catalog_contents` (`catalog_entr...
#
#                                              question            db_id  \
# 16  Find all the catalog publishers whose name con...  product_catalog
# 17  Find all the catalog publishers whose name con...  product_catalog
# 18  Which catalog publishers have substring "Murra...  product_catalog
# 19  Which catalog publishers have substring "Murra...  product_catalog
# 36  Find the name of the product that has the smal...  product_catalog
#
#           open_ai_execution                        model_response_execution  \
# 16  [(Murray Coffee shop,)]                                              []
# 17  [(Murray Coffee shop,)]                                              []
# 18  [(Murray Coffee shop,)]  [(Murray Coffee shop,), (Murray Coffee shop,)]
# 19  [(Murray Coffee shop,)]  [(Murray Coffee shop,), (Murray Coffee shop,)]
# 36                [(Cola,)]                                      [(89 cp,)]
#
#     execution_accuracy error_prompt corrected_query
# 16                   0
# 17                   0
# 18                   0
# 19                   0
# 36                   0

# %%
i = 5
print(df_wrong[df_wrong['error_prompt'] == 'invalid SQL']['open_ai_prompt'].iloc[i])
print(df_wrong[df_wrong['error_prompt'] == 'invalid SQL']['model_response'].iloc[i].lstrip())
print(df_wrong[df_wrong['error_prompt'] == 'invalid SQL']['corrected_query'].iloc[i].lstrip())
print(df_wrong[df_wrong['error_prompt'] == 'invalid SQL']['open_ai_completion'].iloc[i].lstrip())
# Out:
# Schema: create table `affected_region` (`region_id` int,`storm_id` int,`number_city_affected` real,primary key (`region_id`,`storm_id`),foreign key (`region_id`);
# Question: Count the number of different affected regions.
#
# ###
#
#
# SELECT count(DISTINCT affected_region) FROM affected_region
# SELECT COUNT(DISTINCT region_id) FROM affected_region
# SELECT count(DISTINCT region_id) FROM affected_region

# %%
df_wrong[df_wrong['error_prompt'] == 'invalid SQL']['model_response']
# Out:
# 82      SELECT sum ,  avg(settlement_amount) FROM Set...
# 83      SELECT sum ,  avg(settlement_amount) FROM Set...
# 231     SELECT dependent_name FROM dependent WHERE re...
# 352     SELECT hispanic_percent FROM city WHERE black...
# 353     SELECT hispanic_percent FROM city WHERE black...
# 406     SELECT count(DISTINCT affected_region) FROM a...
# 407     SELECT count(DISTINCT affected_region) FROM a...
# 471     SELECT format FROM files GROUP BY format ORDE...
# 472     SELECT format FROM files GROUP BY format ORDE...
# 479     SELECT language ,  avg(rating) FROM song GROU...
# 480     SELECT language ,  avg(rating) FROM song GROU...
# 481     SELECT language ,  avg(rating) FROM song GROU...
# 482     SELECT language ,  avg(rating) FROM song GROU...
# 483     SELECT format ,  count(DISTINCT artist_name) ...
# 484     SELECT format ,  count(DISTINCT artist_name) ...
# 485     SELECT count(*) ,  format FROM Files GROUP BY...
# 486     SELECT count(*) ,  format FROM Files GROUP BY...
# 509     SELECT song_name FROM Song WHERE genre_is  = ...
# 510     SELECT song_name FROM Song WHERE genre_is  = ...
# 590     SELECT customer_phone FROM performers WHERE p...
# 591     SELECT customer_phone FROM performers WHERE p...
# 970     SELECT city FROM airports WHERE country  =  '...
# 971     SELECT city FROM airports WHERE country  =  '...
# 972     SELECT count(*) FROM airports WHERE country  ...
# 973     SELECT count(*) FROM airports WHERE country  ...
# Name: model_response, dtype: object

# %%
print(open_ai_correction_prompt(df_wrong.loc[82]))
# Out:
#         Your task is to correct a SQL query.
#
#         You have the following DDLs:
#         ```
#         create table settlements (settlement_id integer not null,claim_id integer,effective_date date,settlement_amount real,primary key (settlement_id),unique (settlement_id),foreign key (claim_id)
#         ```
#         And following question:
#         """Return the sum and average of all settlement amounts."""
#
#         The draft SQL query is:
#         ```
#          SELECT sum ,  avg(settlement_amount) FROM Settlements
#         ```
#
#         The problem is:
#         ```
#         invalid SQL
#         ```
#
#         Respond with only one concise, corrected SQL statement.

# %%
# ignore: 
# - whitespace
# - capitalization
# - trailing semicolons
# - the difference between single and double quotes
# - difference between 'distinct(...)' and 'distinct ...'
# - explictly stating ASC (the ORDER BY default)
tmp = df_wrong[df_wrong['corrected_query'] != ''].copy()

tmp['correct'] = np.where(tmp['open_ai_completion'].str
                                                                         .strip()
                                                                         .str
                                                                         .lower()
                                                                         .apply(lambda x: re.sub("distinct\((.*)\)", "distinct\\1", 
                                                                                          re.sub('orderby(.*)asc', 'orderby\\1',
                                                                                          re.sub('"', "'",
                                                                                          re.sub('\s+', '', x))))
                                                                                .rstrip(';')) == 
                                     tmp['corrected_query'].str
                                                                     .strip()
                                                                     .str
                                                                     .lower()
                                                                         .apply(lambda x: re.sub("distinct\((.*)\)", "distinct\\1", 
                                                                                          re.sub('orderby(.*)asc', 'orderby\\1',
                                                                                          re.sub('"', "'",
                                                                                          re.sub('\s+', '', x))))
                                                                            .rstrip(';')), 1, 0)
tmp['correct'].mean()
# Out:
# 0.6

# %%
tmp
# Out:
#                                         open_ai_prompt  \
# 82   Schema: create table settlements (settlement_i...
# 83   Schema: create table settlements (settlement_i...
# 231  Schema: create table dependent(essn integer,de...
# 352  Schema: create table "city" ("city_id" int,"co...
# 353  Schema: create table "city" ("city_id" int,"co...
# 406  Schema: create table `affected_region` (`regio...
# 407  Schema: create table `affected_region` (`regio...
# 471  Schema: create table files(\tf_id number(10) n...
# 472  Schema: create table files(\tf_id number(10) n...
# 479  Schema: create table song(\tsong_name varchar2...
# 480  Schema: create table song(\tsong_name varchar2...
# 481  Schema: create table song(\tsong_name varchar2...
# 482  Schema: create table song(\tsong_name varchar2...
# 483  Schema: create table files(\tf_id number(10) n...
# 484  Schema: create table files(\tf_id number(10) n...
# 485  Schema: create table files(\tf_id number(10) n...
# 486  Schema: create table files(\tf_id number(10) n...
# 509  Schema: create table song(\tsong_name varchar2...
# 510  Schema: create table song(\tsong_name varchar2...
# 590  Schema: create table performers (performer_id ...
# 591  Schema: create table performers (performer_id ...
# 970  Schema: create table airports (   apid integer...
# 971  Schema: create table airports (   apid integer...
# 972  Schema: create table airports (   apid integer...
# 973  Schema: create table airports (   apid integer...
#
#                                     open_ai_completion  \
# 82    SELECT sum(settlement_amount) ,  avg(settleme...
# 83    SELECT sum(settlement_amount) ,  avg(settleme...
# 231   SELECT Dependent_name FROM dependent WHERE re...
# 352     SELECT Hispanic FROM city WHERE Black  >  10\n
# 353     SELECT Hispanic FROM city WHERE Black  >  10\n
# 406   SELECT count(DISTINCT region_id) FROM affecte...
# 407   SELECT count(DISTINCT region_id) FROM affecte...
# 471   SELECT formats FROM files GROUP BY formats OR...
# 472   SELECT formats FROM files GROUP BY formats OR...
# 479   SELECT avg(rating) ,  languages FROM song GRO...
# 480   SELECT avg(rating) ,  languages FROM song GRO...
# 481   SELECT avg(rating) ,  languages FROM song GRO...
# 482   SELECT avg(rating) ,  languages FROM song GRO...
# 483   SELECT count(*) ,  formats FROM files GROUP B...
# 484   SELECT count(*) ,  formats FROM files GROUP B...
# 485   SELECT count(*) ,  formats FROM files GROUP B...
# 486   SELECT count(*) ,  formats FROM files GROUP B...
# 509   SELECT song_name FROM song WHERE genre_is  = ...
# 510   SELECT song_name FROM song WHERE genre_is  = ...
# 590   SELECT Customer_Phone FROM PERFORMERS WHERE C...
# 591   SELECT Customer_Phone FROM PERFORMERS WHERE C...
# 970   SELECT city FROM airports WHERE country  =  '...
# 971   SELECT city FROM airports WHERE country  =  '...
# 972   SELECT city FROM airports WHERE country  =  '...
# 973   SELECT city FROM airports WHERE country  =  '...
#
#                                         model_response  \
# 82    SELECT sum ,  avg(settlement_amount) FROM Set...
# 83    SELECT sum ,  avg(settlement_amount) FROM Set...
# 231   SELECT dependent_name FROM dependent WHERE re...
# 352   SELECT hispanic_percent FROM city WHERE black...
# 353   SELECT hispanic_percent FROM city WHERE black...
# 406   SELECT count(DISTINCT affected_region) FROM a...
# 407   SELECT count(DISTINCT affected_region) FROM a...
# 471   SELECT format FROM files GROUP BY format ORDE...
# 472   SELECT format FROM files GROUP BY format ORDE...
# 479   SELECT language ,  avg(rating) FROM song GROU...
# 480   SELECT language ,  avg(rating) FROM song GROU...
# 481   SELECT language ,  avg(rating) FROM song GROU...
# 482   SELECT language ,  avg(rating) FROM song GROU...
# 483   SELECT format ,  count(DISTINCT artist_name) ...
# 484   SELECT format ,  count(DISTINCT artist_name) ...
# 485   SELECT count(*) ,  format FROM Files GROUP BY...
# 486   SELECT count(*) ,  format FROM Files GROUP BY...
# 509   SELECT song_name FROM Song WHERE genre_is  = ...
# 510   SELECT song_name FROM Song WHERE genre_is  = ...
# 590   SELECT customer_phone FROM performers WHERE p...
# 591   SELECT customer_phone FROM performers WHERE p...
# 970   SELECT city FROM airports WHERE country  =  '...
# 971   SELECT city FROM airports WHERE country  =  '...
# 972   SELECT count(*) FROM airports WHERE country  ...
# 973   SELECT count(*) FROM airports WHERE country  ...
#
#                                                 schema  \
# 82   create table settlements (settlement_id intege...
# 83   create table settlements (settlement_id intege...
# 231  create table dependent(essn integer,dependent_...
# 352  create table "city" ("city_id" int,"county_id"...
# 353  create table "city" ("city_id" int,"county_id"...
# 406  create table `affected_region` (`region_id` in...
# 407  create table `affected_region` (`region_id` in...
# 471  create table files(\tf_id number(10) not null,...
# 472  create table files(\tf_id number(10) not null,...
# 479  create table song(\tsong_name varchar2(50),\ta...
# 480  create table song(\tsong_name varchar2(50),\ta...
# 481  create table song(\tsong_name varchar2(50),\ta...
# 482  create table song(\tsong_name varchar2(50),\ta...
# 483  create table files(\tf_id number(10) not null,...
# 484  create table files(\tf_id number(10) not null,...
# 485  create table files(\tf_id number(10) not null,...
# 486  create table files(\tf_id number(10) not null,...
# 509  create table song(\tsong_name varchar2(50),\ta...
# 510  create table song(\tsong_name varchar2(50),\ta...
# 590  create table performers (performer_id integer ...
# 591  create table performers (performer_id integer ...
# 970  create table airports (   apid integer primary...
# 971  create table airports (   apid integer primary...
# 972  create table airports (   apid integer primary...
# 973  create table airports (   apid integer primary...
#
#                                               question  \
# 82   Return the sum and average of all settlement a...
# 83   Return the sum and average of all settlement a...
# 231  find all dependent names who have a spouse rel...
# 352  What are the percentage of hispanics in cities...
# 353  What are the percentage of hispanics in cities...
# 406    Count the number of different affected regions.
# 407    Count the number of different affected regions.
# 471              What is the most popular file format?
# 472              What is the most popular file format?
# 479  What is the average rating of songs for each l...
# 480  What is the average rating of songs for each l...
# 481  What is the average song rating for each langu...
# 482  What is the average song rating for each langu...
# 483  For each file format, return the number of art...
# 484  For each file format, return the number of art...
# 485      How many songs were released for each format?
# 486      How many songs were released for each format?
# 509  What are the names of the songs that are moder...
# 510  What are the names of the songs that are moder...
# 590  What is the phone number of the performer Ashley?
# 591  What is the phone number of the performer Ashley?
# 970  Return the cities with more than 3 airports in...
# 971  Return the cities with more than 3 airports in...
# 972  What is the number of cities in the United Sta...
# 973  What is the number of cities in the United Sta...
#
#                          db_id  \
# 82              insurance_fnol
# 83              insurance_fnol
# 231                  company_1
# 352       county_public_safety
# 353       county_public_safety
# 406               storm_record
# 407               storm_record
# 471                    music_1
# 472                    music_1
# 479                    music_1
# 480                    music_1
# 481                    music_1
# 482                    music_1
# 483                    music_1
# 484                    music_1
# 485                    music_1
# 486                    music_1
# 509                    music_1
# 510                    music_1
# 590  cre_Drama_Workshop_Groups
# 591  cre_Drama_Workshop_Groups
# 970                   flight_4
# 971                   flight_4
# 972                   flight_4
# 973                   flight_4
#
#                                      open_ai_execution  \
# 82            [(53543.69999999999, 5354.369999999999)]
# 83            [(53543.69999999999, 5354.369999999999)]
# 231                   [(Joy,), (Abner,), (Elizabeth,)]
# 352  [(99.5,), (99.1,), (99.0,), (99.1,), (99.2,), ...
# 353  [(99.5,), (99.1,), (99.0,), (99.1,), (99.2,), ...
# 406                                             [(4,)]
# 407                                             [(4,)]
# 471                                           [(mp4,)]
# 472                                           [(mp4,)]
# 479                    [(7.5, bangla), (7.0, english)]
# 480                    [(7.5, bangla), (7.0, english)]
# 481                    [(7.5, bangla), (7.0, english)]
# 482                    [(7.5, bangla), (7.0, english)]
# 483                               [(2, mp3), (4, mp4)]
# 484                               [(2, mp3), (4, mp4)]
# 485                               [(2, mp3), (4, mp4)]
# 486                               [(2, mp3), (4, mp4)]
# 509      [(My love,), (Just beat it,), (Aj ei akash,)]
# 510      [(My love,), (Just beat it,), (Aj ei akash,)]
# 590                                  [(893-536-8857,)]
# 591                                  [(893-536-8857,)]
# 970  [(Anchorage,), (Atlanta,), (Burlington,), (Chi...
# 971  [(Anchorage,), (Atlanta,), (Burlington,), (Chi...
# 972  [(Anchorage,), (Atlanta,), (Burlington,), (Chi...
# 973  [(Anchorage,), (Atlanta,), (Burlington,), (Chi...
#
#     model_response_execution  execution_accuracy error_prompt  \
# 82               invalid SQL                   0  invalid SQL
# 83               invalid SQL                   0  invalid SQL
# 231              invalid SQL                   0  invalid SQL
# 352              invalid SQL                   0  invalid SQL
# 353              invalid SQL                   0  invalid SQL
# 406              invalid SQL                   0  invalid SQL
# 407              invalid SQL                   0  invalid SQL
# 471              invalid SQL                   0  invalid SQL
# 472              invalid SQL                   0  invalid SQL
# 479              invalid SQL                   0  invalid SQL
# 480              invalid SQL                   0  invalid SQL
# 481              invalid SQL                   0  invalid SQL
# 482              invalid SQL                   0  invalid SQL
# 483              invalid SQL                   0  invalid SQL
# 484              invalid SQL                   0  invalid SQL
# 485              invalid SQL                   0  invalid SQL
# 486              invalid SQL                   0  invalid SQL
# 509              invalid SQL                   0  invalid SQL
# 510              invalid SQL                   0  invalid SQL
# 590              invalid SQL                   0  invalid SQL
# 591              invalid SQL                   0  invalid SQL
# 970              invalid SQL                   0  invalid SQL
# 971              invalid SQL                   0  invalid SQL
# 972              invalid SQL                   0  invalid SQL
# 973              invalid SQL                   0  invalid SQL
#
#                                        corrected_query  correct
# 82   \n        SELECT SUM(settlement_amount), AVG(s...        1
# 83   \n        SELECT SUM(settlement_amount), AVG(s...        1
# 231  \n        SELECT dependent_name FROM dependent...        1
# 352  \n        SELECT hispanic FROM city WHERE blac...        1
# 353  \n        SELECT hispanic FROM city WHERE blac...        1
# 406  \n        SELECT COUNT(DISTINCT region_id) FRO...        1
# 407  \n        SELECT COUNT(DISTINCT region_id) FRO...        1
# 471  \n        SELECT format FROM files GROUP BY fo...        0
# 472  \n        SELECT format FROM files GROUP BY fo...        0
# 479  \n        SELECT language, AVG(rating) FROM so...        0
# 480  \n        SELECT language, AVG(rating) FROM so...        0
# 481  \n        SELECT language, AVG(rating) FROM so...        0
# 482  \n        SELECT language, AVG(rating) FROM so...        0
# 483  \n        SELECT formats, COUNT(DISTINCT artis...        0
# 484  \n        SELECT formats, COUNT(DISTINCT artis...        0
# 485  \n        SELECT COUNT(*), formats FROM files ...        1
# 486  \n        SELECT COUNT(*), formats FROM files ...        1
# 509  \n        SELECT song_name FROM Song WHERE gen...        1
# 510  \n        SELECT song_name FROM Song WHERE gen...        1
# 590  \n        SELECT customer_phone FROM performer...        1
# 591  \n        SELECT customer_phone FROM performer...        1
# 970  \n        SELECT city FROM airports WHERE coun...        1
# 971  \n        SELECT city FROM airports WHERE coun...        1
# 972  \n        SELECT COUNT(DISTINCT city) FROM air...        0
# 973  \n        SELECT COUNT(DISTINCT city) FROM air...        0

# %%
for i in range(len(tmp)):
    # print(tmp['open_ai_prompt'].iloc[i])
    print(tmp['model_response'].iloc[i].lstrip())
    print(tmp['corrected_query'].iloc[i].lstrip())
    print(tmp['open_ai_completion'].iloc[i].lstrip())
# Out:
# SELECT sum ,  avg(settlement_amount) FROM Settlements
# SELECT SUM(settlement_amount), AVG(settlement_amount) FROM Settlements;
# SELECT sum(settlement_amount) ,  avg(settlement_amount) FROM settlements
#
# SELECT sum ,  avg(settlement_amount) FROM Settlements
# SELECT SUM(settlement_amount), AVG(settlement_amount) FROM Settlements;
# SELECT sum(settlement_amount) ,  avg(settlement_amount) FROM settlements
#
# SELECT dependent_name FROM dependent WHERE relationship  =  'spouse' AND employee_id  !=  0
# SELECT dependent_name FROM dependent WHERE relationship  =  'spouse'
# SELECT Dependent_name FROM dependent WHERE relationship  =  'Spouse'
#
# SELECT hispanic_percent FROM city WHERE black  >  10
# SELECT hispanic FROM city WHERE black > 10;
# SELECT Hispanic FROM city WHERE Black  >  10
#
# SELECT hispanic_percent FROM city WHERE black  >  10
# SELECT hispanic FROM city WHERE black > 10;
# SELECT Hispanic FROM city WHERE Black  >  10
#
# SELECT count(DISTINCT affected_region) FROM affected_region
# SELECT COUNT(DISTINCT region_id) FROM affected_region
# SELECT count(DISTINCT region_id) FROM affected_region
#
# SELECT count(DISTINCT affected_region) FROM affected_region
# SELECT COUNT(DISTINCT region_id) FROM affected_region;
# SELECT count(DISTINCT region_id) FROM affected_region
#
# SELECT format FROM files GROUP BY format ORDER BY count(*) DESC LIMIT 1
# SELECT format FROM files GROUP BY format ORDER BY COUNT(*) DESC LIMIT 1
# SELECT formats FROM files GROUP BY formats ORDER BY COUNT (*) DESC LIMIT 1
#
# SELECT format FROM files GROUP BY format ORDER BY count(*) DESC LIMIT 1
# SELECT format FROM files GROUP BY format ORDER BY COUNT(*) DESC LIMIT 1
# SELECT formats FROM files GROUP BY formats ORDER BY COUNT (*) DESC LIMIT 1
#
# SELECT language ,  avg(rating) FROM song GROUP BY language
# SELECT language, AVG(rating) FROM song GROUP BY language;
# SELECT avg(rating) ,  languages FROM song GROUP BY languages
#
# SELECT language ,  avg(rating) FROM song GROUP BY language
# SELECT language, AVG(rating) FROM song GROUP BY language;
# SELECT avg(rating) ,  languages FROM song GROUP BY languages
#
# SELECT language ,  avg(rating) FROM song GROUP BY language
# SELECT language, AVG(rating) FROM song WHERE rating > 0 AND rating < 11 GROUP BY language;
# SELECT avg(rating) ,  languages FROM song GROUP BY languages
#
# SELECT language ,  avg(rating) FROM song GROUP BY language
# SELECT language, AVG(rating) FROM song WHERE rating > 0 AND rating < 11 GROUP BY language;
# SELECT avg(rating) ,  languages FROM song GROUP BY languages
#
# SELECT format ,  count(DISTINCT artist_name) FROM Files GROUP BY format
# SELECT formats, COUNT(DISTINCT artist_name) FROM files GROUP BY formats;
# SELECT count(*) ,  formats FROM files GROUP BY formats
#
# SELECT format ,  count(DISTINCT artist_name) FROM Files GROUP BY format
# SELECT formats, COUNT(DISTINCT artist_name) FROM files GROUP BY formats;
# SELECT count(*) ,  formats FROM files GROUP BY formats
#
# SELECT count(*) ,  format FROM Files GROUP BY format
# SELECT COUNT(*), formats FROM files GROUP BY formats;
# SELECT count(*) ,  formats FROM files GROUP BY formats
#
# SELECT count(*) ,  format FROM Files GROUP BY format
# SELECT COUNT(*), formats FROM files GROUP BY formats;
# SELECT count(*) ,  formats FROM files GROUP BY formats
#
# SELECT song_name FROM Song WHERE genre_is  =  'modern' OR language  =  'English'
# SELECT song_name FROM Song WHERE genre_is = 'modern' OR languages = 'English';
# SELECT song_name FROM song WHERE genre_is  =  "modern" OR languages  =  "english"
#
# SELECT song_name FROM Song WHERE genre_is  =  'modern' OR language  =  'English'
# SELECT song_name FROM Song WHERE genre_is = 'modern' OR languages = 'English';
# SELECT song_name FROM song WHERE genre_is  =  "modern" OR languages  =  "english"
#
# SELECT customer_phone FROM performers WHERE performer_name = "Ashley";
# SELECT customer_phone FROM performers WHERE customer_name = "Ashley";
# SELECT Customer_Phone FROM PERFORMERS WHERE Customer_Name  =  "Ashley"
#
# SELECT customer_phone FROM performers WHERE performer_name = "Ashley";
# SELECT customer_phone FROM performers WHERE customer_name = "Ashley";
# SELECT Customer_Phone FROM PERFORMERS WHERE Customer_Name  =  "Ashley"
#
# SELECT city FROM airports WHERE country  =  'United States' AND count(*)  >  3
# SELECT city FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
# SELECT city FROM airports WHERE country  =  'United States' GROUP BY city HAVING count(*)  >  3
#
# SELECT city FROM airports WHERE country  =  'United States' AND count(*)  >  3
# SELECT city FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
# SELECT city FROM airports WHERE country  =  'United States' GROUP BY city HAVING count(*)  >  3
#
# SELECT count(*) FROM airports WHERE country  =  'United States' AND count(*)  >  3
# SELECT COUNT(DISTINCT city) FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
# SELECT city FROM airports WHERE country  =  'United States' GROUP BY city HAVING count(*)  >  3
#
# SELECT count(*) FROM airports WHERE country  =  'United States' AND count(*)  >  3
# SELECT COUNT(DISTINCT city) FROM airports WHERE country = 'United States' GROUP BY city HAVING COUNT(*) > 3;
# SELECT city FROM airports WHERE country  =  'United States' GROUP BY city HAVING count(*)  >  3
