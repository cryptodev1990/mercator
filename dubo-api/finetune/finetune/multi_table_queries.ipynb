# %%
import time
import json
import openai
import re
import sqlite3
import pandas as pd
import numpy as np

from os import path
from openai.api_requestor import error

# %%
def get_schema(db_id):
    PATH = 'spider/database/'
    
    path_to_file   = PATH + db_id + '/schema.sql'
    path_to_file_2 = PATH + db_id + '/' + db_id + '.sqlite'
    
    if path.exists(path_to_file):
        x = open(path_to_file, 'r').read()
        # Remove comment lines
        x = re.sub(r"^/\*.*\n", "", x, flags=re.MULTILINE)
        x = re.sub(r'^--.*(\n|$)', '', x, flags=re.MULTILINE)
        x = re.sub(r"^/\*.*\*/", "", x)
        
        x = re.sub(r'CREATE TABLE \t', 'CREATE TABLE ', x)
        
        arr = x.split(';')
        create_tables = []
        for i, stmt in enumerate(arr):
            stmt = stmt.strip()
            if stmt.lower().startswith('create'):
                create_tables.append(stmt.replace('IF NOT EXISTS ', '').replace('\n', ''))
        return ';'.join(create_tables)
      
    elif path.exists(path_to_file_2):
        # Connect to the sqlite file
        conn = sqlite3.connect(path_to_file_2)

        # Read the schema of the twitter_1.sqlite file into a dataframe
        df_conn = pd.read_sql_query("SELECT sql FROM sqlite_master WHERE type='table';", conn)
        
        # Close the connection
        conn.close()
        
        create_tables = []
        for idx, row in df_conn.iterrows():
            row['sql'] = row['sql'].strip()
            if row['sql'].lower().startswith('create'):
                create_tables.append(row['sql'].replace('IF NOT EXISTS ', '').replace('\n', ''))
        return ';'.join(create_tables)
    
    else: return None

def short_open_ai_prompt(x):
    return f'''Schema: {x['schema']}\nQuestion: {x['question']}\n\n###\n\n'''

# From OpenAI: The completion should start with a whitespace character (` `). 
# This tends to produce better results due to the tokenization we use.
def open_ai_completion(x):
    return f" {x['query']}\n" 

def call_model(row, engine):
    prompt = row["open_ai_prompt"]
    while True:
        try:
            completions = openai.Completion.create(
                engine=engine,
                prompt=prompt,
                max_tokens=1024,
                n=1,
                stop=["\n"],
                temperature=0.5
            )

            print(completions.choices[0].text)
            return completions.choices[0].text
    
        except error.ServiceUnavailableError:
            print('ServiceUnavailableError')
            time.sleep(1)
            continue
            
        except error.InvalidRequestError:
            print('InvalidRequestError: too many tokens')
            time.sleep(1)
            break

# %% [markdown]
# # Data Preparation

# %%
df = pd.read_json('spider/train_spider.json')
# df = df[~df['query'].str.contains('JOIN')]
# df = df[df['query'].str.count('FROM') <= 1]

# Set schema
df['schema']         = df.apply(lambda x: get_schema(x['db_id']), axis=1)
df['schema'] = df['schema'].apply(lambda x: re.sub('(?i) REFERENCES.*?(;|$)', ';', x))
# # Extract the name of the table after FROM
# df['table']  = df['query'].apply(lambda x: re.sub('.*FROM', 'FROM', x))\
#                           .apply(lambda x: re.sub('^FROM\s+(\S+).*', r'\1', x).rstrip(';')).str.lower()
# # Extract the 'create table' statement just for that table
# df['schema'] = df.apply(lambda x: ''.join(re.findall(r"(create table `{}`.*?;)".format(x["table"]), 
#                                                      x["schema"].lower())) or 
#                                   ''.join(re.findall(r"(create table `{}`.*?$)".format(x["table"]), 
#                                                      x["schema"].lower())) or 
#                                   ''.join(re.findall(r"(create table {}.*?;)".format(x["table"]), 
#                                                      x["schema"].lower())) or 
#                                   ''.join(re.findall(r"(create table {}.*?$)".format(x["table"]), 
#                                                      x["schema"].lower())) or 
#                                   ''.join(re.findall(r"(create table \"{}\".*?;)".format(x["table"]), 
#                                                      x["schema"].lower())) or
#                                   ''.join(re.findall(r"(create table \"{}\".*?$)".format(x["table"]), 
#                                                      x["schema"].lower())), axis=1)
df['schema'] = df['schema'].apply(lambda x: re.sub('NOT NULL', '', x))

# Set Open AI prompt and completion
df['open_ai_prompt'] = df.apply(lambda x: short_open_ai_prompt(x), axis=1)
df['open_ai_completion'] = df.apply(lambda x: open_ai_completion(x), axis=1)

# Randomize at the db level
df_db_id = pd.DataFrame(df['db_id'].unique(), columns=['db_id'])
np.random.seed(240956) #set seed
df_db_id['train_test'] = np.random.choice(['train','test'], df_db_id.shape[0], p=[0.8, 0.2])
df = df.merge(df_db_id, on='db_id')
df_train = df[df['train_test'] == 'train'][['open_ai_prompt', 'open_ai_completion']].copy()
df_test  = df[df['train_test'] == 'test'][['open_ai_prompt', 'open_ai_completion']].copy()

# %%
df[df['schema'] == '']['db_id'].unique()
# Out:
# array([], dtype=object)

# %%
print(df.iloc[110]['open_ai_prompt'])
print(df.iloc[110]['open_ai_completion'])
# Out:
# Schema: CREATE TABLE station (    id INTEGER PRIMARY KEY,    name TEXT,    lat NUMERIC,    long NUMERIC,    dock_count INTEGER,    city TEXT,    installation_date TEXT);CREATE TABLE status (    station_id INTEGER,    bikes_available INTEGER,    docks_available INTEGER,    time TEXT,    FOREIGN KEY (station_id);CREATE TABLE trip (    id INTEGER PRIMARY KEY,    duration INTEGER,    start_date TEXT,    start_station_name TEXT, -- this should be removed    start_station_id INTEGER,    end_date TEXT,    end_station_name TEXT, -- this should be removed    end_station_id INTEGER,    bike_id INTEGER,    subscription_type TEXT,    zip_code INTEGER);CREATE TABLE weather (    date TEXT,    max_temperature_f INTEGER,    mean_temperature_f INTEGER,    min_temperature_f INTEGER,    max_dew_point_f INTEGER,    mean_dew_point_f INTEGER,    min_dew_point_f INTEGER,    max_humidity INTEGER,    mean_humidity INTEGER,    min_humidity INTEGER,    max_sea_level_pressure_inches NUMERIC,    mean_sea_level_pressure_inches NUMERIC,    min_sea_level_pressure_inches NUMERIC,    max_visibility_miles INTEGER,    mean_visibility_miles INTEGER,    min_visibility_miles INTEGER,    max_wind_Speed_mph INTEGER,    mean_wind_speed_mph INTEGER,    max_gust_speed_mph INTEGER,    precipitation_inches INTEGER,    cloud_cover INTEGER,    events TEXT,    wind_dir_degrees INTEGER,    zip_code INTEGER)
# Question: What are the dates with a maximum temperature higher than 85?
#
# ###
#
#
#  SELECT date FROM weather WHERE max_temperature_f  >  85

# %%
df_train.shape
# Out:
# (5944, 2)

# %%
df_test.shape
# Out:
# (1056, 2)

# %% [markdown]
# # Training

# %%
# Put the training data into jsonl format
data = []
for idx, row in df_train.iterrows():
    data.append({"prompt": row["open_ai_prompt"], "completion": row["open_ai_completion"]})

timestr = time.strftime("%Y%m%d-%H%M%S")
with open("spider_open_ai_fine_tuning_" + timestr + ".jsonl", "w") as outfile:
    for obj in data:
        json.dump(obj, outfile)
        outfile.write("\n")
        
print("spider_open_ai_fine_tuning_" + timestr + ".jsonl")
# Out:
# spider_open_ai_fine_tuning_20230126-235556.jsonl

# %%
#!openai tools fine_tunes.prepare_data -f spider_open_ai_fine_tuning_20230126-235556.jsonl
# - There are 6 duplicated prompt-completion sets. These are rows: [1296, 2000, 2097, 2984, 2985, 3799]

# %%
df_train_dedup = df_train.copy()
df_train_dedup = df_train_dedup.drop(df_train.index[[1296, 2000, 2097, 2984, 2985, 3799]])
df_train_dedup[(df_train_dedup['open_ai_prompt'] == df_train_dedup.iloc[1296]['open_ai_prompt']) |
               (df_train_dedup['open_ai_prompt'] == df_train_dedup.iloc[2000]['open_ai_prompt']) |
               (df_train_dedup['open_ai_prompt'] == df_train_dedup.iloc[2097]['open_ai_prompt']) |
               (df_train_dedup['open_ai_prompt'] == df_train_dedup.iloc[2984]['open_ai_prompt']) |
               (df_train_dedup['open_ai_prompt'] == df_train_dedup.iloc[2985]['open_ai_prompt']) |
               (df_train_dedup['open_ai_prompt'] == df_train_dedup.iloc[3799]['open_ai_prompt'])]
# Out:
#                                          open_ai_prompt  \
# 1421  Schema: CREATE TABLE classroom\t(building\t\tv...
# 2344  Schema: CREATE TABLE "Campuses" (\t"Id" INTEGE...
# 2442  Schema: create table Movie(\tmID int primary k...
# 3489  Schema: CREATE TABLE `regions` (  `REGION_ID` ...
# 3490  Schema: CREATE TABLE `regions` (  `REGION_ID` ...
# 4405  Schema: CREATE TABLE Person (  name varchar(20...
#
#                                      open_ai_completion
# 1421   SELECT title FROM course WHERE course_id NOT ...
# 2344   SELECT campus FROM campuses WHERE county  =  ...
# 2442                    SELECT count(*) FROM Reviewer\n
# 3489   SELECT job_id FROM employees GROUP BY job_id ...
# 3490   SELECT job_id FROM employees GROUP BY job_id ...
# 4405          SELECT count(DISTINCT city) FROM Person\n

# %%
# Put the training data into jsonl format
data = []
for idx, row in df_train_dedup.iterrows():
    data.append({"prompt": row["open_ai_prompt"], "completion": row["open_ai_completion"]})

timestr = time.strftime("%Y%m%d-%H%M%S")
with open("spider_open_ai_fine_tuning_" + timestr + ".jsonl", "w") as outfile:
    for obj in data:
        json.dump(obj, outfile)
        outfile.write("\n")
        
print("spider_open_ai_fine_tuning_" + timestr + ".jsonl")
# Out:
# spider_open_ai_fine_tuning_20230126-235844.jsonl

# %%
#!openai tools fine_tunes.prepare_data -f spider_open_ai_fine_tuning_20230126-235844.jsonl

# %%
# !openai api fine_tunes.create -t "spider_open_ai_fine_tuning_20230126-235844.jsonl" -m davinci
# [2023-01-27 00:01:35] Created fine-tune: ft-xv8wuk75QTAbYGVPgAC2vHYh
# [2023-01-27 00:05:10] Fine-tune costs $376.19
# [2023-01-27 00:05:17] Fine-tune enqueued. Queue number: 0
# [2023-01-27 00:05:27] Fine-tune started

# %%
# !openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1672357089,
#       "fine_tuned_model": "davinci:ft-mercator-2022-12-29-23-47-24",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-ZMShnMrnhxzay9r0mXXEcxyI",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 7017,
#           "created_at": 1672357645,
#           "filename": "compiled_results.csv",
#           "id": "file-FdDaGVVXGWC08jN4NwodgYnY",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 3380,
#           "created_at": 1672357089,
#           "filename": "openai_classification_fine_tuning.txt",
#           "id": "file-APupvHFP5OaeEWNg6SVT8uyK",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1672357645,
#       "validation_files": []
#     },
#     {
#       "created_at": 1672359981,
#       "fine_tuned_model": "curie:ft-mercator-2022-12-30-00-29-13",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-Ej8Q7PDuU2mwaFWZ6Pz6Nx3a",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 7137,
#           "created_at": 1672360154,
#           "filename": "compiled_results.csv",
#           "id": "file-rfuxlRqwBKEZ3FKQYU1FhTbE",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 3780,
#           "created_at": 1672359981,
#           "filename": "openai_classification_fine_tuning.jsonl",
#           "id": "file-L3OyASJECTFdDTj9WWdbFyCW",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1672360154,
#       "validation_files": []
#     },
#     {
#       "created_at": 1672361065,
#       "fine_tuned_model": "davinci:ft-mercator-2022-12-30-00-48-03",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-UYqkIaV7CZS9aLfFZ1EVw0GC",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 7070,
#           "created_at": 1672361285,
#           "filename": "compiled_results.csv",
#           "id": "file-OJfSWHvKVsj7hUv8XIKzw109",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 3780,
#           "created_at": 1672361065,
#           "filename": "openai_classification_fine_tuning.jsonl",
#           "id": "file-q6jZNWXC2Qox3FS1PMB0wDy9",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1672361285,
#       "validation_files": []
#     },
#     {
#       "created_at": 1672363107,
#       "fine_tuned_model": "davinci:ft-mercator-2022-12-30-01-27-07",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-CM32gCt2Qt7MaZGvg6C2626j",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 50099,
#           "created_at": 1672363628,
#           "filename": "compiled_results.csv",
#           "id": "file-7gxyT041xSQS9nuBjOqrlfal",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 32328,
#           "created_at": 1672363107,
#           "filename": "openai_classification_fine_tuning.jsonl",
#           "id": "file-hi3zqKcuTO2hMY4Tn3gkNECq",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1672363628,
#       "validation_files": []
#     },
#     {
#       "created_at": 1673633601,
#       "fine_tuned_model": "curie:ft-mercator-2023-01-13-18-58-25",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-ktXHwqMgjQuLOdSsEZEXKy90",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 11017,
#           "created_at": 1673636305,
#           "filename": "compiled_results.csv",
#           "id": "file-g7wzj1pyMxhlF6SKCnWCwLy5",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 888550,
#           "created_at": 1673633600,
#           "filename": "spider_open_ai_fine_tuning.jsonl",
#           "id": "file-HmlGzvAbawZ51iOGs1VxQgKL",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1673636306,
#       "validation_files": []
#     },
#     {
#       "created_at": 1673633730,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-13-21-03-38",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-uvli4ARlKMy5Gy2C5zHHV1eD",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 10941,
#           "created_at": 1673643819,
#           "filename": "compiled_results.csv",
#           "id": "file-gvWI9O3cGLLbzC0WNSgda94t",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 888550,
#           "created_at": 1673633717,
#           "filename": "spider_open_ai_fine_tuning.jsonl",
#           "id": "file-plLUrjyA7M8igrCZtMKFevyV",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1673643822,
#       "validation_files": []
#     },
#     {
#       "created_at": 1673642119,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-13-23-39-57",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-IArp6w0FdYZ2D8msrWTqPhkp",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 10692,
#           "created_at": 1673653199,
#           "filename": "compiled_results.csv",
#           "id": "file-J70Nszr4efYx1gpHS9rqzwIw",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 866650,
#           "created_at": 1673642115,
#           "filename": "spider_short_prompt_open_ai_fine_tuning.jsonl",
#           "id": "file-HonZQBmGAVsESaNYQV8IDLse",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1673653199,
#       "validation_files": []
#     },
#     {
#       "created_at": 1673651109,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-14-01-47-14",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-Ihg26q1fpDVSCF9i8rwVOf4o",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 19961,
#           "created_at": 1673660835,
#           "filename": "compiled_results.csv",
#           "id": "file-7f1VIToPw5gRweQb3UZnAsDD",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 159674,
#           "created_at": 1673651108,
#           "filename": "spider_short_prompt_open_ai_fine_tuning.jsonl",
#           "id": "file-WZz9r1jfHZt6qhsdFS5xMKD6",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1673660836,
#       "validation_files": []
#     },
#     {
#       "created_at": 1673998663,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-18-00-37-55",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-dbeUsmj0k5FG0GnnDMJ3s05c",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 19876,
#           "created_at": 1674002276,
#           "filename": "compiled_results.csv",
#           "id": "file-EHcQOFAFnnr0XMxRYIxWw2w4",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 201213,
#           "created_at": 1673998663,
#           "filename": "spider_open_ai_fine_tuning_20230117-153523.jsonl",
#           "id": "file-hzwl04Vk88WfsnthvJXnSU4t",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674002277,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674006408,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-18-02-13-35",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-B5wO3kuwXoUTGRwpdDVMfbRS",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 69793,
#           "created_at": 1674008016,
#           "filename": "compiled_results.csv",
#           "id": "file-hXDw174L2989gxVJg0749sts",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 430197,
#           "created_at": 1674006408,
#           "filename": "spider_open_ai_fine_tuning_20230117-174446.jsonl",
#           "id": "file-mgqafpnvg6j8iXvK9ZjCtjqN",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674008017,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674159359,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-20-01-20-27",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-LKfUyJnzG8W5P3hBlNp8X6tw",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 20010,
#           "created_at": 1674177628,
#           "filename": "compiled_results.csv",
#           "id": "file-6l7E3rsC9l9pxehssQUfJrgj",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 159674,
#           "created_at": 1674159357,
#           "filename": "spider_open_ai_fine_tuning_20230119-121448.jsonl",
#           "id": "file-4rs0plUEDv2ANaBlGafUunEL",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674177629,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674234261,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-20-22-28-50",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-WNeKmZ7ZDyzyZNEuFUbJiTCa",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 38543,
#           "created_at": 1674253733,
#           "filename": "compiled_results.csv",
#           "id": "file-qjKerKoCFJKUtebBkQ4Q0hqH",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 400626,
#           "created_at": 1674234258,
#           "filename": "spider_open_ai_fine_tuning_20230120-090311.jsonl",
#           "id": "file-rJQKziv2Vks6v0geKfXApwqr",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674253739,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674429255,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-22-23-41-26",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-1k58aqPMZXgfdc2hSGjV1kEs",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 116839,
#           "created_at": 1674430889,
#           "filename": "compiled_results.csv",
#           "id": "file-7HTyRBGf5U21TBfAFSoCrnEs",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 713924,
#           "created_at": 1674429254,
#           "filename": "spider_open_ai_fine_tuning_20230122-151249.jsonl",
#           "id": "file-Oe8qx7yx0pWNfEjjOTjVYDIA",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674430890,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674522358,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-24-03-11-01",
#       "hyperparams": {
#         "batch_size": 4,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-SFqSc9W7TLh8VNBuFJTUROpI",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 196889,
#           "created_at": 1674529864,
#           "filename": "compiled_results.csv",
#           "id": "file-79OSOHwfxTBLcr3bipqIp9wX",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 4631097,
#           "created_at": 1674522357,
#           "filename": "spider_open_ai_fine_tuning_20230123-170330.jsonl",
#           "id": "file-nLxqZpXpRWJOCaahgYaOXCr9",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674529864,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674684018,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-25-23-01-53",
#       "hyperparams": {
#         "batch_size": 4,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-GyrEkJ8jiO1ZgUY25ehrTr1D",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 165504,
#           "created_at": 1674687719,
#           "filename": "compiled_results.csv",
#           "id": "file-u15uDpZx37boj1oXyQgP01z8",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 1267606,
#           "created_at": 1674684018,
#           "filename": "spider_open_ai_fine_tuning_20230125-135903.jsonl",
#           "id": "file-M3os7yWoW7d88gqYIblMXKLR",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674687720,
#       "validation_files": []
#     },
#     {
#       "created_at": 1674806495,
#       "fine_tuned_model": "davinci:ft-mercator-2023-01-27-10-13-07",
#       "hyperparams": {
#         "batch_size": 8,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-xv8wuk75QTAbYGVPgAC2vHYh",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ePmgB4qVo14GgUKdUQci6IGz",
#       "result_files": [
#         {
#           "bytes": 180068,
#           "created_at": 1674814391,
#           "filename": "compiled_results.csv",
#           "id": "file-QKxxEgmzbgD3wZ6hZMzj1TEp",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 8629611,
#           "created_at": 1674806495,
#           "filename": "spider_open_ai_fine_tuning_20230126-235844.jsonl",
#           "id": "file-tXQjUUcBmR062P87pPijhJNN",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1674814392,
#       "validation_files": []
#     }
#   ],
#   "object": "list"
# }

# %% [markdown]
# # Out of Sample Testing

# %%
tmp = df_test.copy()

# tmp['model_response'] = ''
data = []
for idx, row in tmp.iterrows():
    print(idx)
    if row['model_response'] != '':
        print('already completed')
        data.append(row['model_response'])
        continue
    
    new_response = call_model(row, engine="davinci:ft-mercator-2023-01-27-10-13-07")
    data.append(new_response)
    tmp.loc[idx,'model_response'] = new_response
# Out:
# 301
# already completed
# 302
# already completed
# 303
# already completed
# 304
# already completed
# 305
# already completed
# 306
# already completed
# 307
# already completed
# 308
# already completed
# 309
# already completed
# 310
# already completed
# 311
# already completed
# 312
# already completed
# 313
# already completed
# 314
# already completed
# 315
# already completed
# 316
# already completed
# 317
# already completed
# 318
# already completed
# 319
# already completed
# 320
# already completed
# 321
# already completed
# 322
# already completed
# 323
# already completed
# 324
# already completed
# 325
# already completed
# 326
# already completed
# 327
# already completed
# 328
# already completed
# 329
# already completed
# 330
# already completed
# 331
# already completed
# 332
# already completed
# 333
# already completed
# 334
# already completed
# 335
# already completed
# 336
# already completed
# 337
# already completed
# 338
# already completed
# 339
# already completed
# 340
# already completed
# 341
# already completed
# 342
# already completed
# 891
# already completed
# 892
# already completed
# 893
# already completed
# 894
# already completed
# 895
# already completed
# 896
# already completed
# 897
# already completed
# 898
# already completed
# 899
# already completed
# 900
# already completed
# 901
# already completed
# 902
# already completed
# 903
# already completed
# 904
# already completed
# 905
# already completed
# 906
# already completed
# 907
# already completed
# 908
# already completed
# 909
# already completed
# 910
# already completed
# 911
# already completed
# 912
# already completed
# 913
# already completed
# 914
# already completed
# 915
# already completed
# 916
# already completed
# 917
# already completed
# 918
# already completed
# 919
# already completed
# 920
# already completed
# 921
# already completed
# 922
# already completed
# 923
# already completed
# 924
# already completed
# 925
# already completed
# 926
# already completed
# 927
# already completed
# 928
# already completed
# 929
# already completed
# 930
# already completed
# 931
# already completed
# 932
# already completed
# 1110
# already completed
# 1111
# already completed
# 1112
# already completed
# 1113
# already completed
# 1114
# already completed
# 1115
# already completed
# 1116
# already completed
# 1117
# already completed
# 1118
# already completed
# 1119
# already completed
# 1120
# already completed
# 1121
# already completed
# 1122
# already completed
# 1123
# already completed
# 1124
# already completed
# 1125
# already completed
# 1126
# already completed
# 1127
# already completed
# 1128
# already completed
# 1129
# already completed
# 1130
# already completed
# 1131
# already completed
# 1132
# already completed
# 1133
# already completed
# 1134
# already completed
# 1135
# already completed
# 1136
# already completed
# 1137
# already completed
# 1138
# already completed
# 1139
# already completed
# 1140
# already completed
# 1141
# already completed
# 1142
# already completed
# 1143
# already completed
# 1144
# already completed
# 1145
# already completed
# 1146
# already completed
# 1147
# already completed
# 1148
# already completed
# 1149
# already completed
# 1689
# already completed
# 1690
# already completed
# 1691
# already completed
# 1692
# already completed
# 1693
# already completed
# 1694
# already completed
# 1695
# already completed
# 1696
# already completed
# 1697
# already completed
# 1698
# already completed
# 1699
# already completed
# 1700
# already completed
# 1701
# already completed
# 1702
# already completed
# 1703
# already completed
# 1704
# already completed
# 1705
# already completed
# 1706
# already completed
# 1707
# already completed
# 1708
# already completed
# 1709
# already completed
# 1710
# already completed
# 1711
# already completed
# 1712
# already completed
# 1713
# already completed
# 1714
# already completed
# 1715
# already completed
# 1716
# already completed
# 1717
# already completed
# 1718
# already completed
# 1719
# already completed
# 1720
# already completed
# 1721
# already completed
# 1722
# already completed
# 1723
# already completed
# 1724
# already completed
# 1725
# already completed
# 1726
# already completed
# 1727
# already completed
# 1728
# already completed
# 1729
# already completed
# 1730
# already completed
# 1731
# already completed
# 1732
# already completed
# 1733
# already completed
# 1734
# already completed
# 1735
# already completed
# 2039
# already completed
# 2040
# already completed
# 2041
# already completed
# 2042
# already completed
# 2043
# already completed
# 2044
# already completed
# 2045
# already completed
# 2046
# already completed
# 2047
# already completed
# 2048
# already completed
# 2049
# already completed
# 2050
# already completed
# 2051
# already completed
# 2052
# already completed
# 2053
# already completed
# 2054
# already completed
# 2055
# already completed
# 2056
# already completed
# 2057
# already completed
# 2058
# already completed
# 2059
# already completed
# 2060
# already completed
# 2061
# already completed
# 2062
# already completed
# 2063
# already completed
# 2064
# already completed
# 2065
# already completed
# 2066
# already completed
# 2067
# already completed
# 2068
# already completed
# 2069
# already completed
# 2070
# already completed
# 2071
# already completed
# 2072
# already completed
# 2073
# already completed
# 2074
# already completed
# 2075
# already completed
# 2076
# already completed
# 2077
# already completed
# 2078
# already completed
# 2079
# already completed
# 2080
# already completed
# 2081
# already completed
# 2082
# already completed
# 2131
# already completed
# 2132
# already completed
# 2133
# already completed
# 2134
# already completed
# 2135
# already completed
# 2136
# already completed
# 2137
# already completed
# 2153
# already completed
# 2154
# already completed
# 2155
# already completed
# 2156
# already completed
# 2157
# already completed
# 2158
# already completed
# 2159
# already completed
# 2160
# already completed
# 2161
# already completed
# 2162
# already completed
# 2163
# already completed
# 2164
# already completed
# 2165
# already completed
# 2166
# already completed
# 2167
# already completed
# 2168
# already completed
# 2169
# already completed
# 2170
# already completed
# 2171
# already completed
# 2172
# already completed
# 2173
# already completed
# 2174
# already completed
# 2175
# already completed
# 2176
# already completed
# 2177
# already completed
# 2178
# already completed
# 2179
# already completed
# 2180
# already completed
# 2181
# already completed
# 2182
# already completed
# 2183
# already completed
# 2184
# already completed
# 2185
# already completed
# 2186
# already completed
# 2187
# already completed
# 2188
# already completed
# 2189
# already completed
# 2190
# already completed
# 2191
# already completed
# 2192
# already completed
# 2193
# already completed
# 2194
# already completed
# 2195
# already completed
# 2196
# already completed
# 2197
# already completed
# 2198
# already completed
# 2199
# already completed
# 2200
# already completed
# 2201
# already completed
# 2202
# already completed
# 2203
# already completed
# 2204
# already completed
# 2205
# already completed
# 2206
# already completed
# 2207
# already completed
# 2208
# already completed
# 2209
# already completed
# 2210
# already completed
# 2211
# already completed
# 2212
# already completed
# 2213
# already completed
# 2214
# already completed
# 2215
# already completed
# 2216
# already completed
# 2217
# already completed
# 2218
# already completed
# 2219
# already completed
# 2220
# already completed
# 2221
# already completed
# 2222
# already completed
# 2223
# already completed
# 2224
# already completed
# 2225
# already completed
# 2226
# already completed
# 2227
# already completed
# 2228
# already completed
# 2229
# already completed
# 2230
# already completed
# 2231
# already completed
# 2232
# already completed
# 2263
# already completed
# 2264
# already completed
# 2265
# already completed
# 2266
# already completed
# 2267
# already completed
# 2268
# already completed
# 2269
# already completed
# 2270
# already completed
# 2271
# already completed
# 2272
# already completed
# 2273
# already completed
# 2274
# already completed
# 2275
# already completed
# 2276
# already completed
# 2277
# already completed
# 2278
# already completed
# 2279
# already completed
# 2280
# already completed
# 2281
# already completed
# 2282
# already completed
# 2283
# already completed
# 2284
# already completed
# 2285
# already completed
# 2286
# already completed
# 2287
# already completed
# 2288
# already completed
# 2289
# already completed
# 2290
# already completed
# 2291
# already completed
# 2292
# already completed
# 2293
# already completed
# 2294
# already completed
# 2295
# already completed
# 2296
# already completed
# 2297
# already completed
# 2298
# already completed
# 2299
# already completed
# 2300
# already completed
# 2301
# already completed
# 2302
# already completed
# 2532
# already completed
# 2533
# already completed
# 2534
# already completed
# 2535
# already completed
# 2536
# already completed
# 2537
# already completed
# 2538
# already completed
# 2539
# already completed
# 2540
# already completed
# 2541
# already completed
# 2542
# already completed
# 2543
# already completed
# 2544
# already completed
# 2545
# already completed
# 2546
# already completed
# 2547
# already completed
# 2548
# already completed
# 2549
# already completed
# 2550
# already completed
# 2551
# already completed
# 2552
# already completed
# 2553
# already completed
# 2554
# already completed
# 2555
# already completed
# 2556
# already completed
# 2557
# already completed
# 2558
# already completed
# 2559
# already completed
# 2560
# already completed
# 2561
# already completed
# 2562
# already completed
# 2563
# already completed
# 2564
# already completed
# 2565
# already completed
# 2566
# already completed
# 2567
# already completed
# 2568
# already completed
# 2569
# already completed
# 2570
# already completed
# 2571
# already completed
# 2690
# already completed
# 2691
# already completed
# 2692
# already completed
# 2693
# already completed
# 2694
# already completed
# 2695
# already completed
# 2696
# already completed
# 2697
# already completed
# 2698
# already completed
# 2699
# already completed
# 2700
# already completed
# 2701
# already completed
# 2702
# already completed
# 2703
# already completed
# 2704
# already completed
# 2705
# already completed
# 2706
# already completed
# 2707
# already completed
# 2708
# already completed
# 2709
# already completed
# 2710
# already completed
# 2711
# already completed
# 2712
# already completed
# 2713
# already completed
# 2714
# already completed
# 2715
# already completed
# 2716
# already completed
# 2717
# already completed
# 2718
# already completed
# 2719
# already completed
# 2720
# already completed
# 2721
# already completed
# 2722
# already completed
# 2723
# already completed
# 2724
# already completed
# 2725
# already completed
# 2726
# already completed
# 2727
# already completed
# 2728
# already completed
# 2729
# already completed
# 2730
# already completed
# 2731
# already completed
# 2732
# already completed
# 2733
# already completed
# 2802
# already completed
# 2803
# already completed
# 2804
# already completed
# 2805
# already completed
# 2806
# already completed
# 2807
# already completed
# 2808
# already completed
# 2809
# already completed
# 2810
# already completed
# 2811
# already completed
# 2812
# already completed
# 2813
# already completed
# 2814
# already completed
# 2815
# already completed
# 2816
# already completed
# 2817
# already completed
# 2818
# already completed
# 2819
# already completed
# 3086
# already completed
# 3087
# already completed
# 3088
# already completed
# 3089
# already completed
# 3090
# already completed
# 3091
# already completed
# 3092
# already completed
# 3093
# already completed
# 3094
# already completed
# 3095
# already completed
# 3096
# already completed
# 3097
# already completed
# 3098
# already completed
# 3099
# already completed
# 3100
# already completed
# 3101
# already completed
# 3102
# already completed
# 3103
# already completed
# 3104
# already completed
# 3105
# already completed
# 3106
# already completed
# 3107
# already completed
# 3108
# already completed
# 3109
# already completed
# 3110
# already completed
# 3111
# already completed
# 3112
# already completed
# 3113
# already completed
# 3114
# already completed
# 3115
# already completed
# 3116
# already completed
# 3117
# already completed
# 3118
# already completed
# 3119
# already completed
# 3120
# already completed
# 3121
# already completed
# 3122
# already completed
# 3123
# already completed
# 3124
# already completed
# 3125
# already completed
# 3389
# already completed
# 3390
# already completed
# 3391
# already completed
# 3392
# already completed
# 3393
# already completed
# 3394
# already completed
# 3395
# already completed
# 3396
# already completed
# 3397
# already completed
# 3398
# already completed
# 3399
# already completed
# 3400
# already completed
# 3401
# already completed
# 3402
# already completed
# 3403
# already completed
# 3404
# already completed
# 3529
# already completed
# 3530
# already completed
# 3531
# already completed
# 3532
# already completed
# 3533
# already completed
# 3534
# already completed
# 3535
# already completed
# 3536
# already completed
# 3537
# already completed
# 3538
# already completed
# 3539
# already completed
# 3540
# already completed
# 3541
# already completed
# 3542
# already completed
# 3543
# already completed
# 3544
# already completed
# 3545
# already completed
# 3546
# already completed
# 3547
# already completed
# 3548
# already completed
# 3549
# already completed
# 3550
# already completed
# 3551
# already completed
# 3552
# already completed
# 3553
# already completed
# 3554
# already completed
# 3555
# already completed
# 3556
# already completed
# 3557
# already completed
# 3558
# already completed
# 3559
# already completed
# 3560
# already completed
# 3561
# already completed
# 3562
# already completed
# 3563
# already completed
# 3564
# already completed
# 3565
# already completed
# 3566
# already completed
# 3567
# already completed
# 3568
# already completed
# 3569
# already completed
# 3570
# already completed
# 3571
# already completed
# 3572
# already completed
# 3573
# already completed
# 3574
# already completed
# 3575
# already completed
# 3576
# already completed
# 3577
# already completed
# 3578
# already completed
# 3579
# already completed
# 3580
# already completed
# 3581
# already completed
# 3582
# already completed
# 3583
# already completed
# 3584
# already completed
# 3585
# already completed
# 3586
# already completed
# 3587
# already completed
# 3588
# already completed
# 3589
# already completed
# 3590
# already completed
# 3591
# already completed
# 3592
# already completed
# 3593
# already completed
# 3594
# already completed
# 3595
# already completed
# 3596
# already completed
# 3597
# already completed
# 3598
# already completed
# 3599
# already completed
# 3600
# already completed
# 3601
# already completed
# 3602
# already completed
# 3603
# already completed
# 3604
# already completed
# 3605
# already completed
# 3606
# already completed
# 3607
# already completed
# 3608
# already completed
# 3609
# already completed
# 3610
# already completed
# 3611
# already completed
# 3612
# already completed
# 3613
# already completed
# 3614
# already completed
# 3615
# already completed
# 3616
# already completed
# 3617
# already completed
# 3618
# already completed
# 3619
# already completed
# 3620
# already completed
# 3621
# already completed
# 3622
# already completed
# 3623
# already completed
# 3624
# already completed
# 3625
# already completed
# 3626
# already completed
# 3627
# already completed
# 3628
# already completed
# 4583
# already completed
# 4584
# already completed
# 4585
# already completed
# 4586
# already completed
# 4587
# already completed
# 4588
# already completed
# 4589
# already completed
# 4590
# already completed
# 4591
# already completed
# 4592
# already completed
# 4593
# already completed
# 4594
# already completed
# 4595
# already completed
# 4596
# already completed
# 4597
# already completed
# 4598
# already completed
# 4599
# already completed
# 4600
# already completed
# 4601
# already completed
# 4602
# already completed
# 4603
# already completed
# 4604
# already completed
# 4605
# already completed
# 4606
# already completed
# 4607
# already completed
# 4608
# already completed
# 4609
# already completed
# 4610
# already completed
# 4611
# already completed
# 4612
# already completed
# 4613
# already completed
# 4614
# already completed
# 4615
# already completed
# 4616
# already completed
# 4617
# already completed
# 4618
# already completed
# 4619
# already completed
# 5090
# already completed
# 5091
# already completed
# 5092
# already completed
# 5093
# already completed
# 5094
# already completed
# 5095
# already completed
# 5096
# already completed
# 5097
# already completed
# 5098
# already completed
# 5099
# already completed
# 5100
# already completed
# 5101
# already completed
# 5102
# already completed
# 5103
# already completed
# 5104
# already completed
# 5105
# already completed
# 5106
# already completed
# 5107
# already completed
# 5108
# already completed
# 5109
# already completed
# 5110
# already completed
# 5111
# already completed
# 5112
# already completed
# 5113
# already completed
# 5114
# already completed
# 5115
# already completed
# 5116
# already completed
# 5117
# already completed
# 5118
# already completed
# 5119
# already completed
# 5120
# already completed
# 5121
# already completed
# 5122
# already completed
# 5123
# already completed
# 5124
# already completed
# 5125
# already completed
# 5126
# already completed
# 5127
# already completed
# 5128
# already completed
# 5129
# already completed
# 5130
# already completed
# 5131
# already completed
# 5132
# already completed
# 5133
# already completed
# 5134
# already completed
# 5135
# already completed
# 5136
# already completed
# 5137
# already completed
# 5138
# already completed
# 5139
# already completed
# 5140
# already completed
# 5141
# already completed
# 5142
# already completed
# 5143
# already completed
# 5144
# already completed
# 5145
# already completed
# 5146
# already completed
# 5147
# already completed
# 5148
# already completed
# 5149
# already completed
# 5150
# already completed
# 5151
# already completed
# 5152
# already completed
# 5153
# already completed
# 5154
# already completed
# 5155
# already completed
# 5156
# already completed
# 5157
# already completed
# 5158
# already completed
# 5159
# already completed
# 5160
# already completed
# 5161
# already completed
# 5162
# already completed
# 5163
# already completed
# 5164
# already completed
# 5165
# already completed
# 5166
# already completed
# 5167
# already completed
# 5168
# already completed
# 5169
# already completed
# 5170
# already completed
# 5171
# already completed
# 5400
# already completed
# 5401
# already completed
# 5402
# already completed
# 5403
# already completed
# 5404
# already completed
# 5405
# already completed
# 5406
# already completed
# 5407
# already completed
# 5408
# already completed
# 5409
# already completed
# 5410
# already completed
# 5411
# already completed
# 5412
# already completed
# 5413
# already completed
# 5414
# already completed
# 5415
# already completed
# 5416
# already completed
# 5417
# already completed
# 5418
# already completed
# 5419
# already completed
# 5420
# already completed
# 5421
# already completed
# 5422
# already completed
# 5423
# already completed
# 5424
# already completed
# 5425
# already completed
# 5426
# already completed
# 5427
# already completed
# 5428
# already completed
# 5429
# already completed
# 5430
# already completed
# 5431
# already completed
# 5432
# already completed
# 5433
# already completed
# 5434
# already completed
# 5435
# already completed
# 5436
# already completed
# 5437
# already completed
# 5438
# already completed
# 5439
# already completed
# 5440
# already completed
# 5441
# already completed
# 5442
# already completed
# 5443
# already completed
# 5653
# already completed
# 5654
# already completed
# 5655
# already completed
# 5656
# already completed
# 5657
# already completed
# 5658
# already completed
# 5659
# already completed
# 5660
# already completed
# 5661
# already completed
# 5662
# already completed
# 5663
# already completed
# 5664
# already completed
# 5665
# already completed
# 5666
# already completed
# 5667
# already completed
# 5969
# already completed
# 5970
# already completed
# 5971
# already completed
# 5972
# already completed
# 5973
# already completed
# 5974
# already completed
# 5975
# already completed
# 5976
# already completed
# 5977
# already completed
# 5978
# already completed
# 5979
# already completed
# 5980
# already completed
# 5981
# already completed
# 5982
# already completed
# 5983
# already completed
# 5984
# already completed
# 5985
# already completed
# 5986
# already completed
# 5987
# already completed
# 5988
# already completed
# 5989
# already completed
# 5990
# already completed
# 5991
# already completed
# 5992
# already completed
# 5993
# already completed
# 5994
# already completed
# 5995
# already completed
# 5996
# already completed
# 5997
# already completed
# 5998
# already completed
# 5999
# already completed
# 6000
# already completed
# 6001
# already completed
# 6002
# already completed
# 6003
# already completed
# 6004
# already completed
# 6005
# already completed
# 6006
# already completed
# 6007
# already completed
# 6008
# already completed
# 6009
# already completed
# 6010
# already completed
# 6011
# already completed
# 6012
# already completed
# 6013
# already completed
# 6014
# already completed
# 6015
# already completed
# 6016
# already completed
# 6017
# already completed
# 6018
# already completed
# 6019
# already completed
# 6020
# already completed
# 6021
# already completed
# 6022
# already completed
# 6023
# already completed
# 6024
# already completed
# 6025
# already completed
# 6026
# already completed
# 6027
# already completed
# 6028
# already completed
# 6029
# already completed
# 6030
# already completed
# 6031
# already completed
# 6032
# already completed
# 6033
# already completed
# 6034
# already completed
# 6035
# already completed
# 6036
# already completed
# 6037
# already completed
# 6038
# already completed
# 6039
# already completed
# 6040
# already completed
# 6041
# already completed
# 6042
# already completed
# 6043
# already completed
# 6044
# already completed
# 6045
# already completed
# 6046
# already completed
# 6047
# already completed
# 6048
# already completed
# 6049
# already completed
# 6050
# already completed
# 6051
# already completed
# 6052
# already completed
# 6053
# already completed
# 6054
# already completed
# 6203
# already completed
# 6204
# already completed
# 6205
# already completed
# 6206
# already completed
# 6207
# already completed
# 6208
# already completed
# 6209
# already completed
# 6210
# already completed
# 6211
# already completed
# 6212
# already completed
# 6213
# already completed
# 6214
# already completed
# 6215
# already completed
# 6216
# already completed
# 6217
# already completed
# 6218
# already completed
# 6219
# already completed
# 6622
# already completed
# 6623
# already completed
# 6624
# already completed
# 6625
# already completed
# 6626
# already completed
# 6627
# already completed
# 6628
# already completed
# 6629
# already completed
# 6630
# already completed
# 6631
# already completed
# 6632
# already completed
# 6633
# already completed
# 6634
# already completed
# 6635
# already completed
# 6636
# already completed
# 6637
# already completed
# 6638
# already completed
# 6639
# already completed
# 6640
# already completed
# 6641
# already completed
# 6642
# already completed
# 6643
# already completed
# 6644
# already completed
# 6645
# already completed
# 6646
# already completed
# 6647
# already completed
# 6648
# already completed
# 6649
# already completed
# 6650
# already completed
# 6651
# already completed
# 6652
# already completed
# 6653
# already completed
# 6654
# already completed
# 6655
# already completed
# 6656
# already completed
# 6657
# already completed
# 6658
# already completed
# 6659
# already completed
# 6660
# already completed
# 6661
# already completed
# 6662
# already completed
# 6663
# already completed
# 6664
# already completed
# 6665
# already completed
# 6666
# already completed
# 6667
# already completed
# 6668
# already completed
# 6669
# already completed
# 6670
# already completed
# 6671
# already completed
# 6672
# already completed
# 6673
# already completed
# 6674
# already completed
# 6675
# already completed
# 6676
# already completed
# 6677
# already completed
# 6678
# already completed
# 6679
# already completed
# 6680
# already completed
# 6681
# already completed
# 6682
# already completed
# 6683
# already completed
# 6684
# already completed
# 6685
# already completed
# 6686
#  SELECT T1.zip_postcode FROM addresses AS T1 JOIN customers AS T2 ON T1.address_id  =  T2.customer_address_id WHERE T2.first_name  =  "Carole" AND T2.last_name  =  "Bernhard"
# 6687
#  SELECT t1.zip_postcode FROM addresses AS t1 JOIN customers AS t2 ON t1.address_id  =  t2.customer_address_id WHERE t2.first_name  =  "Carole" AND t2.last_name  =  "Bernhard"
# 6688
#  SELECT t3.city FROM customers AS t1 JOIN customer_addresses AS t2 ON t1.customer_address_id  =  t2.address_id JOIN addresses AS t3 ON t2.address_id  =  t3.address_id GROUP BY t3.city ORDER BY count(*) DESC LIMIT 1
# 6689
#  SELECT t3.city FROM customers AS t1 JOIN addresses AS t2 ON t1.customer_address_id  =  t2.address_id JOIN addresses AS t3 ON t2.address_id  =  t3.address_id GROUP BY t3.city ORDER BY count(*) DESC LIMIT 1
# 6690
#  SELECT sum(t1.amount_payment) FROM customer_payments AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t2.first_name  =  "Carole" AND t2.last_name  =  "Bernhard"
# 6691
#  SELECT sum(t1.amount_payment) FROM customer_payments AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t2.first_name  =  "Carole" AND t2.last_name  =  "Bernhard"
# 6692
#  SELECT count(*) FROM customers WHERE customer_id NOT IN (SELECT customer_id FROM customer_payments)
# 6693
#  SELECT count(*) FROM customers WHERE customer_id NOT IN (SELECT customer_id FROM customer_payments)
# 6694
#  SELECT T1.first_name ,  T1.last_name FROM customers AS T1 JOIN customer_payments AS T2 ON T1.customer_id  =  T2.customer_id GROUP BY T2.customer_id HAVING count(*)  >  2
# 6695
#  SELECT T1.first_name ,  T1.last_name FROM customers AS T1 JOIN customer_payments AS T2 ON T1.customer_id  =  T2.customer_id GROUP BY T2.customer_id HAVING count(*)  >  2
# 6696
#  SELECT payment_method_code ,  count(*) FROM Customer_payments GROUP BY payment_method_code
# 6697
#  SELECT payment_method_code ,  count(*) FROM customer_payments GROUP BY payment_method_code
# 6698
#  SELECT count(*) FROM lessons WHERE lesson_status_code  =  'Cancelled'
# 6699
#  SELECT count(*) FROM lessons WHERE lesson_status_code  =  'cancelled'
# 6700
#  SELECT T1.lesson_id FROM Lessons AS T1 JOIN Staff AS T2 ON T1.staff_id  =  T2.staff_id WHERE T2.first_name  =  "Janessa" AND T2.last_name  =  "Sawayn" AND T2.nickname LIKE "%s%"
# 6701
#  SELECT T1.lesson_id FROM Lessons AS T1 JOIN Staff AS T2 ON T1.staff_id  =  T2.staff_id JOIN Staff AS T3 ON T2.staff_id  =  T3.staff_id WHERE T3.nickname LIKE '%s%'
# 6702
#  SELECT count(*) FROM staff AS T1 JOIN lessons AS T2 ON T1.staff_id  =  T2.staff_id WHERE T1.first_name LIKE '%a%'
# 6703
#  SELECT count(*) FROM lessons AS T1 JOIN staff AS T2 ON T1.staff_id  =  T2.staff_id WHERE T2.first_name LIKE '%a%'
# 6704
#  SELECT sum(T2.lesson_time) FROM customers AS T1 JOIN lessons AS T2 ON T1.customer_id  =  T2.staff_id WHERE T1.first_name  =  "Janessa" AND T1.last_name  =  "Sawayn"
# 6705
#  SELECT sum(t1.lesson_time) FROM lessons AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id JOIN staff AS t3 ON t1.staff_id  =  t3.staff_id WHERE t3.first_name  =  "Janessa" AND t3.last_name  =  "Sawayn"
# 6706
#  SELECT avg(price) FROM lessons AS T1 JOIN customers AS T2 ON T1.customer_id  =  T2.customer_id WHERE first_name  =  "Janessa" AND last_name  =  "Sawayn"
# 6707
#  SELECT avg(price) FROM lessons AS T1 JOIN customers AS T2 ON T1.customer_id  =  T2.customer_id WHERE T2.first_name  =  "Janessa" AND T2.last_name  =  "Sawayn"
# 6708
#  SELECT count(*) FROM customers AS T1 JOIN lessons AS T2 ON T1.customer_id  =  T2.customer_id WHERE T1.first_name  =  "Ray"
# 6709
#  SELECT count(*) FROM customers AS T1 JOIN lessons AS T2 ON T1.customer_id  =  T2.customer_id WHERE T1.first_name  =  "Ray"
# 6710
#  SELECT DISTINCT T1.last_name FROM customers AS T1 JOIN staff AS T2 ON T1.customer_id  =  T2.staff_id
# 6711
#  SELECT DISTINCT last_name FROM staff UNION SELECT DISTINCT last_name FROM customers
# 6712
#  SELECT first_name FROM staff WHERE staff_id NOT IN (SELECT staff_id FROM lessons)
# 6713
#  SELECT first_name FROM staff WHERE staff_id NOT IN (SELECT staff_id FROM lessons)
# 6714
#  SELECT t1.vehicle_id ,  t2.vehicle_details FROM vehicles AS t1 JOIN lessons AS t2 ON t1.vehicle_id  =  t2.vehicle_id GROUP BY t2.vehicle_id ORDER BY sum(price) DESC LIMIT 1
# 6803
#  SELECT name FROM airports WHERE city  =  "Goroka"
# 6804
#  SELECT name FROM airports WHERE city  =  "Goroka"
# 6805
#  SELECT T1.name ,  T1.city ,  T1.country ,  T1.elevation FROM airports AS T1 JOIN airports AS T2 ON T1.apid  =  T2.apid WHERE T2.city  =  "New York"
# 6806
#  SELECT name ,  city ,  country ,  elevation FROM airports WHERE city  =  "New York"
# 6807
#  SELECT count(*) FROM airlines
# 6808
#  SELECT count(*) FROM airlines
# 6809
#  SELECT count(*) FROM airlines WHERE country  =  "Russia"
# 6810
#  SELECT count(*) FROM airlines WHERE country  =  "Russia"
# 6811
#  SELECT max(elevation) FROM airports WHERE country  =  "Iceland"
# 6812
#  SELECT max(elevation) FROM airports WHERE country  =  "Iceland"
# 6813
#  SELECT name FROM airports WHERE country  =  "Cuba" OR country  =  "Argentina"
# 6814
#  SELECT name FROM airports WHERE country  =  "Cuba" OR country  =  "Argentina"
# 6815
#  SELECT country FROM airlines WHERE name LIKE 'Orbit%'
# 6816
#  SELECT country FROM airlines WHERE name LIKE "Orbit%"
# 6817
#  SELECT name FROM airports WHERE elevation BETWEEN -50 AND 50
# 6818
#  SELECT name FROM airports WHERE elevation BETWEEN -50 AND 50
# 6819
#  SELECT country FROM airports ORDER BY elevation DESC LIMIT 1
# 6820
#  SELECT T1.country FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.dst_apid ORDER BY T1.elevation DESC LIMIT 1
# 6821
#  SELECT count(*) FROM airports WHERE name LIKE "%International%"
# 6822
#  SELECT count(*) FROM airports WHERE name LIKE "%Interanation%"
# 6823
#  SELECT count(DISTINCT city) FROM airports WHERE country  =  "Greenland"
# 6824
#  SELECT count(*) FROM airports WHERE country  =  "Greenland"
# 6825
#  SELECT count(*) FROM airlines AS T1 JOIN routes AS T2 ON T1.alid  =  T2.airline WHERE T1.name  =  "American Airlines"
# 6826
#  SELECT count(*) FROM routes WHERE airline  =  "American"
# 6827
#  SELECT count(*) FROM routes AS T1 JOIN airports AS T2 ON T1.dst_apid  =  T2.apid WHERE T2.country  =  "Canada"
# 6828
#  SELECT count(*) FROM routes AS T1 JOIN airports AS T2 ON T1.dst_apid  =  T2.apid WHERE T2.country  =  "Canada"
# 6829
#  SELECT name ,  city ,  country FROM airports ORDER BY elevation LIMIT 1
# 6830
#  SELECT name ,  city ,  country FROM airports ORDER BY elevation LIMIT 1
# 6831
#  SELECT name ,  city ,  country FROM airports ORDER BY y DESC LIMIT 1
# 6832
#  SELECT name ,  city ,  country FROM airports ORDER BY elevation DESC LIMIT 1
# 6833
#  SELECT T1.name ,  T1.city FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.dst_apid GROUP BY T2.dst_ap ORDER BY count(*) DESC LIMIT 1
# 6834
#  SELECT T1.name ,  T1.city FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.dst_apid GROUP BY T2.dst_ap ORDER BY count(*) DESC LIMIT 1
# 6835
#  SELECT T1.name FROM airlines AS T1 JOIN routes AS T2 ON T1.alid  =  T2.alid GROUP BY T2.alid ORDER BY count(*) DESC LIMIT 10
# 6836
#  SELECT T2.name FROM routes AS T1 JOIN airlines AS T2 ON T1.airline  =  T2.alid GROUP BY T1.airline ORDER BY count(*) DESC LIMIT 10
# 6837
#  SELECT T1.name ,  T1.city FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.src_apid GROUP BY T2.src_apid ORDER BY count(*) DESC LIMIT 1
# 6838
#  SELECT T1.name ,  T1.city FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.src_apid GROUP BY T2.src_apid ORDER BY count(*) DESC LIMIT 1
# 6839
#  SELECT count(*) FROM routes AS T1 JOIN airlines AS T2 ON T1.alid  =  T2.alid WHERE T2.name  =  "American Airlines"
# 6840
#  SELECT count(*) FROM routes AS T1 JOIN airlines AS T2 ON T1.src_apid  =  T2.alid WHERE T2.name  =  "American Airlines"
# 6841
#  SELECT country FROM airlines GROUP BY country ORDER BY count(*) DESC LIMIT 1
# 6842
#  SELECT country FROM airlines GROUP BY country ORDER BY count(*) DESC LIMIT 1
# 6843
#  SELECT country FROM airlines WHERE active  =  "Y" GROUP BY country ORDER BY count(*) DESC LIMIT 1
# 6844
#  SELECT country FROM airlines WHERE active  =  "Y" GROUP BY country ORDER BY count(*) DESC LIMIT 1
# 6845
#  SELECT country ,  count(*) FROM airlines GROUP BY country ORDER BY count(*) DESC
# 6846
#  SELECT count(*) ,  country FROM airlines GROUP BY country ORDER BY count(*) DESC
# 6847
#  SELECT country ,  count(*) FROM airports GROUP BY country ORDER BY count(*) DESC
# 6848
#  SELECT country ,  count(*) FROM airports GROUP BY country ORDER BY count(*) DESC
# 6849
#  SELECT city ,  count(*) FROM airports WHERE country  =  "United States" GROUP BY city ORDER BY count(*) DESC
# 6850
#  SELECT count(*) ,  city FROM airports WHERE country  =  "United States" GROUP BY city ORDER BY count(*) DESC
# 6851
#  SELECT city FROM airports WHERE country  =  "United States" GROUP BY city HAVING count(*)  >  3
# 6852
#  SELECT count(*) FROM airports WHERE country  =  "United States" AND count(*)  >  3
# 6853
#  SELECT count(*) FROM airports WHERE name LIKE "%%" GROUP BY name HAVING count(*)  >  3
# 6854
#  SELECT count(*) FROM airports WHERE city LIKE "%%" GROUP BY city
# 6855
#  SELECT count(*) ,  name FROM airports GROUP BY name HAVING count(*)  >  1
# 6856
#  SELECT count(*) ,  name FROM airports GROUP BY name HAVING count(*)  >  1
# 6857
#  SELECT city FROM airports GROUP BY city HAVING count(*)  >  2 ORDER BY count(*) DESC
# 6858
#  SELECT city FROM airports GROUP BY city HAVING count(*)  >  2 ORDER BY count(*) DESC
# 6859
#  SELECT count(*) ,  T1.src_ap ,  T1.dst_ap FROM routes AS T1 JOIN airports AS T2 ON T1.dst_apid  =  T2.apid GROUP BY T1.src_ap
# 6860
#  SELECT T1.name ,  count(*) FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.src_apid GROUP BY T2.src_apid
# 6861
#  SELECT src_ap ,  count(*) FROM routes GROUP BY src_ap ORDER BY count(*) DESC
# 6862
#  SELECT T1.name ,  count(*) FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.src_apid GROUP BY T2.src_apid ORDER BY count(*) DESC LIMIT 1
# 6863
#  SELECT country ,  avg(elevation) FROM airports GROUP BY country
# 6864
#  SELECT country ,  avg(elevation) FROM airports GROUP BY country
# 6865
#  SELECT name FROM airports GROUP BY name HAVING count(*)  =  2
# 6866
#  SELECT name FROM airports GROUP BY name HAVING count(*)  =  2
# 6867
#  SELECT country ,  count(*) FROM routes AS T1 JOIN airlines AS T2 ON T1.alid  =  T2.alid GROUP BY T1.alid ,  T2.name
# 6868
#  SELECT country ,  alid ,  count(*) FROM routes GROUP BY country ,  alid
# 6869
#  SELECT count(*) FROM routes AS T1 JOIN airports AS T2 ON T1.dst_apid  =  T2.apid WHERE T2.country  =  "Italy"
# 6870
#  SELECT count(*) FROM routes AS T1 JOIN airports AS T2 ON T1.dst_apid  =  T2.apid WHERE T2.name  =  "Italy"
# 6871
#  SELECT count(*) FROM routes AS T1 JOIN airlines AS T2 ON T1.src_apid  =  T2.alid WHERE T1.dst_ap  =  'IT' AND T2.name  =  'American Airlines'
# 6872
#  SELECT count(*) FROM routes AS T1 JOIN airlines AS T2 ON T1.alid  =  T2.alid WHERE T1.dst_ap  =  "ITA" AND T2.name  =  "American Airlines"
# 6873
#  SELECT count(*) FROM routes WHERE dst_ap = "JFK"
# 6874
#  SELECT count(*) FROM routes WHERE dst_apid  =  "JFK"
# 6875
#  SELECT count(*) FROM routes AS T1 JOIN airports AS T2 ON T1.src_apid  =  T2.apid JOIN airlines AS T3 ON T1.src_apid  =  T3.alid WHERE T2.name  =  "United States" AND T3.name  =  "Canada"
# 6876
#  SELECT count(*) FROM routes AS T1 JOIN airports AS T2 ON T1.dst_apid  =  T2.apid JOIN airlines AS T3 ON T1.src_apid  =  T3.alid WHERE T2.name  =  "United States" AND T3.name  =  "Canada"
# 6877
#  SELECT T1.rid FROM routes AS T1 JOIN airports AS T2 ON T1.src_apid  =  T2.apid JOIN airlines AS T3 ON T1.dst_apid  =  T3.alid WHERE T2.name LIKE "Chicago%" AND T3.name LIKE "United States%"
# 6878
#  SELECT T1.rid FROM routes AS T1 JOIN airports AS T2 ON T1.src_apid  =  T2.apid JOIN airlines AS T3 ON T1.dst_apid  =  T3.alid WHERE T2.name  =  "United States"
# 6879
#  SELECT T1.name FROM airlines AS T1 JOIN routes AS T2 ON T1.alid  =  T2.airline GROUP BY T2.airline ORDER BY count(*) DESC LIMIT 1
# 6880
#  SELECT T1.name FROM airlines AS T1 JOIN routes AS T2 ON T1.alid  =  T2.airline GROUP BY T2.airline ORDER BY count(*) DESC LIMIT 1
# 6881
#  SELECT src_ap FROM routes WHERE rid IN (SELECT T1.rid FROM routes AS T1 JOIN airlines AS T2 ON T1.src_apid  =  T2.alid WHERE T2.country  =  "China") ORDER BY count(*) DESC LIMIT 1
# 6882
#  SELECT T1.name FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.src_apid WHERE T2.dst_apid  =  "CN" GROUP BY T2.dst_apid ORDER BY count(*) DESC LIMIT 1
# 6883
#  SELECT T1.dst_ap FROM routes AS T1 JOIN airports AS T2 ON T1.rid  =  T2.apid JOIN airlines AS T3 ON T2.ap  =  T3.alid WHERE T3.country  =  "China" GROUP BY T1.dst_ap ORDER BY count(*) DESC LIMIT 1
# 6884
#  SELECT T1.name FROM airports AS T1 JOIN routes AS T2 ON T1.apid  =  T2.dst_apid JOIN airlines AS T3 ON T2.src_ap  =  T3.alid WHERE T3.country  =  "China" GROUP BY T2.dst_ap ORDER BY count(*) DESC LIMIT 1

# %%
df_test['model_response'] = tmp['model_response']

# %%
df_test.to_csv('df_test_davinci_ft-mercator-2023-01-27-10-13-07.csv')

# %%
print(tmp.loc[5090]['open_ai_prompt'])
# Out:
# Schema: CREATE TABLE Ref_Payment_Methods (payment_method_code CHAR(10) ,payment_method_description VARCHAR(80),PRIMARY KEY (payment_method_code),UNIQUE (payment_method_code));CREATE TABLE Ref_Service_Types (Service_Type_Code CHAR(15) ,Parent_Service_Type_Code CHAR(15),Service_Type_Description VARCHAR(255),PRIMARY KEY (Service_Type_Code),UNIQUE (Service_Type_Code));CREATE TABLE Addresses (Address_ID VARCHAR(100) ,Line_1 VARCHAR(255),Line_2 VARCHAR(255),City_Town VARCHAR(255),State_County VARCHAR(255),Other_Details VARCHAR(255),PRIMARY KEY (Address_ID),UNIQUE (Address_ID));CREATE TABLE Products (Product_ID VARCHAR(100) ,Product_Name VARCHAR(255),Product_Price DECIMAL(20,4),Product_Description VARCHAR(255),Other_Product_Service_Details VARCHAR(255),PRIMARY KEY (Product_ID),UNIQUE (Product_ID));CREATE TABLE Marketing_Regions (Marketing_Region_Code CHAR(15) ,Marketing_Region_Name VARCHAR(255) ,Marketing_Region_Descriptrion VARCHAR(255) ,Other_Details VARCHAR(255),PRIMARY KEY (Marketing_Region_Code),UNIQUE (Marketing_Region_Code));CREATE TABLE Clients (Client_ID INTEGER ,Address_ID INTEGER ,Customer_Email_Address VARCHAR(255),Customer_Name VARCHAR(255),Customer_Phone VARCHAR(255),Other_Details VARCHAR(255),PRIMARY KEY (Client_ID),UNIQUE (Client_ID),FOREIGN KEY (Address_ID);CREATE TABLE Drama_Workshop_Groups (Workshop_Group_ID INTEGER ,Address_ID INTEGER ,Currency_Code CHAR(15) ,Marketing_Region_Code CHAR(15) ,Store_Name VARCHAR(255),Store_Phone VARCHAR(255),Store_Email_Address VARCHAR(255),Other_Details VARCHAR(255),PRIMARY KEY (Workshop_Group_ID),UNIQUE (Workshop_Group_ID),FOREIGN KEY (Address_ID);CREATE TABLE Performers (Performer_ID INTEGER ,Address_ID INTEGER ,Customer_Name VARCHAR(255),Customer_Phone VARCHAR(255),Customer_Email_Address VARCHAR(255),Other_Details VARCHAR(255),PRIMARY KEY (Performer_ID),UNIQUE (Performer_ID),FOREIGN KEY (Address_ID);CREATE TABLE Customers (Customer_ID VARCHAR(100) ,Address_ID INTEGER ,Customer_Name VARCHAR(255),Customer_Phone VARCHAR(255),Customer_Email_Address VARCHAR(255),Other_Details VARCHAR(255),PRIMARY KEY (Customer_ID),UNIQUE (Customer_ID),FOREIGN KEY (Address_ID);CREATE TABLE Stores (Store_ID VARCHAR(100) ,Address_ID INTEGER ,Marketing_Region_Code CHAR(15) ,Store_Name VARCHAR(255),Store_Phone VARCHAR(255),Store_Email_Address VARCHAR(255),Other_Details VARCHAR(255),PRIMARY KEY (Store_ID),UNIQUE (Store_ID),FOREIGN KEY (Address_ID);CREATE TABLE Bookings (Booking_ID INTEGER  ,Customer_ID INTEGER ,Workshop_Group_ID VARCHAR(100) ,Status_Code CHAR(15) ,Store_ID INTEGER ,Order_Date DATETIME ,Planned_Delivery_Date DATETIME ,Actual_Delivery_Date DATETIME ,Other_Order_Details VARCHAR(255),PRIMARY KEY (Booking_ID),UNIQUE (Booking_ID),FOREIGN KEY (Customer_ID);CREATE TABLE Performers_in_Bookings (Order_ID INTEGER ,Performer_ID INTEGER ,PRIMARY KEY (Order_ID, Performer_ID),FOREIGN KEY (Performer_ID);CREATE TABLE Customer_Orders (Order_ID INTEGER  ,Customer_ID INTEGER ,Store_ID INTEGER ,Order_Date DATETIME ,Planned_Delivery_Date DATETIME ,Actual_Delivery_Date DATETIME ,Other_Order_Details VARCHAR(255),PRIMARY KEY (Order_ID),UNIQUE (Order_ID),FOREIGN KEY (Customer_ID);CREATE TABLE Order_Items (Order_Item_ID INTEGER  ,Order_ID INTEGER ,Product_ID INTEGER ,Order_Quantity VARCHAR(288),Other_Item_Details VARCHAR(255),PRIMARY KEY (Order_Item_ID),FOREIGN KEY (Order_ID);CREATE TABLE Invoices (Invoice_ID INTEGER ,Order_ID INTEGER ,payment_method_code CHAR(15),Product_ID INTEGER ,Order_Quantity VARCHAR(288),Other_Item_Details VARCHAR(255),Order_Item_ID INTEGER ,PRIMARY KEY (Invoice_ID),FOREIGN KEY (Order_ID);CREATE TABLE Services (Service_ID INTEGER ,Service_Type_Code CHAR(15),Workshop_Group_ID INTEGER ,Product_Description VARCHAR(255),Product_Name VARCHAR(255),Product_Price DECIMAL(20,4),Other_Product_Service_Details VARCHAR(255),PRIMARY KEY (Service_ID),UNIQUE (Service_ID),FOREIGN KEY (Workshop_Group_ID);CREATE TABLE Bookings_Services (Order_ID INTEGER ,Product_ID INTEGER ,PRIMARY KEY (Order_ID, Product_ID),FOR ...
# Question: How many bookings do we have?
#
# ###

# %%
df_test['model_response'] = df_test['model_response'].fillna('')

# %%
# ignore: 
# - whitespace
# - capitalization
# - trailing semicolons
# - the difference between single and double quotes
# - difference between 'distinct(...)' and 'distinct ...'
# - explictly stating ASC (the ORDER BY default)
tmp = df_test[df_test['model_response'] != ''].copy()

tmp['correct'] = np.where(tmp['open_ai_completion'].str
                                                                         .strip()
                                                                         .str
                                                                         .lower()
                                                                         .apply(lambda x: re.sub("distinct\((.*)\)", "distinct\\1", 
                                                                                          re.sub('orderby(.*)asc', 'orderby\\1',
                                                                                          re.sub('"', "'",
                                                                                          re.sub('\s+', '', x))))
                                                                                .rstrip(';')) == 
                                     tmp['model_response'].str
                                                                     .strip()
                                                                     .str
                                                                     .lower()
                                                                         .apply(lambda x: re.sub("distinct\((.*)\)", "distinct\\1", 
                                                                                          re.sub('orderby(.*)asc', 'orderby\\1',
                                                                                          re.sub('"', "'",
                                                                                          re.sub('\s+', '', x))))
                                                                            .rstrip(';')), 1, 0)
tmp['correct'].mean()
# Out:
# 0.4394250513347023

# %%
# 0 leaves off "distinct"
# 10 adds a bad GROUP BY
# 20 - provided answer is bad
# 30 completely wrong
# 40 wrong table
# 50 - right, just reverses join order
# 60 leaves off a join
# 70 leaves off a join
# 80 leaves off a column, adds two joins it doesn't need
# 90 - right, just reverses column and join order
i = 90

print(tmp[tmp['correct'] == 0]['open_ai_prompt'].iloc[i])
print(tmp[tmp['correct'] == 0]['open_ai_completion'].iloc[i])
print(tmp[tmp['correct'] == 0]['model_response'].iloc[i])
# Out:
# Schema: CREATE TABLE "region" ("Region_ID" int,"Region_name" text,"Date" text,"Label" text,"Format" text,"Catalogue" text,PRIMARY KEY ("Region_ID"));CREATE TABLE "party" ("Party_ID" int,"Minister" text,"Took_office" text,"Left_office" text,"Region_ID" int,"Party_name" text,PRIMARY KEY ("Party_ID"),FOREIGN KEY (`Region_ID`);CREATE TABLE "member" ("Member_ID" int,"Member_Name" text,"Party_ID" text,"In_office" text,PRIMARY KEY ("Member_ID"),FOREIGN KEY (`Party_ID`);CREATE TABLE "party_events" ("Event_ID" int,"Event_Name" text,"Party_ID" int,"Member_in_charge_ID" int,PRIMARY KEY ("Event_ID"),FOREIGN KEY (`Party_ID`);
# Question: How many members are in each party?
#
# ###
#
#
#  SELECT T2.party_name ,  count(*) FROM Member AS T1 JOIN party AS T2 ON T1.party_id  =  T2.party_id GROUP BY T1.party_id
#
#  SELECT count(*) ,  T2.Party_name FROM party AS T1 JOIN member AS T2 ON T1.Party_ID  =  T2.Party_ID GROUP BY T2.Party_name

# %% [markdown]
# ## How does the multi-table query model perform on single table queries?

# %%
# ignore: 
# - whitespace
# - capitalization
# - trailing semicolons
# - the difference between single and double quotes
# - coerce 'distinct(...)' to 'distinct ...'
# - explictly stating ASC, the ORDER BY default
df_test_single = df_test[~df_test['open_ai_completion'].str.contains('JOIN')].copy()
df_test_single = df_test_single[df_test_single['open_ai_completion'].str.count('FROM') <= 1]
df_test_single = df_test_single[df_test_single['model_response'] != '']

df_test_single['correct'] = np.where(df_test_single['open_ai_completion'].str
                                                                         .strip()
                                                                         .str
                                                                         .lower()
                                                                         .apply(lambda x: re.sub("distinct\((.*)\)", "distinct\\1", 
                                                                                          re.sub('orderby(.*)asc', 'orderby\\1',
                                                                                          re.sub('"', "'",
                                                                                          re.sub('\s+', '', x))))
                                                                                .rstrip(';')) == 
                                     df_test_single['model_response'].str
                                                                     .strip()
                                                                     .str
                                                                     .lower()
                                                                         .apply(lambda x: re.sub("distinct\((.*)\)", "distinct\\1", 
                                                                                          re.sub('orderby(.*)asc', 'orderby\\1',
                                                                                          re.sub('"', "'",
                                                                                          re.sub('\s+', '', x))))
                                                                            .rstrip(';')), 1, 0)
df_test_single['correct'].mean()
# Out:
# 0.6713709677419355

# %%
# 0 leaves off "distinct"
# 10 confuses which column goes in SELECT vs WHERE clause
# 20 wrong table
# 30 wrong table
# 40 sorts by "year" instead of "date" to find "most recent"
# 50 adds a join it doesn't need and sorts by the wrong column
# 60 adds a join it doesn't need
# 70 wrong table, but I'd argue the model gets it right and the provided answer is wrong
# 80 leave off a column, but I'd argue the model gets it right and the provided answer is wrong
# 90 is right, just reverses the column order
i = 90

print(df_test_single[df_test_single['correct'] == 0]['open_ai_prompt'].iloc[i])
print(df_test_single[df_test_single['correct'] == 0]['open_ai_completion'].iloc[i])
print(df_test_single[df_test_single['correct'] == 0]['model_response'].iloc[i])
# Out:
# Schema: create table genre(	g_name varchar2(20) not null,	rating varchar2(10),	most_popular_in varchar2(50),	primary key(g_name));create table artist(	artist_name varchar2(50) not null,	country varchar2(20),	gender varchar2(20),	preferred_genre varchar2(50),	constraint a_name primary key(artist_name),	foreign key(preferred_genre);create table files(	f_id number(10) not null,	artist_name varchar2(50),	file_size varchar2(20),	duration varchar2(20),	formats varchar2(20),	primary key(f_id),	foreign key(artist_name);create table song(	song_name varchar2(50),	artist_name varchar2(50),	country varchar2(20),	f_id number(10),    	genre_is varchar2(20),	rating number(10) check(rating>0 and rating<11),	languages varchar2(20),	releasedate Date, 	resolution number(10) not null,	constraint s_name primary key(song_name),	foreign key(artist_name);
# Question: List the names of all genres in alphabetical oder, together with its ratings.
#
# ###
#
#
#  SELECT g_name ,  rating FROM genre ORDER BY g_name
#
#  SELECT rating ,  g_name FROM genre ORDER BY g_name

# %%
df_test_single[df_test_single['correct'] == 0].iloc[50]
# Out:
# open_ai_prompt        Schema: CREATE TABLE "circuits" ("circuitId" I...
# open_ai_completion     SELECT DISTINCT forename FROM drivers ORDER B...
# model_response         SELECT DISTINCT forename FROM drivers ORDER B...
# correct                                                               0
# Name: 2199, dtype: object

# %%
df_test_single[df_test_single['correct'] == 0].iloc[50]['open_ai_completion']
# Out:
# ' SELECT DISTINCT forename FROM drivers ORDER BY forename ASC\n'

# %%
df_test_single[df_test_single['correct'] == 0].iloc[50]['model_response']
# Out:
# ' SELECT DISTINCT forename FROM drivers ORDER BY forename'

# %%
tmp = df_test_single[(df_test_single['open_ai_completion'].str.contains("ASC")) & (df_test_single['correct'] == 0)]
# tmp = df_test_single[(df_test_single['open_ai_completion'].str.contains("DISTINCT")) & (df_test_single['correct'] == 0)]
tmp
i = 4
print(tmp.iloc[i]['open_ai_completion'])
print(tmp.iloc[i]['model_response'])
# Out:
#  SELECT DISTINCT forename FROM drivers ORDER BY forename ASC
#
#  SELECT DISTINCT forename FROM drivers ORDER BY forename

# %%
df_test_single[df_test_single['model_response'] != ''].shape
# Out:
# (496, 4)

# %% [markdown]
# # How does raw da vinci compare?

# %%
tmp = df_test.copy()

tmp['model_response'] = ''
data = []
for idx, row in tmp.iterrows():
    print(idx)
    if row['model_response'] != '':
        print('already completed')
        data.append(row['model_response'])
        continue
    
    new_response = call_model(row, engine="davinci")
    data.append(new_response)
    tmp.loc[idx,'model_response'] = new_response
# Out:
# 301
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[260], line 12
#       9     data.append(row['model_response'])
#      10     continue
# ---> 12 new_response = call_model(row, engine="davinci")
#      13 data.append(new_response)
#      14 tmp.loc[idx,'model_response'] = new_response
#
# Cell In[64], line 55, in call_model(row, engine)
#      53 while True:
#      54     try:
# ---> 55         completions = openai.Completion.create(
#      56             engine=engine,
#      57             prompt=prompt,
#      58             max_tokens=1024,
#      59             n=1,
#      60             stop=["\n"],
#      61             temperature=0.5
#      62         )
#      64         print(completions.choices[0].text)
#      65         return completions.choices[0].text
#
# File /opt/homebrew/lib/python3.10/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /opt/homebrew/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /opt/homebrew/lib/python3.10/site-packages/openai/api_requestor.py:227, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     206 def request(
#     207     self,
#     208     method,
#    (...)
#     215     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     216 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     217     result = self.request_raw(
#     218         method.lower(),
#     219         url,
#    (...)
#     225         request_timeout=request_timeout,
#     226     )
# --> 227     resp, got_stream = self._interpret_response(result, stream)
#     228     return resp, got_stream, self.api_key
#
# File /opt/homebrew/lib/python3.10/site-packages/openai/api_requestor.py:620, in APIRequestor._interpret_response(self, result, stream)
#     612     return (
#     613         self._interpret_response_line(
#     614             line, result.status_code, result.headers, stream=True
#     615         )
#     616         for line in parse_stream(result.iter_lines())
#     617     ), True
#     618 else:
#     619     return (
# --> 620         self._interpret_response_line(
#     621             result.content.decode("utf-8"),
#     622             result.status_code,
#     623             result.headers,
#     624             stream=False,
#     625         ),
#     626         False,
#     627     )
#
# File /opt/homebrew/lib/python3.10/site-packages/openai/api_requestor.py:680, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     678 stream_error = stream and "error" in resp.data
#     679 if stream_error or not 200 <= rcode < 300:
# --> 680     raise self.handle_error_response(
#     681         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     682     )
#     683 return resp
#
# AuthenticationError: Incorrect API key provided: sk-Xwp8P***************************************98o5. You can find your API key at https://beta.openai.com.
