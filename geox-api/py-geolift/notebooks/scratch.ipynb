# %% [markdown]
# ## Summary
#
# Walkthrough of GeoLift to check that PyGeoLift works correctly.

# %%
import sys
import os
sys.path.append("..")
os.environ["R_HOME"] = "/Library/Frameworks/R.framework/Resources"

# %%
# %reload_ext autoreload
# %autoreload 2
# %aimport pygeolift

# %%
import pygeolift.data

# %%
from rpy2.robjects.packages import importr, data as r_package_data
from rpy2.robjects import pandas2ri, default_converter, numpy2ri, NULL
from rpy2.robjects.conversion import localconverter

# %%
from pygeolift import geolift

# %% [markdown]
# Load example package data, `GeoLift_PreTest`.

# %%
geo_lift_pre_test = pygeolift.data.load_GeoLift_PreTest()

# %%
geo_lift_pre_test.head()
# Out:
#    location     Y        date
# 0  new york  3300  2021-01-01
# 1  new york  3202  2021-01-02
# 2  new york  4138  2021-01-03
# 3  new york  3716  2021-01-04
# 4  new york  3270  2021-01-05

# %%
geo_test_data_pre_test =  geolift.geo_data_read(geo_lift_pre_test,
                                        date_id = "date",
                                        location_id = "location",
                                        Y_id = "Y",
                                        X = [], #empty list as we have no covariates
                                        format = "yyyy-mm-dd",
                                        summary = True)
# Out:
# R[write to console]: ##################################
# #####       Summary       #####
# ##################################
#
# * Raw Number of Locations: 40
# * Time Periods: 90
# * Final Number of Locations (Complete): 40

# %%
# Out:
# [{'location': 'new york', 'Y': 3300, 'date': '2021-01-01'},
#  {'location': 'new york', 'Y': 3202, 'date': '2021-01-02'},
#  {'location': 'new york', 'Y': 4138, 'date': '2021-01-03'},
#  {'location': 'new york', 'Y': 3716, 'date': '2021-01-04'},
#  {'location': 'new york', 'Y': 3270, 'date': '2021-01-05'},
#  {'location': 'new york', 'Y': 3260, 'date': '2021-01-06'},
#  {'location': 'new york', 'Y': 3438, 'date': '2021-01-07'},
#  {'location': 'new york', 'Y': 3427, 'date': '2021-01-08'},
#  {'location': 'new york', 'Y': 3930, 'date': '2021-01-09'},
#  {'location': 'new york', 'Y': 4939, 'date': '2021-01-10'},
#  {'location': 'new york', 'Y': 4368, 'date': '2021-01-11'},
#  {'location': 'new york', 'Y': 3812, 'date': '2021-01-12'},
#  {'location': 'new york', 'Y': 3523, 'date': '2021-01-13'},
#  {'location': 'new york', 'Y': 3444, 'date': '2021-01-14'},
#  {'location': 'new york', 'Y': 3378, 'date': '2021-01-15'},
#  {'location': 'new york', 'Y': 3403, 'date': '2021-01-16'},
#  {'location': 'new york', 'Y': 3760, 'date': '2021-01-17'},
#  {'location': 'new york', 'Y': 4468, 'date': '2021-01-18'},
#  {'location': 'new york', 'Y': 3412, 'date': '2021-01-19'},
#  {'location': 'new york', 'Y': 3377, 'date': '2021-01-20'},
#  {'location': 'new york', 'Y': 2605, 'date': '2021-01-21'},
#  {'location': 'new york', 'Y': 3552, 'date': '2021-01-22'},
#  {'location': 'new york', 'Y': 3993, 'date': '2021-01-23'},
#  {'location': 'new york', 'Y': 5399, 'date': '2021-01-24'},
#  {'location': 'new york', 'Y': 4716, 'date': '2021-01-25'},
#  {'location': 'new york', 'Y': 3534, 'date': '2021-01-26'},
#  {'location': 'chicago', 'Y': 2474, 'date': '2021-03-11'},
#  {'location': 'chicago', 'Y': 2825, 'date': '2021-03-12'},
#  {'location': 'chicago', 'Y': 3173, 'date': '2021-03-13'},
#  {'location': 'chicago', 'Y': 4375, 'date': '2021-03-14'},
#  {'location': 'chicago', 'Y': 3378, 'date': '2021-03-15'},
#  {'location': 'chicago', 'Y': 2696, 'date': '2021-03-16'},
#  {'location': 'chicago', 'Y': 2308, 'date': '2021-03-17'},
#  {'location': 'chicago', 'Y': 2351, 'date': '2021-03-18'},
#  {'location': 'chicago', 'Y': 2385, 'date': '2021-03-19'},
#  {'location': 'chicago', 'Y': 2774, 'date': '2021-03-20'},
#  {'location': 'chicago', 'Y': 3914, 'date': '2021-03-21'},
#  {'location': 'chicago', 'Y': 2944, 'date': '2021-03-22'},
#  {'location': 'chicago', 'Y': 2394, 'date': '2021-03-23'},
#  {'location': 'chicago', 'Y': 2168, 'date': '2021-03-24'},
#  {'location': 'chicago', 'Y': 2320, 'date': '2021-03-25'},
#  {'location': 'chicago', 'Y': 2738, 'date': '2021-03-26'},
#  {'location': 'chicago', 'Y': 3216, 'date': '2021-03-27'},
#  {'location': 'chicago', 'Y': 4253, 'date': '2021-03-28'},
#  {'location': 'chicago', 'Y': 3187, 'date': '2021-03-29'},
#  {'location': 'chicago', 'Y': 2566, 'date': '2021-03-30'},
#  {'location': 'chicago', 'Y': 2393, 'date': '2021-03-31'},
#  {'location': 'washington', 'Y': 1841, 'date': '2021-01-01'},
#  {'location': 'washington', 'Y': 2278, 'date': '2021-01-02'},
#  {'location': 'washington', 'Y': 3634, 'date': '2021-01-03'},
#  {'location': 'washington', 'Y': 659, 'date': '2021-01-04'},
#  {'location': 'washington', 'Y': 1282, 'date': '2021-01-05'},
#  {'location': 'washington', 'Y': 2104, 'date': '2021-01-06'},
#  {'location': 'washington', 'Y': 1691, 'date': '2021-01-07'},
#  {'location': 'washington', 'Y': 1928, 'date': '2021-01-08'},
#  {'location': 'washington', 'Y': 2554, 'date': '2021-01-09'},
#  {'location': 'washington', 'Y': 4599, 'date': '2021-01-10'},
#  {'location': 'washington', 'Y': 3963, 'date': '2021-01-11'},
#  {'location': 'washington', 'Y': 2188, 'date': '2021-01-12'},
#  {'location': 'washington', 'Y': 1893, 'date': '2021-01-13'},
#  {'location': 'washington', 'Y': 1764, 'date': '2021-01-14'},
#  {'location': 'washington', 'Y': 1840, 'date': '2021-01-15'},
#  {'location': 'washington', 'Y': 2503, 'date': '2021-01-16'},
#  {'location': 'washington', 'Y': 3983, 'date': '2021-01-17'},
#  {'location': 'washington', 'Y': 3345, 'date': '2021-01-18'},
#  {'location': 'washington', 'Y': 1931, 'date': '2021-01-19'},
#  {'location': 'washington', 'Y': 1953, 'date': '2021-01-20'},
#  {'location': 'washington', 'Y': 1739, 'date': '2021-01-21'},
#  {'location': 'washington', 'Y': 1896, 'date': '2021-01-22'},
#  {'location': 'washington', 'Y': 2768, 'date': '2021-01-23'},
#  {'location': 'washington', 'Y': 4182, 'date': '2021-01-24'},
#  {'location': 'washington', 'Y': 3679, 'date': '2021-01-25'},
#  {'location': 'washington', 'Y': 2153, 'date': '2021-01-26'},
#  {'location': 'washington', 'Y': 2028, 'date': '2021-01-27'},
#  {'location': 'washington', 'Y': 1889, 'date': '2021-01-28'},
#  {'location': 'washington', 'Y': 2096, 'date': '2021-01-29'},
#  {'location': 'washington', 'Y': 2516, 'date': '2021-01-30'},
#  {'location': 'washington', 'Y': 4106, 'date': '2021-01-31'},
#  {'location': 'washington', 'Y': 3695, 'date': '2021-02-01'},
#  {'location': 'washington', 'Y': 2003, 'date': '2021-02-02'},
#  {'location': 'washington', 'Y': 1757, 'date': '2021-02-03'},
#  {'location': 'washington', 'Y': 1702, 'date': '2021-02-04'},
#  {'location': 'washington', 'Y': 1958, 'date': '2021-02-05'},
#  {'location': 'washington', 'Y': 2795, 'date': '2021-02-06'},
#  {'location': 'washington', 'Y': 4195, 'date': '2021-02-07'},
#  {'location': 'washington', 'Y': 3968, 'date': '2021-02-08'},
#  {'location': 'washington', 'Y': 2335, 'date': '2021-02-09'},
#  {'location': 'washington', 'Y': 2264, 'date': '2021-02-10'},
#  {'location': 'washington', 'Y': 1960, 'date': '2021-02-11'},
#  {'location': 'washington', 'Y': 1935, 'date': '2021-02-12'},
#  {'location': 'washington', 'Y': 2625, 'date': '2021-02-13'},
#  {'location': 'washington', 'Y': 4000, 'date': '2021-02-14'},
#  {'location': 'washington', 'Y': 4189, 'date': '2021-02-15'},
#  {'location': 'washington', 'Y': 2145, 'date': '2021-02-16'},
#  {'location': 'washington', 'Y': 2019, 'date': '2021-02-17'},
#  {'location': 'washington', 'Y': 1929, 'date': '2021-02-18'},
#  {'location': 'washington', 'Y': 1987, 'date': '2021-02-19'},
#  {'location': 'washington', 'Y': 2745, 'date': '2021-02-20'},
#  {'location': 'washington', 'Y': 4530, 'date': '2021-02-21'},
#  {'location': 'washington', 'Y': 4124, 'date': '2021-02-22'},
#  {'location': 'washington', 'Y': 2195, 'date': '2021-02-23'},
#  {'location': 'washington', 'Y': 2200, 'date': '2021-02-24'},
#  {'location': 'washington', 'Y': 3461, 'date': '2021-02-25'},
#  {'location': 'washington', 'Y': 2081, 'date': '2021-02-26'},
#  {'location': 'washington', 'Y': 2727, 'date': '2021-02-27'},
#  {'location': 'washington', 'Y': 4306, 'date': '2021-02-28'},
#  {'location': 'washington', 'Y': 3840, 'date': '2021-03-01'},
#  {'location': 'washington', 'Y': 1952, 'date': '2021-03-02'},
#  {'location': 'washington', 'Y': 1872, 'date': '2021-03-03'},
#  {'location': 'washington', 'Y': 1727, 'date': '2021-03-04'},
#  {'location': 'washington', 'Y': 1887, 'date': '2021-03-05'},
#  {'location': 'washington', 'Y': 2528, 'date': '2021-03-06'},
#  {'location': 'washington', 'Y': 3836, 'date': '2021-03-07'},
#  {'location': 'washington', 'Y': 3459, 'date': '2021-03-08'},
#  {'location': 'washington', 'Y': 1913, 'date': '2021-03-09'},
#  {'location': 'washington', 'Y': 1872, 'date': '2021-03-10'},
#  {'location': 'washington', 'Y': 2132, 'date': '2021-03-11'},
#  {'location': 'washington', 'Y': 2417, 'date': '2021-03-12'},
#  {'location': 'washington', 'Y': 2914, 'date': '2021-03-13'},
#  {'location': 'washington', 'Y': 4232, 'date': '2021-03-14'},
#  {'location': 'washington', 'Y': 3875, 'date': '2021-03-15'},
#  {'location': 'washington', 'Y': 1940, 'date': '2021-03-16'},
#  {'location': 'washington', 'Y': 1871, 'date': '2021-03-17'},
#  {'location': 'washington', 'Y': 1767, 'date': '2021-03-18'},
#  {'location': 'washington', 'Y': 2007, 'date': '2021-03-19'},
#  {'location': 'washington', 'Y': 2544, 'date': '2021-03-20'},
#  {'location': 'washington', 'Y': 4260, 'date': '2021-03-21'},
#  {'location': 'washington', 'Y': 3703, 'date': '2021-03-22'},
#  {'location': 'washington', 'Y': 1814, 'date': '2021-03-23'},
#  {'location': 'washington', 'Y': 1635, 'date': '2021-03-24'},
#  {'location': 'washington', 'Y': 1802, 'date': '2021-03-25'},
#  {'location': 'washington', 'Y': 2258, 'date': '2021-03-26'},
#  {'location': 'washington', 'Y': 3037, 'date': '2021-03-27'},
#  {'location': 'washington', 'Y': 4453, 'date': '2021-03-28'},
#  {'location': 'washington', 'Y': 3923, 'date': '2021-03-29'},
#  {'location': 'washington', 'Y': 2144, 'date': '2021-03-30'},
#  {'location': 'washington', 'Y': 1996, 'date': '2021-03-31'},
#  {'location': 'los angeles', 'Y': 2491, 'date': '2021-01-01'},
#  {'location': 'los angeles', 'Y': 2535, 'date': '2021-01-02'},
#  {'location': 'los angeles', 'Y': 3410, 'date': '2021-01-03'},
#  {'location': 'los angeles', 'Y': 3118, 'date': '2021-01-04'},
#  {'location': 'los angeles', 'Y': 2707, 'date': '2021-01-05'},
#  {'location': 'los angeles', 'Y': 2554, 'date': '2021-01-06'},
#  {'location': 'los angeles', 'Y': 2276, 'date': '2021-01-07'},
#  {'location': 'los angeles', 'Y': 2834, 'date': '2021-01-08'},
#  {'location': 'los angeles', 'Y': 3186, 'date': '2021-01-09'},
#  {'location': 'los angeles', 'Y': 4514, 'date': '2021-01-10'},
#  {'location': 'los angeles', 'Y': 4353, 'date': '2021-01-11'},
#  {'location': 'los angeles', 'Y': 2874, 'date': '2021-01-12'},
#  {'location': 'los angeles', 'Y': 2971, 'date': '2021-01-13'},
#  {'location': 'los angeles', 'Y': 2704, 'date': '2021-01-14'},
#  {'location': 'los angeles', 'Y': 2304, 'date': '2021-01-15'},
#  {'location': 'los angeles', 'Y': 2877, 'date': '2021-01-16'},
#  {'location': 'los angeles', 'Y': 3945, 'date': '2021-01-17'},
#  {'location': 'los angeles', 'Y': 4096, 'date': '2021-01-18'},
#  {'location': 'los angeles', 'Y': 2761, 'date': '2021-01-19'},
#  {'location': 'los angeles', 'Y': 2671, 'date': '2021-01-20'},
#  {'location': 'los angeles', 'Y': 2467, 'date': '2021-01-21'},
#  {'location': 'san diego', 'Y': 3149, 'date': '2021-01-04'},
#  {'location': 'san diego', 'Y': 2538, 'date': '2021-01-05'},
#  {'location': 'san diego', 'Y': 2356, 'date': '2021-01-06'},
#  {'location': 'san diego', 'Y': 3182, 'date': '2021-01-07'},
#  {'location': 'san diego', 'Y': 3116, 'date': '2021-01-08'},
#  {'location': 'san diego', 'Y': 4064, 'date': '2021-01-09'},
#  {'location': 'san diego', 'Y': 5091, 'date': '2021-01-10'},
#  {'location': 'san diego', 'Y': 3443, 'date': '2021-01-11'},
#  {'location': 'san diego', 'Y': 3751, 'date': '2021-01-12'},
#  {'location': 'san diego', 'Y': 3445, 'date': '2021-01-13'},
#  {'location': 'san diego', 'Y': 3445, 'date': '2021-01-14'},
#  {'location': 'san diego', 'Y': 3373, 'date': '2021-01-15'},
#  {'location': 'san diego', 'Y': 3317, 'date': '2021-01-16'},
#  {'location': 'san diego', 'Y': 4572, 'date': '2021-01-17'},
#  {'location': 'san diego', 'Y': 2920, 'date': '2021-01-18'},
#  {'location': 'san diego', 'Y': 3070, 'date': '2021-01-19'},
#  {'location': 'san diego', 'Y': 3035, 'date': '2021-01-20'},
#  {'location': 'san diego', 'Y': 2840, 'date': '2021-01-21'},
#  {'location': 'san diego', 'Y': 3164, 'date': '2021-01-22'},
#  {'location': 'san diego', 'Y': 3645, 'date': '2021-01-23'},
#  {'location': 'san diego', 'Y': 4589, 'date': '2021-01-24'},
#  {'location': 'san diego', 'Y': 3886, 'date': '2021-01-25'},
#  {'location': 'san diego', 'Y': 3728, 'date': '2021-01-26'},
#  {'location': 'san diego', 'Y': 3323, 'date': '2021-01-27'},
#  {'location': 'san diego', 'Y': 3386, 'date': '2021-01-28'},
#  {'location': 'san diego', 'Y': 3370, 'date': '2021-01-29'},
#  {'location': 'san diego', 'Y': 3422, 'date': '2021-01-30'},
#  {'location': 'san diego', 'Y': 5121, 'date': '2021-01-31'},
#  {'location': 'san diego', 'Y': 3544, 'date': '2021-02-01'},
#  {'location': 'san diego', 'Y': 3140, 'date': '2021-02-02'},
#  {'location': 'san diego', 'Y': 2932, 'date': '2021-02-03'},
#  {'location': 'san diego', 'Y': 2792, 'date': '2021-02-04'},
#  {'location': 'san diego', 'Y': 3036, 'date': '2021-02-05'},
#  {'location': 'san diego', 'Y': 3585, 'date': '2021-02-06'},
#  {'location': 'san diego', 'Y': 4780, 'date': '2021-02-07'},
#  {'location': 'san diego', 'Y': 3599, 'date': '2021-02-08'},
#  {'location': 'san diego', 'Y': 3545, 'date': '2021-02-09'},
#  {'location': 'san diego', 'Y': 3224, 'date': '2021-02-10'},
#  {'location': 'san diego', 'Y': 3630, 'date': '2021-02-11'},
#  {'location': 'san diego', 'Y': 3548, 'date': '2021-02-12'},
#  {'location': 'san diego', 'Y': 3382, 'date': '2021-02-13'},
#  {'location': 'san diego', 'Y': 5088, 'date': '2021-02-14'},
#  {'location': 'san diego', 'Y': 3535, 'date': '2021-02-15'},
#  {'location': 'san diego', 'Y': 3326, 'date': '2021-02-16'},
#  {'location': 'san diego', 'Y': 2918, 'date': '2021-02-17'},
#  {'location': 'san diego', 'Y': 2738, 'date': '2021-02-18'},
#  {'location': 'san diego', 'Y': 2773, 'date': '2021-02-19'},
#  {'location': 'san diego', 'Y': 3457, 'date': '2021-02-20'},
#  {'location': 'san diego', 'Y': 4566, 'date': '2021-02-21'},
#  {'location': 'san diego', 'Y': 3461, 'date': '2021-02-22'},
#  {'location': 'san diego', 'Y': 3536, 'date': '2021-02-23'},
#  {'location': 'san diego', 'Y': 3875, 'date': '2021-02-24'},
#  {'location': 'san diego', 'Y': 3460, 'date': '2021-02-25'},
#  {'location': 'san diego', 'Y': 3407, 'date': '2021-02-26'},
#  {'location': 'san diego', 'Y': 3787, 'date': '2021-02-27'},
#  {'location': 'san diego', 'Y': 5097, 'date': '2021-02-28'},
#  {'location': 'san diego', 'Y': 3783, 'date': '2021-03-01'},
#  {'location': 'san diego', 'Y': 3432, 'date': '2021-03-02'},
#  {'location': 'san diego', 'Y': 2988, 'date': '2021-03-03'},
#  {'location': 'san diego', 'Y': 2909, 'date': '2021-03-04'},
#  {'location': 'san diego', 'Y': 2832, 'date': '2021-03-05'},
#  {'location': 'san diego', 'Y': 3363, 'date': '2021-03-06'},
#  {'location': 'san diego', 'Y': 4710, 'date': '2021-03-07'},
#  {'location': 'san diego', 'Y': 3163, 'date': '2021-03-08'},
#  {'location': 'san diego', 'Y': 3130, 'date': '2021-03-09'},
#  {'location': 'san diego', 'Y': 2911, 'date': '2021-03-10'},
#  {'location': 'san diego', 'Y': 3430, 'date': '2021-03-11'},
#  {'location': 'san diego', 'Y': 3631, 'date': '2021-03-12'},
#  {'location': 'san diego', 'Y': 3979, 'date': '2021-03-13'},
#  {'location': 'san diego', 'Y': 5338, 'date': '2021-03-14'},
#  {'location': 'san diego', 'Y': 3488, 'date': '2021-03-15'},
#  {'location': 'san diego', 'Y': 3345, 'date': '2021-03-16'},
#  {'location': 'san diego', 'Y': 3188, 'date': '2021-03-17'},
#  {'location': 'san diego', 'Y': 3013, 'date': '2021-03-18'},
#  {'location': 'san diego', 'Y': 3058, 'date': '2021-03-19'},
#  {'location': 'san diego', 'Y': 3397, 'date': '2021-03-20'},
#  {'location': 'san diego', 'Y': 4902, 'date': '2021-03-21'},
#  {'location': 'san diego', 'Y': 3193, 'date': '2021-03-22'},
#  {'location': 'san diego', 'Y': 2985, 'date': '2021-03-23'},
#  {'location': 'san diego', 'Y': 2793, 'date': '2021-03-24'},
#  {'location': 'san diego', 'Y': 2841, 'date': '2021-03-25'},
#  {'location': 'san diego', 'Y': 3646, 'date': '2021-03-26'},
#  {'location': 'san diego', 'Y': 4006, 'date': '2021-03-27'},
#  {'location': 'san diego', 'Y': 4924, 'date': '2021-03-28'},
#  {'location': 'san diego', 'Y': 3364, 'date': '2021-03-29'},
#  {'location': 'san diego', 'Y': 3235, 'date': '2021-03-30'},
#  {'location': 'san diego', 'Y': 3130, 'date': '2021-03-31'},
#  {'location': 'austin', 'Y': 2124, 'date': '2021-01-01'},
#  {'location': 'austin', 'Y': 2258, 'date': '2021-01-02'},
#  {'location': 'austin', 'Y': 2994, 'date': '2021-01-03'},
#  {'location': 'austin', 'Y': 2964, 'date': '2021-01-04'},
#  {'location': 'austin', 'Y': 2134, 'date': '2021-01-05'},
#  {'location': 'austin', 'Y': 2025, 'date': '2021-01-06'},
#  {'location': 'austin', 'Y': 1954, 'date': '2021-01-07'},
#  {'location': 'austin', 'Y': 2187, 'date': '2021-01-08'},
#  {'location': 'austin', 'Y': 2523, 'date': '2021-01-09'},
#  {'location': 'austin', 'Y': 3503, 'date': '2021-01-10'},
#  {'location': 'austin', 'Y': 3067, 'date': '2021-01-11'},
#  {'location': 'austin', 'Y': 2313, 'date': '2021-01-12'},
#  {'location': 'austin', 'Y': 2339, 'date': '2021-01-13'},
#  {'location': 'austin', 'Y': 2103, 'date': '2021-01-14'},
#  {'location': 'austin', 'Y': 2162, 'date': '2021-01-15'},
#  {'location': 'austin', 'Y': 2295, 'date': '2021-01-16'},
#  {'location': 'austin', 'Y': 3315, 'date': '2021-01-17'},
#  {'location': 'austin', 'Y': 2884, 'date': '2021-01-18'},
#  {'location': 'austin', 'Y': 2323, 'date': '2021-01-19'},
#  {'location': 'austin', 'Y': 2046, 'date': '2021-01-20'},
#  {'location': 'austin', 'Y': 2306, 'date': '2021-01-21'},
#  {'location': 'austin', 'Y': 2279, 'date': '2021-01-22'},
#  {'location': 'austin', 'Y': 2659, 'date': '2021-01-23'},
#  {'location': 'austin', 'Y': 3622, 'date': '2021-01-24'},
#  {'location': 'austin', 'Y': 3308, 'date': '2021-01-25'},
#  {'location': 'austin', 'Y': 2422, 'date': '2021-01-26'},
#  {'location': 'austin', 'Y': 2419, 'date': '2021-01-27'},
#  {'location': 'austin', 'Y': 2244, 'date': '2021-01-28'},
#  {'location': 'austin', 'Y': 2423, 'date': '2021-01-29'},
#  {'location': 'austin', 'Y': 2591, 'date': '2021-01-30'},
#  {'location': 'austin', 'Y': 3570, 'date': '2021-01-31'},
#  {'location': 'austin', 'Y': 3272, 'date': '2021-02-01'},
#  {'location': 'austin', 'Y': 2211, 'date': '2021-02-02'},
#  {'location': 'austin', 'Y': 2043, 'date': '2021-02-03'},
#  {'location': 'austin', 'Y': 2024, 'date': '2021-02-04'},
#  {'location': 'austin', 'Y': 2090, 'date': '2021-02-05'},
#  {'location': 'austin', 'Y': 2699, 'date': '2021-02-06'},
#  {'location': 'austin', 'Y': 3525, 'date': '2021-02-07'},
#  {'location': 'austin', 'Y': 3084, 'date': '2021-02-08'},
#  {'location': 'austin', 'Y': 2236, 'date': '2021-02-09'},
#  {'location': 'austin', 'Y': 2347, 'date': '2021-02-10'},
#  {'location': 'austin', 'Y': 2186, 'date': '2021-02-11'},
#  {'location': 'austin', 'Y': 2379, 'date': '2021-02-12'},
#  {'location': 'austin', 'Y': 2724, 'date': '2021-02-13'},
#  {'location': 'austin', 'Y': 3503, 'date': '2021-02-14'},
#  {'location': 'austin', 'Y': 2873, 'date': '2021-02-15'},
#  {'location': 'austin', 'Y': 2214, 'date': '2021-02-16'},
#  {'location': 'austin', 'Y': 2145, 'date': '2021-02-17'},
#  {'location': 'austin', 'Y': 2067, 'date': '2021-02-18'},
#  {'location': 'austin', 'Y': 2022, 'date': '2021-02-19'},
#  {'location': 'austin', 'Y': 2524, 'date': '2021-02-20'},
#  {'location': 'austin', 'Y': 3359, 'date': '2021-02-21'},
#  {'location': 'austin', 'Y': 3120, 'date': '2021-02-22'},
#  {'location': 'austin', 'Y': 2304, 'date': '2021-02-23'},
#  {'location': 'austin', 'Y': 2428, 'date': '2021-02-24'},
#  {'location': 'austin', 'Y': 2491, 'date': '2021-02-25'},
#  {'location': 'austin', 'Y': 2055, 'date': '2021-02-26'},
#  {'location': 'austin', 'Y': 2851, 'date': '2021-02-27'},
#  {'location': 'austin', 'Y': 3442, 'date': '2021-02-28'},
#  {'location': 'austin', 'Y': 3056, 'date': '2021-03-01'},
#  {'location': 'austin', 'Y': 2223, 'date': '2021-03-02'},
#  {'location': 'austin', 'Y': 2230, 'date': '2021-03-03'},
#  {'location': 'austin', 'Y': 2090, 'date': '2021-03-04'},
#  {'location': 'austin', 'Y': 2034, 'date': '2021-03-05'},
#  {'location': 'austin', 'Y': 2670, 'date': '2021-03-06'},
#  {'location': 'austin', 'Y': 3388, 'date': '2021-03-07'},
#  {'location': 'austin', 'Y': 3046, 'date': '2021-03-08'},
#  {'location': 'austin', 'Y': 2085, 'date': '2021-03-09'},
#  {'location': 'austin', 'Y': 2128, 'date': '2021-03-10'},
#  {'location': 'austin', 'Y': 2110, 'date': '2021-03-11'},
#  {'location': 'austin', 'Y': 2356, 'date': '2021-03-12'},
#  {'location': 'austin', 'Y': 2855, 'date': '2021-03-13'},
#  {'location': 'austin', 'Y': 3639, 'date': '2021-03-14'},
#  {'location': 'austin', 'Y': 3146, 'date': '2021-03-15'},
#  {'location': 'austin', 'Y': 2286, 'date': '2021-03-16'},
#  {'location': 'austin', 'Y': 2094, 'date': '2021-03-17'},
#  {'location': 'austin', 'Y': 2153, 'date': '2021-03-18'},
#  {'location': 'austin', 'Y': 2246, 'date': '2021-03-19'},
#  {'location': 'austin', 'Y': 2846, 'date': '2021-03-20'},
#  {'location': 'austin', 'Y': 3627, 'date': '2021-03-21'},
#  {'location': 'austin', 'Y': 3046, 'date': '2021-03-22'},
#  {'location': 'austin', 'Y': 2163, 'date': '2021-03-23'},
#  {'location': 'austin', 'Y': 2250, 'date': '2021-03-24'},
#  {'location': 'austin', 'Y': 2164, 'date': '2021-03-25'},
#  {'location': 'austin', 'Y': 2495, 'date': '2021-03-26'},
#  {'location': 'austin', 'Y': 2994, 'date': '2021-03-27'},
#  {'location': 'austin', 'Y': 3424, 'date': '2021-03-28'},
#  {'location': 'austin', 'Y': 3580, 'date': '2021-03-29'},
#  {'location': 'austin', 'Y': 2462, 'date': '2021-03-30'},
#  {'location': 'austin', 'Y': 2558, 'date': '2021-03-31'},
#  {'location': 'dallas', 'Y': 1683, 'date': '2021-01-01'},
#  {'location': 'dallas', 'Y': 2016, 'date': '2021-01-02'},
#  {'location': 'dallas', 'Y': 2980, 'date': '2021-01-03'},
#  {'location': 'dallas', 'Y': 635, 'date': '2021-01-04'},
#  {'location': 'dallas', 'Y': 937, 'date': '2021-01-05'},
#  {'location': 'dallas', 'Y': 1971, 'date': '2021-01-06'},
#  {'location': 'dallas', 'Y': 1787, 'date': '2021-01-07'},
#  {'location': 'dallas', 'Y': 2006, 'date': '2021-01-08'},
#  {'location': 'dallas', 'Y': 2432, 'date': '2021-01-09'},
#  {'location': 'dallas', 'Y': 4070, 'date': '2021-01-10'},
#  ...]

# %%
input_data = [MarketSelectionInputDataRow(**row) for row in geo_lift_pre_test.to_dict(orient='records')]
df = pd.DataFrame.from_records(row.dict() for row in input_data)
df['date'] = [d.strftime("%Y-%m-%d") for d in df['date']]
data_clean = geo_data_read(
    df,
    date_id = "date",
    Y_id = "Y",
    location_id = "location",
    format = "yyyy-mm-dd",
    keep_unix_time=True,
    summary = False
)
# Out:
#         location  time     date_unix       Y
# 1        atlanta     1  1.609459e+09  3384.0
# 2        atlanta     2  1.609546e+09  3904.0
# 3        atlanta     3  1.609632e+09  5734.0
# 4        atlanta     4  1.609718e+09  4311.0
# 5        atlanta     5  1.609805e+09  3686.0
# ...          ...   ...           ...     ...
# 3596  washington    86  1.616803e+09  3037.0
# 3597  washington    87  1.616890e+09  4453.0
# 3598  washington    88  1.616976e+09  3923.0
# 3599  washington    89  1.617062e+09  2144.0
# 3600  washington    90  1.617149e+09  1996.0
#
# [3600 rows x 4 columns]

# %%
import numpy as np
market_selections = geolift.geo_lift_market_selection(
                                        data = data_clean, #geo_test_data_pre_test,
                                        treatment_periods = [10,15],
                                        N = [2,3,4,5],
                                        Y_id = "Y",
                                        location_id = "location",
                                        time_id = "time",
                                        effect_size = list(np.arange(-0.25, 0.25, 0.05)),
                                        lookback_window = 1, 
                                        include_markets = ["chicago"],
                                        exclude_markets = ["honolulu"],
                                        cpic = 7.50,
                                        budget = 100000,
                                        alpha = 0.1,
                                        Correlations = True,
                                        fixed_effects = True,
                                        side_of_test = "one_sided"
                                        )
# Out:
# R[write to console]: Setting up cluster.
#
# R[write to console]: Importing functions into cluster.
#
# R[write to console]:
# Deterministic setup with 2 locations in treatment.
#
# R[write to console]:
# Deterministic setup with 3 locations in treatment.
#
# R[write to console]:
# Deterministic setup with 4 locations in treatment.
#
# R[write to console]:
# Deterministic setup with 5 locations in treatment.
#   ID                                           location duration EffectSize
# 1  1            atlanta, chicago, las vegas, saint paul       15       0.05
# 2  2                                  chicago, portland       15       0.05
# 3  3             chicago, cincinnati, houston, portland       15       0.05
# 4  4                  chicago, houston, nashville, reno       15       0.05
# 5  5       atlanta, chicago, cleveland, las vegas, reno       10       0.05
# 6  6 atlanta, chicago, cleveland, las vegas, saint paul       10       0.05
#   Power AvgScaledL2Imbalance Investment   AvgATT Average_MDE ProportionTotal_Y
# 1     1            0.5558341   85305.00 189.2567  0.04991417        0.08767192
# 2     1            0.1738778   32281.87 146.5321  0.05111983        0.03306537
# 3     1            0.1971864   74118.37 159.3627  0.04829913        0.07576405
# 4     1            0.3321341   75556.12 174.0647  0.05193036        0.07816073
# 5     1            0.4536741   69300.00 195.0787  0.05292824        0.10714670
# 6     1            0.6273970   70187.62 176.4054  0.04699004        0.10736581
#   abs_lift_in_zero   Holdout rank correlation
# 1            0.000 0.9123281    1   0.9775394
# 2            0.001 0.9669346    2   0.9321104
# 3            0.002 0.9242359    3   0.9144814
# 4            0.002 0.9218393    3   0.9146693
# 5            0.003 0.8928533    5   0.9788758
# 6            0.003 0.8926342    5   0.9856002

# %%
from typing import List, Optional
import pandas as pd
from pydantic import BaseModel, Field, confloat, PositiveInt, PositiveFloat, root_validator, validator
from pandas import DataFrame
from typing import TypedDict
import datetime
from enum import Enum

from pygeolift.geolift import geo_lift_market_selection, geo_data_read

class EnumStringPrint:
    def __str__(self):
        return str(self.value)    

class TestSidedness(EnumStringPrint, str, Enum):
    one_sided = "one_sided"
    two_sided = "two_sided"

class MarketSelectionInputDataRow(BaseModel):
    location: str
    date: datetime.date
    Y: float

class PowerCurveValue(BaseModel):
    """Power curve value in the market selection API results."""
    location: str = Field(..., description="Location id")
    duration: int = Field(..., description="Length of experiment assignment (in days)")
    EffectSize: float = Field(..., description="Effect size used in the simulation (relative)")
    power: float = Field(..., description="Power (proportion of stat sig simulations)")
    Investment: float = Field(..., description="Investment, equal to CPIC * conversions)")
    AvgATT: float = Field(..., description="Average treatment effect for the treated units")
    AvgDetectedLift: float = Field(..., description="Average detected lift.")
    

class LocationAssignment(BaseModel):
    location: List[str] = Field(..., description="Sorted list of location identifiers")
    duration: int = Field(..., description="Length of experiment assignment (in days)")
    EffectSize: float = Field(..., description="Smallest effect size for that (location combination, duration) where power is at least 80%.")
    Power: float = Field(..., description="Power at the smallest effect size")
    AvgScaledL2Imbalance: float = Field(..., description="Average scaled L2 imbalance")
    Investment: float   = Field(..., description="Estimated marketing budget for this")
    AvgATT: float  = Field(..., description="Average ATT estimate in simulations")
    Average_MDE: float  = Field(..., description="Average MDE in simulations")
    ProportionTotal_Y: float  = Field(..., description="Proportion of total Y")
    abs_lift_in_zero: float  = Field(..., description="Estimated lift when there is no treatment effect. This should be close to 0.")
    Holdout: float = Field(...)
    rank: int = Field(..., description="Ranking of best designs. This the average rank of the ranks of (TODO).")
    correlation: Optional[float]  = Field(None)
    power_curve: List[PowerCurveValue] = Field(..., description="A data frame with the results for all effect sizes that were estimated")
    
    class Config:
        arbitrary_types_allowed = True

class MarketSelectionResult(BaseModel):
    __root__: List[LocationAssignment] = Field(..., description="List of assignments and information about those assignments.")

class MarketSelectionInput(BaseModel):
    data: List[MarketSelectionInputDataRow] = Field(..., description="Data ")
    treatment_periods: List[PositiveInt] = Field(..., description="List of the number of experiment lengths (in days) to simulation.")
    num_locations: List[PositiveInt] = Field(...)
    effect_sizes: List[float] = Field([0, 0.05, 0.10, 0.15, 0.20, 0.25])
    lookback_window: PositiveInt = Field(1)
    include_locations: List[str] = Field([])
    exclude_locations: List[str] = Field([])
    cpic: PositiveFloat = Field(1)
    budget: Optional[PositiveFloat] = Field(None)
    side_of_test: TestSidedness = Field(TestSidedness.one_sided)
    fixed_effects: bool = True
    alpha: confloat(gt=0, lt=1) = Field(0.05, description="Statistical significance value.")
    
    @validator('include_locations', 'exclude_locations', 'effect_sizes', pre=True)
    def uniquify_list(cls, v):
        """Ensure locations are always unique."""
        return list(set(v))
    
    # @validator('effect_sizes')
    # def check_effect_sizes(cls, v):
    #     # check that all effect sizes are in the same direction
    #     if sum(x >= 0 for x in v) != len(v):
    #         raise ValueError("Effect sizes must be either all positive or all negative.")
    #     return v   
            
    @root_validator(pre=False)
    def check_include_locations(cls, values):
        include_locations = values.get('include_locations')
        if include_locations:
            locations = set(row.location for row in values.get('data'))
            missing_locations = set(include_locations) - locations
            if len(missing_locations) > 0:
                raise ValueError('Some locations in `include_locations` are not in `data`: {}'.format(','.join(missing_locations)))
        return values
    
    @root_validator(pre=False)
    def check_exclude_locations(cls, values):
        exclude_locations = values.get('exclude_locations')
        if exclude_locations:
            locations = set(row.location for row in values.get('data'))
            missing_locations = set(exclude_locations) - locations
            if len(missing_locations) > 0:
                raise ValueError('Some locations in `exclude_locations` are not in `data`: {}'.format(','.join(missing_locations)))
        return values    

def market_selection(input: MarketSelectionInput) -> MarketSelectionResult:
    # preprocess and clean data
    df = pd.DataFrame.from_records([row.dict() for row in input.data])
    df['date'] = [d.strftime("%Y-%m-%d") for d in df['date']]
    data_clean = geo_data_read(
        df,
        date_id = "date",
        Y_id = "Y",
        location_id = "location",
        format = "yyyy-mm-dd",
        keep_unix_time=True,
        summary = False
    )

    # Run main function
    results = geo_lift_market_selection(
        data = data_clean,
        treatment_periods = input.treatment_periods,
        N = input.num_locations,
        #X = tuple(),
        effect_size = input.effect_sizes,
        lookback_window = input.lookback_window,
        Y_id = "Y",
        location_id = "location",
        time_id = "time",
        include_markets = input.include_locations,
        exclude_markets = input.exclude_locations,
        cpic = input.cpic,
        budget = input.budget,
        alpha = input.alpha,
        fixed_effects = input.fixed_effects,
        side_of_test = str(input.side_of_test),
        # These should be set internally
        Correlations = True,
        parallel = False,
        parallel_setup = "sequential",
        ProgressBar = False,
        print_ = False
    )

    #results.PowerCurves['duration'] = results.PowerCurves['duration'].astype(int)
    power_curves = dict(list(results.PowerCurves.groupby(["location", "duration"])))
    output = []
    # Post process results
    for row in results.BestMarkets.sort_values(["rank"]).itertuples(index=False):
        d = row._asdict()
        d['power_curve'] = power_curves[(row.location, row.duration)].to_dict(orient='records')
        d['location'] = d['location'].split(',')
        d['duration'] = int(d['duration'])
        output.append(d)
    # TODO: Should the original parameters be included in the results
    return MarketSelectionResult(__root__=output)


df = [MarketSelectionInputDataRow(**row) for row in geo_lift_pre_test.to_dict(orient='records')]
api_input = MarketSelectionInput(
    data = df,
    treatment_periods=[10, 15],
    num_locations=[2, 3, 4, 5],
    effect_sizes = list(np.arange(-0.25, 0.25, 0.05)),
    lookback_window = 1,
    include_locations=["chicago"],
    exclude_locations=["honolulu"],
    cpic = 7.50,
    budget = 100_000,
    alpha = 0.1,
    side_of_test="one_sided",
    fixed_effects=True,
)
with open("market_selection_api_input.json", "w") as f:
    f.write(api_input.json())
res = market_selection(api_input)
with open("market_selection_api_output.json", "w") as f:
    f.write(res.json())

# market_selections = geolift.geo_lift_market_selection(
#                                         data = data_clean, #geo_test_data_pre_test,
#                                         treatment_periods = input.treatment_periods,
#                                         N = input.num_locations,
#                                         Y_id = "Y",
#                                         location_id = "location",
#                                         time_id = "time",
#                                         effect_size = input.effect_sizes,
#                                         lookback_window = 1, 
#                                         include_markets = input.include_locations,
#                                         exclude_markets = input.exclude_locations,
#                                         cpic = 7.50,
#                                         budget = 100000,
#                                         alpha = 0.1,
#                                         Correlations = True,
#                                         fixed_effects = True,
#                                         side_of_test = "one_sided"
#                                         )

# MarketSelections <- GeoLiftMarketSelection(data = GeoTestData_PreTest,
#                                           treatment_periods = c(10,15),
#                                           N = c(2,3,4,5),
#                                           Y_id = "Y",
#                                           location_id = "location",
#                                           time_id = "time",
#                                           effect_size = seq(-0.25, 0.25, 0.05),
#                                           lookback_window = 1, 
#                                           include_markets = c("chicago"),
#                                           exclude_markets = c("honolulu"),
#                                           cpic = 7.50,
#                                           budget = 100000,
#                                           alpha = 0.1,
#                                           Correlations = TRUE,
#                                           fixed_effects = TRUE,
#                                           side_of_test = "one_sided")
# Out:
# R[write to console]:
# Deterministic setup with 2 locations in treatment.
#
# R[write to console]:
# Deterministic setup with 3 locations in treatment.
#
# R[write to console]:
# Deterministic setup with 4 locations in treatment.
#
# R[write to console]:
# Deterministic setup with 5 locations in treatment.

# %%
res.dict()
# Out:
# {'__root__': [{'location': ['chicago', ' portland'],
#    'duration': 15,
#    'EffectSize': 0.04999999999999993,
#    'Power': 1.0,
#    'AvgScaledL2Imbalance': 0.17387779481518423,
#    'Investment': 32281.874999999956,
#    'AvgATT': 146.53208139442432,
#    'Average_MDE': 0.05111983233411362,
#    'ProportionTotal_Y': 0.03306537043498415,
#    'abs_lift_in_zero': 0.001,
#    'Holdout': 0.9669346295650159,
#    'rank': 1,
#    'correlation': None,
#    'power_curve': [{'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': -0.25,
#      'power': 1.0,
#      'Investment': 161409.375,
#      'AvgATT': -714.3179186055752,
#      'AvgDetectedLift': -0.2492001197613473},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': -0.2,
#      'power': 1.0,
#      'Investment': 129127.5,
#      'AvgATT': -570.8429186055752,
#      'AvgDetectedLift': -0.19914679441210378},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': -0.15000000000000002,
#      'power': 1.0,
#      'Investment': 96845.62500000001,
#      'AvgATT': -427.3679186055752,
#      'AvgDetectedLift': -0.14909346906286025},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': -0.10000000000000003,
#      'power': 1.0,
#      'Investment': 64563.75000000002,
#      'AvgATT': -283.8929186055752,
#      'AvgDetectedLift': -0.09904014371361675},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': -0.050000000000000044,
#      'power': 1.0,
#      'Investment': 32281.87500000003,
#      'AvgATT': -140.4179186055752,
#      'AvgDetectedLift': -0.048986818364373234},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': -5.551115123125783e-17,
#      'power': 0.0,
#      'Investment': 3.5840080903071225e-11,
#      'AvgATT': 3.057081394424798,
#      'AvgDetectedLift': 0.0010665069848702802},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': 0.04999999999999993,
#      'power': 1.0,
#      'Investment': 32281.874999999956,
#      'AvgATT': 146.53208139442432,
#      'AvgDetectedLift': 0.05111983233411362},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': 0.09999999999999992,
#      'power': 1.0,
#      'Investment': 64563.74999999995,
#      'AvgATT': 290.0070813944243,
#      'AvgDetectedLift': 0.10117315768335713},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': 0.1499999999999999,
#      'power': 1.0,
#      'Investment': 96845.62499999994,
#      'AvgATT': 433.4820813944248,
#      'AvgDetectedLift': 0.15122648303260083},
#     {'location': 'chicago, portland',
#      'duration': 15,
#      'EffectSize': 0.1999999999999999,
#      'power': 1.0,
#      'Investment': 129127.49999999994,
#      'AvgATT': 576.9570813944248,
#      'AvgDetectedLift': 0.20127980838184434}]},
#   {'location': ['chicago', ' portland'],
#    'duration': 10,
#    'EffectSize': 0.04999999999999993,
#    'Power': 1.0,
#    'AvgScaledL2Imbalance': 0.16823100500772098,
#    'Investment': 21823.12499999997,
#    'AvgATT': 155.45257029995665,
#    'Average_MDE': 0.053608310294942056,
#    'ProportionTotal_Y': 0.03306537043498415,
#    'abs_lift_in_zero': 0.004,
#    'Holdout': 0.9669346295650159,
#    'rank': 2,
#    'correlation': None,
#    'power_curve': [{'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': -0.25,
#      'power': 1.0,
#      'Investment': 109115.625,
#      'AvgATT': -717.472429700043,
#      'AvgDetectedLift': -0.24742263550361274},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': -0.2,
#      'power': 1.0,
#      'Investment': 87292.5,
#      'AvgATT': -571.984929700043,
#      'AvgDetectedLift': -0.19725081120385357},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': -0.15000000000000002,
#      'power': 1.0,
#      'Investment': 65469.37500000001,
#      'AvgATT': -426.49742970004297,
#      'AvgDetectedLift': -0.14707898690409443},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': -0.10000000000000003,
#      'power': 1.0,
#      'Investment': 43646.250000000015,
#      'AvgATT': -281.00992970004336,
#      'AvgDetectedLift': -0.09690716260433539},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': -0.050000000000000044,
#      'power': 1.0,
#      'Investment': 21823.12500000002,
#      'AvgATT': -135.522429700043,
#      'AvgDetectedLift': -0.04673533830457612},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': -5.551115123125783e-17,
#      'power': 0.0,
#      'Investment': 2.422853584427287e-11,
#      'AvgATT': 9.965070299957006,
#      'AvgDetectedLift': 0.00343648599518303},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': 0.04999999999999993,
#      'power': 1.0,
#      'Investment': 21823.12499999997,
#      'AvgATT': 155.45257029995665,
#      'AvgDetectedLift': 0.053608310294942056},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': 0.09999999999999992,
#      'power': 1.0,
#      'Investment': 43646.24999999996,
#      'AvgATT': 300.94007029995663,
#      'AvgDetectedLift': 0.1037801345947012},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': 0.1499999999999999,
#      'power': 1.0,
#      'Investment': 65469.37499999996,
#      'AvgATT': 446.427570299957,
#      'AvgDetectedLift': 0.15395195889446048},
#     {'location': 'chicago, portland',
#      'duration': 10,
#      'EffectSize': 0.1999999999999999,
#      'power': 1.0,
#      'Investment': 87292.49999999996,
#      'AvgATT': 591.915069463638,
#      'AvgDetectedLift': 0.20412378284694163}]},
#   {'location': ['atlanta', ' chicago'],
#    'duration': 15,
#    'EffectSize': 0.04999999999999993,
#    'Power': 1.0,
#    'AvgScaledL2Imbalance': 0.44615536607978273,
#    'Investment': 40674.37499999995,
#    'AvgATT': 156.0039054236923,
#    'Average_MDE': 0.042855024082169256,
#    'ProportionTotal_Y': 0.04195216975630156,
#    'abs_lift_in_zero': 0.007,
#    'Holdout': 0.9580478302436984,
#    'rank': 3,
#    'correlation': None,
#    'power_curve': [{'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': -0.25,
#      'power': 1.0,
#      'Investment': 203371.875,
#      'AvgATT': -928.6460945763072,
#      'AvgDetectedLift': -0.25510355422702186},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': -0.2,
#      'power': 1.0,
#      'Investment': 162697.5,
#      'AvgATT': -747.8710945763072,
#      'AvgDetectedLift': -0.20544379117549},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': -0.15000000000000002,
#      'power': 1.0,
#      'Investment': 122023.12500000001,
#      'AvgATT': -567.0960945763072,
#      'AvgDetectedLift': -0.1557840281239581},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': -0.10000000000000003,
#      'power': 1.0,
#      'Investment': 81348.75000000003,
#      'AvgATT': -386.32109445236904,
#      'AvgDetectedLift': -0.10612426504199299},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': -0.050000000000000044,
#      'power': 1.0,
#      'Investment': 40674.37500000004,
#      'AvgATT': -205.5460945763072,
#      'AvgDetectedLift': -0.05646450202089436},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': -5.551115123125783e-17,
#      'power': 0.0,
#      'Investment': 4.515762763723785e-11,
#      'AvgATT': -24.771094576307224,
#      'AvgDetectedLift': -0.006804738969362485},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': 0.04999999999999993,
#      'power': 1.0,
#      'Investment': 40674.37499999995,
#      'AvgATT': 156.0039054236923,
#      'AvgDetectedLift': 0.042855024082169256},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': 0.09999999999999992,
#      'power': 1.0,
#      'Investment': 81348.74999999994,
#      'AvgATT': 336.77890542369227,
#      'AvgDetectedLift': 0.09251478713370113},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': 0.1499999999999999,
#      'power': 1.0,
#      'Investment': 122023.12499999993,
#      'AvgATT': 517.5539054236923,
#      'AvgDetectedLift': 0.142174550185233},
#     {'location': 'atlanta, chicago',
#      'duration': 15,
#      'EffectSize': 0.1999999999999999,
#      'power': 1.0,
#      'Investment': 162697.4999999999,
#      'AvgATT': 698.3289054236927,
#      'AvgDetectedLift': 0.19183431323676503}]},
#   {'location': ['atlanta', ' chicago'],
#    'duration': 10,
#    'EffectSize': 0.04999999999999993,
#    'Power': 1.0,
#    'AvgScaledL2Imbalance': 0.45475375411558866,
#    'Investment': 27439.124999999964,
#    'AvgATT': 154.69335718562652,
#    'Average_MDE': 0.0419588864423016,
#    'ProportionTotal_Y': 0.04195216975630156,
#    'abs_lift_in_zero': 0.008,
#    'Holdout': 0.9580478302436984,
#    'rank': 4,
#    'correlation': None,
#    'power_curve': [{'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': -0.25,
#      'power': 1.0,
#      'Investment': 137195.625,
#      'AvgATT': -942.8716428143729,
#      'AvgDetectedLift': -0.255743652541213},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': -0.2,
#      'power': 1.0,
#      'Investment': 109756.5,
#      'AvgATT': -759.9441428143728,
#      'AvgDetectedLift': -0.20612656271062718},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': -0.15000000000000002,
#      'power': 1.0,
#      'Investment': 82317.37500000001,
#      'AvgATT': -577.016642814373,
#      'AvgDetectedLift': -0.15650947288004147},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': -0.10000000000000003,
#      'power': 1.0,
#      'Investment': 54878.25000000002,
#      'AvgATT': -394.0891428143732,
#      'AvgDetectedLift': -0.10689238304945571},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': -0.050000000000000044,
#      'power': 1.0,
#      'Investment': 27439.125000000025,
#      'AvgATT': -211.16164281437304,
#      'AvgDetectedLift': -0.05727529321886988},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': -5.551115123125783e-17,
#      'power': 0.0,
#      'Investment': 3.046354835056775e-11,
#      'AvgATT': -28.2341428143729,
#      'AvgDetectedLift': -0.007658203388284039},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': 0.04999999999999993,
#      'power': 1.0,
#      'Investment': 27439.124999999964,
#      'AvgATT': 154.69335718562652,
#      'AvgDetectedLift': 0.0419588864423016},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': 0.09999999999999992,
#      'power': 1.0,
#      'Investment': 54878.249999999956,
#      'AvgATT': 337.6208571856267,
#      'AvgDetectedLift': 0.09157597627288744},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': 0.1499999999999999,
#      'power': 1.0,
#      'Investment': 82317.37499999996,
#      'AvgATT': 520.5483571856269,
#      'AvgDetectedLift': 0.14119306610347326},
#     {'location': 'atlanta, chicago',
#      'duration': 10,
#      'EffectSize': 0.1999999999999999,
#      'power': 1.0,
#      'Investment': 109756.49999999994,
#      'AvgATT': 703.475857185627,
#      'AvgDetectedLift': 0.19081015593405912}]},
#   {'location': ['chicago', ' cincinnati'],
#    'duration': 10,
#    'EffectSize': -5.551115123125783e-17,
#    'Power': 1.0,
#    'AvgScaledL2Imbalance': 0.18067897536937125,
#    'Investment': 2.485386896289299e-11,
#    'AvgATT': -93.98191590497008,
#    'Average_MDE': -0.030525185678200853,
#    'ProportionTotal_Y': 0.03418832056289843,
#    'abs_lift_in_zero': 0.031,
#    'Holdout': 0.03418832056289843,
#    'rank': 5,
#    'correlation': None,
#    'power_curve': [{'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': -0.25,
#      'power': 1.0,
#      'Investment': 111931.875,
#      'AvgATT': -840.1944159049701,
#      'AvgDetectedLift': -0.27289388925865066},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': -0.2,
#      'power': 1.0,
#      'Investment': 89545.5,
#      'AvgATT': -690.9519159049698,
#      'AvgDetectedLift': -0.2244201485425606},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': -0.15000000000000002,
#      'power': 1.0,
#      'Investment': 67159.12500000001,
#      'AvgATT': -541.7094159049702,
#      'AvgDetectedLift': -0.17594640782647078},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': -0.10000000000000003,
#      'power': 1.0,
#      'Investment': 44772.750000000015,
#      'AvgATT': -392.4669159049703,
#      'AvgDetectedLift': -0.12747266711038083},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': -0.050000000000000044,
#      'power': 1.0,
#      'Investment': 22386.37500000002,
#      'AvgATT': -243.22441590497039,
#      'AvgDetectedLift': -0.0789989263942909},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': -5.551115123125783e-17,
#      'power': 1.0,
#      'Investment': 2.485386896289299e-11,
#      'AvgATT': -93.98191590497008,
#      'AvgDetectedLift': -0.030525185678200853},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': 0.04999999999999993,
#      'power': 0.0,
#      'Investment': 22386.37499999997,
#      'AvgATT': 55.26058409502948,
#      'AvgDetectedLift': 0.017948555037888964},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': 0.09999999999999992,
#      'power': 1.0,
#      'Investment': 44772.74999999996,
#      'AvgATT': 204.50308409502978,
#      'AvgDetectedLift': 0.06642229575397901},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': 0.1499999999999999,
#      'power': 1.0,
#      'Investment': 67159.12499999996,
#      'AvgATT': 353.74558409502936,
#      'AvgDetectedLift': 0.11489603647006882},
#     {'location': 'chicago, cincinnati',
#      'duration': 10,
#      'EffectSize': 0.1999999999999999,
#      'power': 1.0,
#      'Investment': 89545.49999999996,
#      'AvgATT': 502.98808409502965,
#      'AvgDetectedLift': 0.1633697771861589}]},
#   {'location': ['chicago', ' cincinnati'],
#    'duration': 15,
#    'EffectSize': 0.04999999999999993,
#    'Power': 1.0,
#    'AvgScaledL2Imbalance': 0.18424567905160738,
#    'Investment': 33318.374999999956,
#    'AvgATT': 100.43328494112987,
#    'Average_MDE': 0.03337450410127692,
#    'ProportionTotal_Y': 0.03418832056289843,
#    'abs_lift_in_zero': 0.017,
#    'Holdout': 0.9658116794371016,
#    'rank': 5,
#    'correlation': None,
#    'power_curve': [{'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': -0.25,
#      'power': 1.0,
#      'Investment': 166591.875,
#      'AvgATT': -788.0567150588696,
#      'AvgDetectedLift': -0.2618753542133735},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': -0.2,
#      'power': 1.0,
#      'Investment': 133273.5,
#      'AvgATT': -639.975048392203,
#      'AvgDetectedLift': -0.2126670444942651},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': -0.15000000000000002,
#      'power': 1.0,
#      'Investment': 99955.12500000001,
#      'AvgATT': -491.8933817255364,
#      'AvgDetectedLift': -0.16345873477515668},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': -0.10000000000000003,
#      'power': 1.0,
#      'Investment': 66636.75000000003,
#      'AvgATT': -343.8117150588698,
#      'AvgDetectedLift': -0.1142504250560483},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': -0.050000000000000044,
#      'power': 1.0,
#      'Investment': 33318.37500000003,
#      'AvgATT': -195.73004839220326,
#      'AvgDetectedLift': -0.06504211533693989},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': -5.551115123125783e-17,
#      'power': 0.0,
#      'Investment': 3.69908270680952e-11,
#      'AvgATT': -47.64838172553621,
#      'AvgDetectedLift': -0.015833805617831324},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': 0.04999999999999993,
#      'power': 1.0,
#      'Investment': 33318.374999999956,
#      'AvgATT': 100.43328494112987,
#      'AvgDetectedLift': 0.03337450410127692},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': 0.09999999999999992,
#      'power': 1.0,
#      'Investment': 66636.74999999994,
#      'AvgATT': 248.51495160779692,
#      'AvgDetectedLift': 0.08258281382038547},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': 0.1499999999999999,
#      'power': 1.0,
#      'Investment': 99955.12499999994,
#      'AvgATT': 396.5966182744635,
#      'AvgDetectedLift': 0.13179112353949388},
#     {'location': 'chicago, cincinnati',
#      'duration': 15,
#      'EffectSize': 0.1999999999999999,
#      'power': 1.0,
#      'Investment': 133273.49999999994,
#      'AvgATT': 544.6782849411305,
#      'AvgDetectedLift': 0.18099943325860243}]}]}

# %%
# Out:
# [-0.25, -0.2, -0.15, -0.1, -0.05, -0.0, 0.05, 0.1, 0.15, 0.2]

# %%
geo_test_data_test = geolift.geo_data_read(data = GeoLift_Test,
                                    date_id = "date",
                                    location_id = "location",
                                    Y_id = "Y",
                                    format = "yyyy-mm-dd",
                                    summary = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000016?line=0'>1</a> geo_test_data_test = geolift.geo_data_read(data = GeoLift_Test,
#       <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000016?line=1'>2</a>                                     date_id = "date",
#       <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000016?line=2'>3</a>                                     location_id = "location",
#       <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000016?line=3'>4</a>                                     Y_id = "Y",
#       <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000016?line=4'>5</a>                                     format = "yyyy-mm-dd",
#       <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000016?line=5'>6</a>                                     summary = True)
#
# NameError: name 'GeoLift_Test' is not defined

# %%
geo_test_data_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb Cell 16' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jrnold/geox/geox-api/py-geolift/notebooks/PyGeoLiftWalkThrough.ipynb#ch0000017?line=0'>1</a> df
#
# NameError: name 'df' is not defined

# %% [markdown]
# Experiment create info
#
# - name
# - locations and variants
# - experiment start
# - experiment end
# - metrics
# - time unit: date
# - additional matching metrics (TBD)
# - model used to analyze it ... ?
#
# TODO: the data and metrics will include data prior to the experiment start. How should that be handled?

# %%
geo_lift_test_dates = GeoLift_Test['date'].unique()
geo_lift_test_dates.sort()
geo_lift_test_dates[[90, 104]]
# Out:
# array(['2021-04-01', '2021-04-15'], dtype=object)

# %%
geo_test = geolift.geo_lift(
                   data = geo_test_data_test,
                   locations = ["chicago", "portland"],
                   treatment_start_time = 91, 
                   treatment_end_time = 105,
                   Y_id = "Y",
                   location_id = "location",
                   time_id = "time")

# %% [markdown]
# experiment:
#   - id
#   - name
#   - pre_period_start
#   - pre_period_end
#   - treatment_end
#   - treatment_start
#   - alpha
#
# experiment_variants:
#   - variant: str
#
# experiment_assignments:
#   - variant: str
#   - location: str
#
# results:
#   - experiment_id
#   - blob of stuff
#
#
# ['results',
#  'inference',
#  'data',
#  'y_obs',
#  'y_hat',
#  'ATT',
#  'ATT_se',
#  'TreatmentStart',
#  'TreatmentEnd',
#  'test_id',
#  'incremental',
#  'Y_id',
#  'summary',
#  'ConfidenceIntervals',
#  'lower_bound',
#  'upper_bound',
#  'df_weights',
#  'stat_test']

# %%
# 
# treated_time = 15
# untreated time = 90
# geo_test_data_test['time'].max(). Max 105 time periods
# treated locations = 2
# geo_test_data_test['location'].unique().size = 40 unique periods
# Out:
# 40

# %% [markdown]
# Note: Augsynth fits the per-period "mean" of all the treated units!

# %%
from pygeolift.rpy2_utils import r_df_to_pandas
print(geo_test.rx2("test_id"))
results = geo_test.rx2("results")
results.rx2("weights")
# Out:
#   loc_id     name
# 1      6  chicago
# 2     32 portland
# <rpy2.robjects.vectors.FloatMatrix object at 0x13001dc00> [RTYPES.REALSXP]
# R classes: ('matrix', 'array')
# [0.000000, 0.046525, -0.000000, 0.133537, ..., 0.045073, 0.000000, 0.000000, 0.000000]

# %%
# Experiment
import pandas as pd
name = 'Example 1'
variants = ['treatment', 'control']
treatment_locations = ['chicago', 'portland']
start_date = '2021-04-01'
end_date = '2021-04-15'

locations = pd.DataFrame({'location': GeoLift_Test['location'].unique()})
locations['variant'] = 'control'
locations[locations['location'].isin(treatment_locations)] = 'treatment'

# %%
# Out:
# array([-2147483648], dtype=int32)
